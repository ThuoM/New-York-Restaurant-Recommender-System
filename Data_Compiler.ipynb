# %%
from bs4 import BeautifulSoup
import requests
import time
import random
import re
import csv
import pandas as pd

# %%
from os import walk

# folder path
dir_path = r'reviews'
res = []
for (dir_path, dir_names, file_names) in walk(dir_path):
    # print(f'Adding these files: {file_names}')
    res.extend(file_names)
    # don't look inside any subdirectory
    break
print(res)
# Out:
# ['reviews (1).csv', 'reviews (10).csv', 'reviews (11).csv', 'reviews (12).csv', 'reviews (13).csv', 'reviews (14).csv', 'reviews (15).csv', 'reviews (16).csv', 'reviews (17).csv', 'reviews (18).csv', 'reviews (19).csv', 'reviews (20).csv', 'reviews (21).csv', 'reviews (22).csv', 'reviews (23).csv', 'reviews (24).csv', 'reviews (3).csv', 'reviews (30).csv', 'reviews (31).csv', 'reviews (32).csv', 'reviews (33).csv', 'reviews (34).csv', 'reviews (35).csv', 'reviews (36).csv', 'reviews (37).csv', 'reviews (38).csv', 'reviews (39).csv', 'reviews (4).csv', 'reviews (40).csv', 'reviews (41).csv', 'reviews (42).csv', 'reviews (43).csv', 'reviews (44).csv', 'reviews (45).csv', 'reviews (46).csv', 'reviews (47).csv', 'reviews (49).csv', 'reviews (5).csv', 'reviews (50).csv', 'reviews (51).csv', 'reviews (52).csv', 'reviews (53).csv', 'reviews (54).csv', 'reviews (55).csv', 'reviews (56).csv', 'reviews (57).csv', 'reviews (58).csv', 'reviews (59).csv', 'reviews (6).csv', 'reviews (60).csv', 'reviews (61).csv', 'reviews (7).csv', 'reviews (8).csv', 'reviews (9).csv', 'reviews st.csv', 'reviews.csv', 'reviews2.csv', 'reviews3.csv', 'reviewsa.csv', 'reviewsb.csv', 'reviewsc.csv', 'reviewsd.csv', 'reviewse.csv', 'reviewsf.csv', 'reviewsg.csv', 'reviewsh.csv', 'reviewsi.csv']

# %%
# list of the files to keep
keep = []

for name in res:
    if 'review' in name:
        keep.append(name)
print(keep)
# Out:
# ['reviews (1).csv', 'reviews (10).csv', 'reviews (11).csv', 'reviews (12).csv', 'reviews (13).csv', 'reviews (14).csv', 'reviews (15).csv', 'reviews (16).csv', 'reviews (17).csv', 'reviews (18).csv', 'reviews (19).csv', 'reviews (20).csv', 'reviews (21).csv', 'reviews (22).csv', 'reviews (23).csv', 'reviews (24).csv', 'reviews (3).csv', 'reviews (30).csv', 'reviews (31).csv', 'reviews (32).csv', 'reviews (33).csv', 'reviews (34).csv', 'reviews (35).csv', 'reviews (36).csv', 'reviews (37).csv', 'reviews (38).csv', 'reviews (39).csv', 'reviews (4).csv', 'reviews (40).csv', 'reviews (41).csv', 'reviews (42).csv', 'reviews (43).csv', 'reviews (44).csv', 'reviews (45).csv', 'reviews (46).csv', 'reviews (47).csv', 'reviews (49).csv', 'reviews (5).csv', 'reviews (50).csv', 'reviews (51).csv', 'reviews (52).csv', 'reviews (53).csv', 'reviews (54).csv', 'reviews (55).csv', 'reviews (56).csv', 'reviews (57).csv', 'reviews (58).csv', 'reviews (59).csv', 'reviews (6).csv', 'reviews (60).csv', 'reviews (61).csv', 'reviews (7).csv', 'reviews (8).csv', 'reviews (9).csv', 'reviews st.csv', 'reviews.csv', 'reviews2.csv', 'reviews3.csv', 'reviewsa.csv', 'reviewsb.csv', 'reviewsc.csv', 'reviewsd.csv', 'reviewse.csv', 'reviewsf.csv', 'reviewsg.csv', 'reviewsh.csv', 'reviewsi.csv']

# %%
# Confirms the list of files to pull data from
work_on = []
with open('list.csv', 'r') as csvfile:
    info = csvfile.read()
    for line in keep:
        if line in info:
            continue
        else:
            print(f'Pulling data from {line}')
            work_on.append(line)
    csvfile.close()

# %%
# !pip install --upgrade pandas

# %%
li = []
with open('list.csv', 'a+', encoding='utf-8') as csvfile:
    list_writer = csv.writer(csvfile)
    dic = {}
    length = len(work_on)
    print(length)
    while length >= 1:
        for name in work_on:
            print(f'{name} is being read ..............')
            df = pd.read_csv(f'reviews/{name}', index_col=None, on_bad_lines='skip',header=None)
            li.append(df)
            dic['name'] = name
            list_writer.writerow(dic.values())
            length -= 1
        final_frame = pd.concat(li, axis=0, ignore_index=True)
        print('Gone through entire list')
# Out:
# 0

# %%
final_frame.head()
# Out:
#            0                                            1  \
# 0   Wendy Z.  /user_details?userid=oOKOZaixy015iOziX27aww
# 1   Kenny C.  /user_details?userid=xJpvRrk04rb4rgWtMXaPUQ
# 2  Donald K.  /user_details?userid=lnhsAi3Sia4umNhsUZt3hA
# 3  Olivia W.  /user_details?userid=_4nGEt_tsWh6x_K4HB1jdQ
# 4  Angela F.  /user_details?userid=soOntXRt-ALDxLGzJokaPQ
#
#                         2           3    4           5  \
# 0            Brooklyn, NY    7/3/2022  5.0  No comment
# 1            Brooklyn, NY   5/31/2022  4.0  No comment
# 2  Brooklyn, Brooklyn, NY  11/19/2022  2.0  No comment
# 3            Brooklyn, NY   3/26/2022  4.0  No comment
# 4            Brooklyn, NY    4/4/2022  4.0  No comment
#
#                                                    6
# 0  https://www.yelp.com/biz/menya-and-izakaya-bro...
# 1  https://www.yelp.com/biz/menya-and-izakaya-bro...
# 2  https://www.yelp.com/biz/menya-and-izakaya-bro...
# 3  https://www.yelp.com/biz/menya-and-izakaya-bro...
# 4  https://www.yelp.com/biz/menya-and-izakaya-bro...

# %%
# remove duplicates
final_frame = final_frame.drop_duplicates()

# check duplicates
print(f'The num of duplicates are: {final_frame.duplicated().sum()} duplicates')
# Out:
# The num of duplicates are: 0 duplicates

# %%
# columns having null values
final_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22422 entries, 0 to 22432
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       22422 non-null  object
#  1   1       22422 non-null  object
#  2   2       22422 non-null  object
#  3   3       22422 non-null  object
#  4   4       22422 non-null  float64
#  5   5       22422 non-null  object
#  6   6       22422 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 1.4+ MB

# %%
final_frame = final_frame.dropna(axis=0)
final_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22422 entries, 0 to 22432
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       22422 non-null  object
#  1   1       22422 non-null  object
#  2   2       22422 non-null  object
#  3   3       22422 non-null  object
#  4   4       22422 non-null  float64
#  5   5       22422 non-null  object
#  6   6       22422 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 1.4+ MB

# %%
# check the percentage of restaurants done in the final csv

restaurants = pd.read_csv('restaurant_data.csv')

rest_df = restaurants.drop_duplicates(subset=['URL'])
rest_df.head()
# Out:
#               Name  Rating Pricing  \
# 0        Da Andrea       4      $$
# 1         LoveMama       5      $$
# 2  Ye's Apothecary       5     $$$
# 3   Joe's Shanghai       4      $$
# 4         Antidote       4      $$
#
#                                                  URL   Latitude  Longitude  \
# 0  https://www.yelp.com/biz/da-andrea-new-york?ad...  40.736218 -73.995970
# 1  https://www.yelp.com/biz/lovemama-new-york?adj...  40.730409 -73.986127
# 2  https://www.yelp.com/biz/yes-apothecary-new-yo...  40.719450 -73.989800
# 3  https://www.yelp.com/biz/joes-shanghai-new-yor...  40.715661 -73.996701
# 4  https://www.yelp.com/biz/antidote-brooklyn-2?a...  40.714253 -73.965448
#
#                                        Transactions  \
# 0  ['delivery', 'pickup', 'restaurant_reservation']
# 1  ['delivery', 'pickup', 'restaurant_reservation']
# 2                                                []
# 3                            ['delivery', 'pickup']
# 4                            ['delivery', 'pickup']
#
#                              Location         Phone   Display Phone  \
# 0    35 W 13th St, New York, NY 10011  1.212367e+10  (212) 367-1979
# 1     174 2nd Ave, New York, NY 10003  1.212255e+10  (212) 254-5370
# 2  119 Orchard St, New York, NY 10002           NaN             NaN
# 3    46 Bowery St, New York, NY 10013  1.212234e+10  (212) 233-8888
# 4     66 S 2nd St, Brooklyn, NY 11249  1.718782e+10  (718) 782-2585
#
#       Distance                                            Reviews  \
# 0  3526.365252  [{'text': 'This small and crowded place seems ...
# 1  2645.074283  [{'text': 'Absolutely LOVED LoveMama!! As a co...
# 2  1638.756115  [{'text': 'Edy and Josh are the BEST bartender...
# 3  1766.176007  [{'text': 'This is the third stop of our food ...
# 4  1376.494330  [{'text': 'Excellent service & food! The drink...
#
#    Review Count                                Cuisine  \
# 0             3                    I, t, a, l, i, a, n
# 1             3                             T, h, a, i
# 2             3                 S, z, e, c, h, u, a, n
# 3             3     S, h, a, n, g, h, a, i, n, e, s, e
# 4             3  C, o, c, k, t, a, i, l,  , B, a, r, s
#
#             Restaurant ID  Number of Reviews
# 0  hdiuRS9sVZSMReZm4oV5SA               1851
# 1  jjJc_CrkB2HodEinB6cWww               6377
# 2  8YWLuLUKj0t_0_Xv06UUtw                212
# 3  0CjK3esfpFcxIopebzjFxA               7098
# 4  4DInnPhOyvXFbYpUdO0SMQ                325

# %%
# get the set of available restaurants
got_rest = set(final_frame[6])

list_rest = set(rest_df['URL'])

# %%
# What restaurants do we have
missing_urls = []
for url in list_rest:
    if url in got_rest:
        num = len(final_frame[final_frame[6] == url])
        expected = rest_df[rest_df['URL'] == url]
        # print(expected['Number of Reviews'])
        eventual = float(num/expected['Number of Reviews']) *100
        if eventual >= 90.0:
            print(f"We have {expected['Name']} and have about ....... {eventual}% of expected collection")
            print('WITHIN COMPLETED EXPECTATION')
        else:
            print(f"We have {expected['Name']} and have about ....... {eventual}% of expected collection")
            print(f"{expected['Name']} NEEDS MORE COLLECTION PLEASE")
            missing_urls.append(url)
    else:
        expected = rest_df[rest_df['URL'] == url]
        num = 0
        eventual = (num/expected['Number of Reviews']) *100
        # print(f"We have {expected['Name']} and have about ....... {eventual}% of expected collection")
        # print(f"{expected['Name']} NEEDS MORE COLLECTION PLEASE")
        missing_urls.append(url)

        
print('Done with list of content')
# Out:
# We have 396    Popular
# Name: Name, dtype: object and have about ....... 93.26923076923077% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 231    Bites of Xi'an
# Name: Name, dtype: object and have about ....... 87.5% of expected collection
# 231    Bites of Xi'an
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 359    Somtum Der Redhook
# Name: Name, dtype: object and have about ....... 65.78947368421053% of expected collection
# 359    Somtum Der Redhook
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 262    Chino Grande
# Name: Name, dtype: object and have about ....... 56.52173913043478% of expected collection
# 262    Chino Grande
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 184    Koloman
# Name: Name, dtype: object and have about ....... 92.3076923076923% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 42    Momofuku Ssam Bar
# Name: Name, dtype: object and have about ....... 83.78378378378379% of expected collection
# 42    Momofuku Ssam Bar
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 151    Izakaya Juraku
# Name: Name, dtype: object and have about ....... 63.87434554973822% of expected collection
# 151    Izakaya Juraku
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 59    Fifty Henry
# Name: Name, dtype: object and have about ....... 76.92307692307693% of expected collection
# 59    Fifty Henry
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 61    Java Indonesian Restaurant
# Name: Name, dtype: object and have about ....... 83.88429752066115% of expected collection
# 61    Java Indonesian Restaurant
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 111    Place des Fêtes
# Name: Name, dtype: object and have about ....... 103.125% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 347    Osteria La Baia
# Name: Name, dtype: object and have about ....... 101.35135135135135% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 37    Aoi Kitchen
# Name: Name, dtype: object and have about ....... 88.42592592592592% of expected collection
# 37    Aoi Kitchen
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 432    Oiji Mi
# Name: Name, dtype: object and have about ....... 89.31297709923665% of expected collection
# 432    Oiji Mi
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 50    SPES
# Name: Name, dtype: object and have about ....... 106.4516129032258% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 277    3 Times
# Name: Name, dtype: object and have about ....... 80.46511627906978% of expected collection
# 277    3 Times
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 487    Oxalis
# Name: Name, dtype: object and have about ....... 90.8695652173913% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 420    La Barca Cantina
# Name: Name, dtype: object and have about ....... 89.58333333333334% of expected collection
# 420    La Barca Cantina
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 93    Sun Hing Lung Co
# Name: Name, dtype: object and have about ....... 88.0% of expected collection
# 93    Sun Hing Lung Co
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 339    Cafe Spaghetti
# Name: Name, dtype: object and have about ....... 102.85714285714285% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 337    Pearl Street Supper Club
# Name: Name, dtype: object and have about ....... 88.88888888888889% of expected collection
# 337    Pearl Street Supper Club
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 54    Mad for Chicken Brooklyn Heights
# Name: Name, dtype: object and have about ....... 57.89473684210527% of expected collection
# 54    Mad for Chicken Brooklyn Heights
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 241    H&H Reserve
# Name: Name, dtype: object and have about ....... 100.0% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 87    Omusubi Gonbei
# Name: Name, dtype: object and have about ....... 73.39449541284404% of expected collection
# 87    Omusubi Gonbei
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 72    Xolo
# Name: Name, dtype: object and have about ....... 109.09090909090908% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 223    Mekelburg's
# Name: Name, dtype: object and have about ....... 100.0% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 187    Chef Huang Jian Bing & Peking Duck
# Name: Name, dtype: object and have about ....... 57.99999999999999% of expected collection
# 187    Chef Huang Jian Bing & Peking Duck
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 90    Monsieur Vo
# Name: Name, dtype: object and have about ....... 44.230769230769226% of expected collection
# 90    Monsieur Vo
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 424    Canal Street Market
# Name: Name, dtype: object and have about ....... 94.81132075471697% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 190    Endswell Bar & Bistro
# Name: Name, dtype: object and have about ....... 92.43697478991596% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 79    The Grotto
# Name: Name, dtype: object and have about ....... 104.16666666666667% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 213    Leroy's
# Name: Name, dtype: object and have about ....... 57.14285714285714% of expected collection
# 213    Leroy's
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 293    Itaewon Pocha
# Name: Name, dtype: object and have about ....... 0.4166666666666667% of expected collection
# 293    Itaewon Pocha
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 298    Ensenada
# Name: Name, dtype: object and have about ....... 105.55555555555556% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 291    Loreto Italian Kitchen & Bar
# Name: Name, dtype: object and have about ....... 104.08163265306123% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 96    Fong On
# Name: Name, dtype: object and have about ....... 87.86610878661088% of expected collection
# 96    Fong On
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 372    Nabila’s
# Name: Name, dtype: object and have about ....... 105.26315789473684% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 113    El Pingüino
# Name: Name, dtype: object and have about ....... 113.63636363636364% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 20    Ichibantei
# Name: Name, dtype: object and have about ....... 89.39929328621908% of expected collection
# 20    Ichibantei
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 330    Izakaya
# Name: Name, dtype: object and have about ....... 88.8086642599278% of expected collection
# 330    Izakaya
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 308    Bar Camillo
# Name: Name, dtype: object and have about ....... 100.0% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 488    Little Mad
# Name: Name, dtype: object and have about ....... 95.78313253012048% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 243    Kettl
# Name: Name, dtype: object and have about ....... 100.0% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 445    Menya & Izakaya
# Name: Name, dtype: object and have about ....... 87.83783783783784% of expected collection
# 445    Menya & Izakaya
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 138    Bacàn
# Name: Name, dtype: object and have about ....... 100.0% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 71    C as in Charlie
# Name: Name, dtype: object and have about ....... 93.75% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 53    Hakata Tonton
# Name: Name, dtype: object and have about ....... 91.52542372881356% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 43    Mắm
# Name: Name, dtype: object and have about ....... 100.0% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 297    Mr Bao
# Name: Name, dtype: object and have about ....... 87.01298701298701% of expected collection
# 297    Mr Bao
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 235    Dinner Party
# Name: Name, dtype: object and have about ....... 61.53846153846154% of expected collection
# 235    Dinner Party
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 289    Aldama
# Name: Name, dtype: object and have about ....... 82.85714285714286% of expected collection
# 289    Aldama
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 85    Wan Wan
# Name: Name, dtype: object and have about ....... 75.0% of expected collection
# 85    Wan Wan
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 381    Do Not Disturb
# Name: Name, dtype: object and have about ....... 61.53846153846154% of expected collection
# 381    Do Not Disturb
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 284    Mesiba
# Name: Name, dtype: object and have about ....... 160.0% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 430    Virginia's
# Name: Name, dtype: object and have about ....... 133.33333333333331% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 369    Taiwanese Yummy
# Name: Name, dtype: object and have about ....... 133.33333333333331% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 496    Liberty Bagels
# Name: Name, dtype: object and have about ....... 90.07633587786259% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 173    Balaboosta
# Name: Name, dtype: object and have about ....... 102.0% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 209    Los Tacos No. 1
# Name: Name, dtype: object and have about ....... 60.32171581769437% of expected collection
# 209    Los Tacos No. 1
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 307    Marian's
# Name: Name, dtype: object and have about ....... 100.0% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 35    Jack's Wife Freda
# Name: Name, dtype: object and have about ....... 104.44444444444446% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 206    Deux Chats
# Name: Name, dtype: object and have about ....... 100.0% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 51    Clover Hill
# Name: Name, dtype: object and have about ....... 102.7027027027027% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 109    Olle
# Name: Name, dtype: object and have about ....... 114.28571428571428% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 387    Elder Greene
# Name: Name, dtype: object and have about ....... 101.44927536231884% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 292    Reyna
# Name: Name, dtype: object and have about ....... 122.22222222222223% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 226    GunBae Tribeca
# Name: Name, dtype: object and have about ....... 79.05759162303664% of expected collection
# 226    GunBae Tribeca
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 152    LĒNA
# Name: Name, dtype: object and have about ....... 91.66666666666666% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 300    Ho Foods
# Name: Name, dtype: object and have about ....... 79.60199004975125% of expected collection
# 300    Ho Foods
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 265    Aska
# Name: Name, dtype: object and have about ....... 71.83098591549296% of expected collection
# 265    Aska
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 10    ARIARI
# Name: Name, dtype: object and have about ....... 102.27272727272727% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 240    Monkey Bar
# Name: Name, dtype: object and have about ....... 94.73684210526315% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 112    The Reading Room
# Name: Name, dtype: object and have about ....... 96.29629629629629% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 433    Los Tacos No.1
# Name: Name, dtype: object and have about ....... 83.49514563106796% of expected collection
# 433    Los Tacos No.1
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 114    Sweetwater Restaurant
# Name: Name, dtype: object and have about ....... 91.90371991247265% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 45    The Office of Mr Moto
# Name: Name, dtype: object and have about ....... 108.57142857142857% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 195    Casino
# Name: Name, dtype: object and have about ....... 108.33333333333333% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 287    A Pasta Bar
# Name: Name, dtype: object and have about ....... 85.26315789473684% of expected collection
# 287    A Pasta Bar
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 48    Mokyo
# Name: Name, dtype: object and have about ....... 74.4186046511628% of expected collection
# 48    Mokyo
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 177    Bonnie's
# Name: Name, dtype: object and have about ....... 68.33333333333333% of expected collection
# 177    Bonnie's
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 335    no. 7
# Name: Name, dtype: object and have about ....... 100.0% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 290    Seeds & Weeds
# Name: Name, dtype: object and have about ....... 105.55555555555556% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 217    Dollar Hits - New York
# Name: Name, dtype: object and have about ....... 109.52380952380953% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 210    Dim Sum Palace
# Name: Name, dtype: object and have about ....... 86.35097493036211% of expected collection
# 210    Dim Sum Palace
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 374    La Chilaquería - New York
# Name: Name, dtype: object and have about ....... 104.76190476190477% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 182    Cool World
# Name: Name, dtype: object and have about ....... 111.11111111111111% of expected collection
# WITHIN COMPLETED EXPECTATION
# We have 99    Casa Nono
# Name: Name, dtype: object and have about ....... 74.07407407407408% of expected collection
# 99    Casa Nono
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 299    Gage and Tollner
# Name: Name, dtype: object and have about ....... 79.04191616766467% of expected collection
# 299    Gage and Tollner
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 196    Kyuramen - Chinatown
# Name: Name, dtype: object and have about ....... 71.875% of expected collection
# 196    Kyuramen - Chinatown
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 332    Medusa The Greek
# Name: Name, dtype: object and have about ....... 85.29411764705883% of expected collection
# 332    Medusa The Greek
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 225    Xu's Public House
# Name: Name, dtype: object and have about ....... 71.42857142857143% of expected collection
# 225    Xu's Public House
# Name: Name, dtype: object NEEDS MORE COLLECTION PLEASE
# We have 141    Momoya SoHo
# Name: Name, dtype: object and have about ....... 95.55555555555556% of expected collection
# WITHIN COMPLETED EXPECTATION
# Done with list of content

# %%
len(missing_urls)
# Out:
# 386

# %%
with open('final_revs.csv', 'a+', encoding='utf-8') as csvfile:
        review_writer = csv.writer(csvfile)
        for index, row in final_frame.iterrows():
            dic = {}
        
            # Assign the user values to the dictionary
            dic['username'] = row[0]
            dic['account'] = row[1]
            dic['location'] = row[2]
            dic['date'] = row[3]
            dic['rating'] = row[4]
            dic['comments'] = row[5]
            dic['restaurant'] = row[6]

            # write this info to the local csv
            review_writer.writerow(dic.values())
print('Done')
# Out:
# Done

# %%
try:
    missing_url_df = pd.read_csv('missing_urls.csv', header=None)
except pd.errors.EmptyDataError:
    found_missing_urls = list(['File is empty'])
else:
    found_missing_urls = list(missing_url_df)


found_missing_urls
# Out:
# [0]

# %%
# Dealing with missing urls
with open('missing_urls.csv', 'a+', encoding='utf-8') as csvfile:
        review_writer = csv.writer(csvfile)
        for url in missing_urls:
            dic = {}
            # print(url)
        
            if url in found_missing_urls:
                continue
            else:
                # Assign the user values to the dictionary
                dic['url'] = url

                # write this info to the local csv
                review_writer.writerow(dic.values())
print('Done')
# Out:
# Done

# %%
data = pd.read_csv('final_revs.csv')

# %%
data.shape
# Out:
# (166226, 7)
