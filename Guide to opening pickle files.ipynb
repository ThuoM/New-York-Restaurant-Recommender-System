# %%
# loading library
import dill as pickle

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
# load saved models and files
with open('model_pkl' , 'rb') as f:
    hybrid_recommender = pickle.load(f)

with open('restaurants.pkl' , 'rb') as f:
    filtered_restaurant_df = pickle.load(f)

with open('sentence_processor.pkl' , 'rb') as f:
    process_sentences = pickle.load(f)

with open('svd.pkl' , 'rb') as f:
    model = pickle.load(f)
    
with open('wards.pkl' , 'rb') as f:
    constituents_list = pickle.load(f)

with open('prices.pkl' , 'rb') as f:
    price_map = pickle.load(f)
    
with open('content_base_r.pkl' , 'rb') as f:
    contentB_recommend = pickle.load(f)

# %%
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))
result = contentB_recommend('burgers in nyc')
# result.head(10)
display('Restaurant based recommendations: ', result.head(10))
# Out:
# Processed user feedback: burger nyc
# 'Restaurant based recommendations: '
#                       name  rating   location      price        cuisine  \
# 370      7th street burger       4   new york        low        burgers
# 389          the hihi room       4   new york        low        burgers
# 411          kings of kobe       4   new york        low        burgers
# 451          kings of kobe       4   new york        low        burgers
# 301                 miznon       4   new york        low  mediterranean
# 468               ai ki ya       3   new york        low          ramen
# 325                   lupa       4   new york  mid-range        italian
# 251  macao trading company       5   new york  mid-range    asianfusion
# 239  macao trading company       5   new york  mid-range    asianfusion
# 176   emily - west village       5   new york        low          pizza
#
#          transactions                                           comments  \
# 370  pickup, delivery  my brother claimed this the best burger of nyc...
# 389  pickup, delivery  i dislike veggie burgers. but they have an ama...
# 411  delivery, pickup  the kings of kobe was a great burger place and...
# 451  delivery, pickup  the kings of kobe was a great burger place and...
# 301  pickup, delivery  my favorite burger place!! very close to 7th s...
# 468  delivery, pickup  good food! nice vibes! good service! one of my...
# 325  pickup, delivery  it's been quite sometime since i've been here,...
# 251  delivery, pickup  just come for the drinks and bar. cocktails so...
# 239  delivery, pickup  just come for the drinks and bar. cocktails so...
# 176  delivery, pickup  service and staff is a little disorganized but...
#
#      similarity                      id  num_id
# 370    0.586564  VVYea3NzbklOyHEzSEavWw     337
# 389    0.402536  QyB52nUrwJRY0ipuwcfR_A     356
# 411    0.339384  H26qMBb0OFNn2xmSTM1Phw     378
# 451    0.339384  H26qMBb0OFNn2xmSTM1Phw     378
# 301    0.233529  kTQ0rRfgtlPwX9_O8OY_UA     285
# 468    0.219248  MTtqSunPEZwdCJFMHsiHzg     420
# 325    0.201726  yZJbealagfujEkgesAl2hA     309
# 251    0.193727  U74_3F7r3tMhd6dmTmDBxQ     235
# 239    0.193727  U74_3F7r3tMhd6dmTmDBxQ     235
# 176    0.187998  m86CNmYThtzzWB3nPnrhbg     172

# %%
result = hybrid_recommender(0, 'burgers in nyc')
# result.head(10)
display('Personal recommendations: ', result.head(10))
# Out:
# Processed user feedback: burger nyc
# 'Personal recommendations: '
#                                     name  rating   location          price  \
# 370                    7th street burger       4   new york            low
# 265                                 aska       2   brooklyn  pricey-dining
# 468                             ai ki ya       3   new york            low
# 231                       bites of xi'an       3   new york            low
# 449                                leyla       4   new york            low
# 176                 emily - west village       5   new york            low
# 291         loreto italian kitchen & bar       1   brooklyn            low
# 471                           virginia's       5   new york            low
# 430                           virginia's       5   new york            low
# 208  luke's lobster brooklyn bridge park       4   brooklyn            low
#
#                    cuisine      transactions  \
# 370                burgers  pickup, delivery
# 265           scandinavian
# 468                  ramen  delivery, pickup
# 231                burgers  delivery, pickup
# 449                turkish  delivery, pickup
# 176                  pizza  delivery, pickup
# 291                lounges  delivery, pickup
# 471  american(traditional)
# 430  american(traditional)
# 208                seafood          delivery
#
#                                               comments  similarity  \
# 370  my brother claimed this the best burger of nyc...    0.586564
# 265  one of the best dining experiences of my life....    0.130766
# 468  good food! nice vibes! good service! one of my...    0.219248
# 231  amazing place, noodles are full of flavor and ...    0.101406
# 449  amazing atmosphere cute place with lots of dec...    0.129742
# 176  service and staff is a little disorganized but...    0.187998
# 291  the interior setting is nice. they aren't tryi...    0.167026
# 471  banana pudding and molten chocolate cake are t...    0.125225
# 430  banana pudding and molten chocolate cake are t...    0.125225
# 208  this was my third stop for a lobster role in n...    0.125276
#
#                          id  num_id       est
# 370  VVYea3NzbklOyHEzSEavWw     337  4.667439
# 265  UM3DuPsG6UKdmsC23O_Icw     249  4.662646
# 468  MTtqSunPEZwdCJFMHsiHzg     420  4.655588
# 231  --SoNTeCXFUx56no0OgibQ     227  4.597719
# 449  goKn7tKTIqpNPM_jR2yRCg     416  4.545970
# 176  m86CNmYThtzzWB3nPnrhbg     172  4.535106
# 291  wCj2FSi9o6iosMIMNIIZsA     275  4.503221
# 471  jlbtOUU-dmPwLwSYXal2oQ     397  4.476839
# 430  jlbtOUU-dmPwLwSYXal2oQ     397  4.476839
# 208  RrNe_0PReWHXAnjTEXBikQ     204  4.474511
