# %% [markdown]
# # **New york Recommendation System**

# %% [markdown]
# ##### **Group 1 (i.e. Foodies) members**:
# <ul type='square'>
#     <li> David Mwiti</li>
#     <li> Karen Amanya</li>
#     <li> Mercy Onduso </li>
#     <li> Nicholus Magak </li>
#     <li> Penina Wanyama </li>
#     <li> Stephen Thuo </li>
# </ul>

# %% [markdown]
# # Business Understanding

# %% [markdown]
# #### **Importing the required libraries**

# %%
import pandas as pd
import numpy as np
import string
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %config inlineBackend.figure_format = 'retina'
import seaborn as sns
sns.set_context('notebook')
from dataprep.clean import clean_country #pip install dataprep
import pycountry #conda install -c conda-forge pycountry
from surprise import Reader, Dataset, SVD, accuracy
from surprise.model_selection import cross_validate
from surprise.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### **Loading the data**

# %% [markdown]
# ##### _**1. restaurants_df**_

# %%
restaurant_df = pd.read_csv('restaurant_data.csv', encoding='utf-8', on_bad_lines='skip', low_memory=False)
restaurant_df.head()
# Out:
#               Name  Rating Pricing  \
# 0        Da Andrea       4      $$
# 1         LoveMama       5      $$
# 2  Ye's Apothecary       5     $$$
# 3   Joe's Shanghai       4      $$
# 4         Antidote       4      $$
#
#                                                  URL   Latitude  Longitude  \
# 0  https://www.yelp.com/biz/da-andrea-new-york?ad...  40.736218 -73.995970
# 1  https://www.yelp.com/biz/lovemama-new-york?adj...  40.730409 -73.986127
# 2  https://www.yelp.com/biz/yes-apothecary-new-yo...  40.719450 -73.989800
# 3  https://www.yelp.com/biz/joes-shanghai-new-yor...  40.715661 -73.996701
# 4  https://www.yelp.com/biz/antidote-brooklyn-2?a...  40.714253 -73.965448
#
#                                        Transactions  \
# 0  ['delivery', 'pickup', 'restaurant_reservation']
# 1  ['delivery', 'pickup', 'restaurant_reservation']
# 2                                                []
# 3                            ['delivery', 'pickup']
# 4                            ['delivery', 'pickup']
#
#                              Location         Phone   Display Phone  \
# 0    35 W 13th St, New York, NY 10011  1.212367e+10  (212) 367-1979
# 1     174 2nd Ave, New York, NY 10003  1.212255e+10  (212) 254-5370
# 2  119 Orchard St, New York, NY 10002           NaN             NaN
# 3    46 Bowery St, New York, NY 10013  1.212234e+10  (212) 233-8888
# 4     66 S 2nd St, Brooklyn, NY 11249  1.718782e+10  (718) 782-2585
#
#       Distance                                            Reviews  \
# 0  3526.365252  [{'text': 'This small and crowded place seems ...
# 1  2645.074283  [{'text': 'Absolutely LOVED LoveMama!! As a co...
# 2  1638.756115  [{'text': 'Edy and Josh are the BEST bartender...
# 3  1766.176007  [{'text': 'This is the third stop of our food ...
# 4  1376.494330  [{'text': 'Excellent service & food! The drink...
#
#    Review Count                                Cuisine  \
# 0             3                    I, t, a, l, i, a, n
# 1             3                             T, h, a, i
# 2             3                 S, z, e, c, h, u, a, n
# 3             3     S, h, a, n, g, h, a, i, n, e, s, e
# 4             3  C, o, c, k, t, a, i, l,  , B, a, r, s
#
#             Restaurant ID  Number of Reviews
# 0  hdiuRS9sVZSMReZm4oV5SA               1851
# 1  jjJc_CrkB2HodEinB6cWww               6377
# 2  8YWLuLUKj0t_0_Xv06UUtw                212
# 3  0CjK3esfpFcxIopebzjFxA               7098
# 4  4DInnPhOyvXFbYpUdO0SMQ                325

# %% [markdown]
# ##### _**2. users_df**_

# %%
user_revs_df = pd.read_csv('final_revs.csv', encoding='utf-8', on_bad_lines='skip', low_memory=False, header=None)
columns=['User_Name','Account','Location','Date_of_review','Rating','Comment','Restaurant_link']
user_revs_df.columns = columns
user_revs_df.head()
# Out:
#     User_Name                                      Account          Location  \
# 0  Richard D.  /user_details?userid=pRfWy61wU9e1nrCVrOEWLA      New York, NY
# 1    Elisa H.  /user_details?userid=ExhcUTTcj_MBhZdFQT9KYg      Brooklyn, NY
# 2  Morlene C.  /user_details?userid=VLTBPUrbNRR-f84h-altQw      Brooklyn, NY
# 3    Ruwan J.  /user_details?userid=xBVo8v0mw64nk6K-pYgI6A      New York, NY
# 4     Mike C.  /user_details?userid=37cpUoM8hlkSQfReIEBd-Q  Forest Hills, NY
#
#   Date_of_review  Rating                                            Comment  \
# 0      2/16/2023     4.0                                         No comment
# 1       1/6/2023     4.0                                         No comment
# 2     12/15/2022     3.0                                         No comment
# 3      3/23/2023     4.0  Urbanspace  Union Square is a newish addition-...
# 4     12/14/2022     5.0                                         No comment
#
#                                      Restaurant_link
# 0  https://www.yelp.com/biz/urbanspace-union-squa...
# 1  https://www.yelp.com/biz/urbanspace-union-squa...
# 2  https://www.yelp.com/biz/urbanspace-union-squa...
# 3  https://www.yelp.com/biz/urbanspace-union-squa...
# 4  https://www.yelp.com/biz/urbanspace-union-squa...

# %% [markdown]
# # Data Understanding

# %% [markdown]
# ##### _**1. restaurants_df**_

# %%
restaurant_df.info()

# Observations:
#   16 columns & 500 rows
#   It has some missing phone & display phone numbers
#   Missing quite a bit of data on the pricing section
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               500 non-null    object
#  1   Rating             500 non-null    int64
#  2   Pricing            315 non-null    object
#  3   URL                500 non-null    object
#  4   Latitude           500 non-null    float64
#  5   Longitude          500 non-null    float64
#  6   Transactions       500 non-null    object
#  7   Location           500 non-null    object
#  8   Phone              430 non-null    float64
#  9   Display Phone      430 non-null    object
#  10  Distance           500 non-null    float64
#  11  Reviews            500 non-null    object
#  12  Review Count       500 non-null    int64
#  13  Cuisine            500 non-null    object
#  14  Restaurant ID      500 non-null    object
#  15  Number of Reviews  500 non-null    int64
# dtypes: float64(4), int64(3), object(9)
# memory usage: 62.6+ KB

# %%
# Converting the cuisine text to a more human readable format
restaurant_df['Cuisine'] = restaurant_df['Cuisine'].map(lambda x: x.replace(',',''))

# %%
# viewing the types of cuisines 
set(restaurant_df['Cuisine'])
# Out:
# {'A m e r i c a n   ( N e w )',
#  'A m e r i c a n   ( T r a d i t i o n a l )',
#  'A r g e n t i n e',
#  'A s i a n   F u s i o n',
#  'A u s t r a l i a n',
#  'A u s t r i a n',
#  'B a g e l s',
#  'B a k e r i e s',
#  'B a r b e q u e',
#  'B a r s',
#  'B e l g i a n',
#  'B r a z i l i a n',
#  'B r e a k f a s t   &   B r u n c h',
#  'B u b b l e   T e a',
#  'B u f f e t s',
#  'B u r g e r s',
#  'B u r m e s e',
#  'C a f e s',
#  'C a j u n / C r e o l e',
#  'C a m b o d i a n',
#  'C a n t o n e s e',
#  'C a r i b b e a n',
#  'C h i c k e n   S h o p',
#  'C h i c k e n   W i n g s',
#  'C h i n e s e',
#  'C o c k t a i l   B a r s',
#  'C o f f e e   &   T e a',
#  'C o m f o r t   F o o d',
#  'C u b a n',
#  'D e l i s',
#  'D e s s e r t s',
#  'D i m   S u m',
#  'D i n e r s',
#  'F a s t   F o o d',
#  'F i l i p i n o',
#  'F o n d u e',
#  'F o o d   C o u r t',
#  'F r e n c h',
#  'G a s t r o p u b s',
#  'G e o r g i a n',
#  'G e r m a n',
#  'G r e e k',
#  'G r o c e r y',
#  'H i m a l a y a n / N e p a l e s e',
#  'H o t   D o g s',
#  'H o t   P o t',
#  'I n d i a n',
#  'I n d o n e s i a n',
#  'I t a l i a n',
#  'I z a k a y a',
#  'J a p a n e s e',
#  'J a p a n e s e   C u r r y',
#  'K o r e a n',
#  'L a t i n   A m e r i c a n',
#  'L e b a n e s e',
#  'L o u n g e s',
#  'M a l a y s i a n',
#  'M e d i t e r r a n e a n',
#  'M e x i c a n',
#  'M i d d l e   E a s t e r n',
#  'M o d e r n   E u r o p e a n',
#  'M o r o c c a n',
#  'N e w   M e x i c a n   C u i s i n e',
#  'N o o d l e s',
#  'P a n   A s i a n',
#  'P a t i s s e r i e / C a k e   S h o p',
#  'P e r s i a n / I r a n i a n',
#  'P e r u v i a n',
#  'P i z z a',
#  'P o r t u g u e s e',
#  'P u b s',
#  'R a m e n',
#  'S a n d w i c h e s',
#  'S c a n d i n a v i a n',
#  'S e a f o o d',
#  'S h a n g h a i n e s e',
#  'S o u l   F o o d',
#  'S o u t h e r n',
#  'S p a n i s h',
#  'S p e a k e a s i e s',
#  'S p e c i a l t y   F o o d',
#  'S t e a k h o u s e s',
#  'S u s h i   B a r s',
#  'S z e c h u a n',
#  'T a c o s',
#  'T a i w a n e s e',
#  'T a p a s   B a r s',
#  'T e a   R o o m s',
#  'T e p p a n y a k i',
#  'T h a i',
#  'T u r k i s h',
#  'V e g e t a r i a n',
#  'V e n e z u e l a n',
#  'V e n u e s   &   E v e n t   S p a c e s',
#  'V i e t n a m e s e',
#  'W i n e   B a r s'}

# %%
# viewing the number of unique restaurants
len(restaurant_df['Restaurant ID'].unique())
# Out:
# 435

# %%
# Types of transactions occuring in the restaurants
set(restaurant_df['Transactions'])
# Out:
# {"['delivery', 'pickup', 'restaurant_reservation']",
#  "['delivery', 'pickup']",
#  "['delivery']",
#  "['pickup', 'delivery', 'restaurant_reservation']",
#  "['pickup', 'delivery']",
#  "['pickup', 'restaurant_reservation', 'delivery']",
#  "['restaurant_reservation', 'delivery', 'pickup']",
#  "['restaurant_reservation', 'delivery']",
#  "['restaurant_reservation']",
#  '[]'}

# %%
# viewing the locations
set(restaurant_df['Location'])
# Out:
# {'1 Doyers St, New York, NY 10013',
#  '1 Greene Ave, Brooklyn, NY 11238',
#  '1 John St, Brooklyn, NY 11201',
#  '10 Columbus Cir, New York, NY 10019',
#  '10 Columbus Cir, Third Floor, New York, NY 10019',
#  '10 Hudson Yards, New York, NY 10001',
#  '100 Pearl St, New York, NY 10004',
#  '102 Lexington Ave, New York, NY 10016',
#  '102 Suffolk St, New York, NY 10002',
#  '1025 Manhattan Ave, Brooklyn, NY 11222',
#  '103 N 3rd St, New York, NY 11249',
#  '1035 Flushing Ave, Brooklyn, NY 11237',
#  '104 2nd Ave, New York, NY 10003',
#  '104 S 4th St, Brooklyn, NY 11249',
#  '105 N 6th St, Brooklyn, NY 11249',
#  '105 Wilson Ave, New York, NY 11237',
#  '1063 1st Ave, New York, NY 10022',
#  '108 E 4th St, New York, NY 10003',
#  '108 W 74th St, New York, NY 10023',
#  '109 N 3rd St, Brooklyn, NY 11249',
#  '109 St Marks Pl, New York, NY 10009',
#  '11 E 13th St, New York, NY 10003',
#  '11 E 30th St, New York, NY 10016',
#  '11 E 47th St, New York, NY 10017',
#  '11 Hanover Sq, New York, NY 10005',
#  '11 Mott St, New York, NY 10013',
#  '11 W 8th St, New York, NY 10011',
#  '11 Water St, Brooklyn, NY 11201',
#  '110 E 7th St, New York, NY 10009',
#  '110 Madison Ave, New York, NY 10016',
#  '112 Eldridge St, New York, NY 10002',
#  '115 Allen St, New York, NY 10002',
#  '115 Division St, New York, NY 10002',
#  '1158 Myrtle Ave, Brooklyn, NY 11221',
#  '116 Newark Ave, Jersey City, NJ 07302',
#  '117 Ferris St, Brooklyn, NY 11231',
#  '117 Second Ave, New York, NY 10003',
#  '118 Madison Ave, New York, NY 10016',
#  '118A Eldridge St, New York, NY 10002',
#  '119 1st Ave, New York, NY 10003',
#  '119 Kent Ave, Brooklyn, NY 11249',
#  '119 Orchard St, New York, NY 10002',
#  '119 Saint Marks Pl, New York, NY 10009',
#  '12 John Street, World Trade Center Stadium, New York, NY 10038',
#  '120 Saint Marks Pl, New York, NY 10009',
#  '121 Ludlow St, New York, NY 10002',
#  '124 E 14th St, New York, NY 10003',
#  '126 MacDougal St, New York, NY 10012',
#  '126 Union St, Brooklyn, NY 11231',
#  '128 Greenpoint Ave, Brooklyn, NY 11222',
#  '128 Macdougal St, New York, NY 10012',
#  '129 Mulberry St, New York, NY 10013',
#  '129 W 52nd St, New York, NY 10019',
#  '130 Division St, New York, NY 10002',
#  '131 Christopher St, New York, NY 10014',
#  '131A Orchard St, New York, NY 10002',
#  '132 4th Ave, New York, NY 10003',
#  '132 Bowery, New York, NY 10013',
#  '132 Franklin St, Brooklyn, NY 11222',
#  '132 Greene Ave, Brooklyn, NY 11238',
#  '132 W 47th St, New York, NY 10036',
#  '133 5th Ave, Brooklyn, NY 11217',
#  '133 Chrystie St, New York, NY 10002',
#  '134 Nevins St, Brooklyn, NY 11217',
#  '135 E 55th St, New York, NY 10022',
#  '136 Church St, New York, NY 10007',
#  '136 Mulberry St, New York, NY 10013',
#  '137 E 13th St, New York, NY 10003',
#  '137 Eldridge St, New York, NY 10002',
#  '138 Smith St, New York, NY 11201',
#  '139 W 28th St, New York, NY 10001',
#  '140 Schermerhorn St, Brooklyn, NY 11201',
#  '143 4th Ave, New York, NY 10003',
#  '143 Orchard St, New York, NY 10002',
#  '1439 2nd Ave, New York, NY 10021',
#  '144 2nd Ave, New York, NY 10003',
#  '145 Borinquen Pl, Brooklyn, NY 11211',
#  '146 Metropolitan Ave, Brooklyn, NY 11249',
#  '147 Front St, Brooklyn, NY 11201',
#  '149 W 14th St, New York, NY 10011',
#  '15 E 31st St, New York, NY 10016',
#  '15 MetroTech Ctr, Brooklyn, NY 11201',
#  '15 Union Square W, New York, NY 10003',
#  '150 Ainslie St, Brooklyn, NY 11211',
#  '150 E 14th St, New York, NY 10003',
#  '151 E Broadway, New York, NY 10002',
#  '151 Elizabeth St, New York, NY 10012',
#  '152 2nd Ave, Ste A, New York, NY 10003',
#  '152 Driggs Ave, Brooklyn, NY 11222',
#  '153 Rivington St, New York, NY 10002',
#  '156 10th Ave, New York, NY 10011',
#  '156 Knickerbocker Ave, New York, NY 11237',
#  '159 Central Ave, Brooklyn, NY 11221',
#  '16 E 46th St, New York, NY 10017',
#  '16 E 58th St, New York, NY 10022',
#  '16 W 29th St, New York, NY 10001',
#  '160 E 23rd St, New York, NY 10010',
#  '160 Franklin St, Brooklyn, NY 11222',
#  '164 Graham Ave, Brooklyn, NY 11206',
#  '165 Mulberry St, New York, NY 10013',
#  "166 Dekalb Ave, Walter's, Brooklyn, NY 11217",
#  '168 Borinquen Pl, Brooklyn, NY 11211',
#  '169 Sullivan St, New York, NY 10012',
#  '17 W 19th St, New York, NY 10011',
#  '170 S 3rd St, Brooklyn, NY 11211',
#  '170 Thompson St, New York, NY 10012',
#  '171 Avenue A, New York, NY 10009',
#  '171 E Broadway, New York, NY 10002',
#  '171 Grand St, Brooklyn, NY 11249',
#  '171 Lafayette Ave, Brooklyn, NY 11238',
#  '174 2nd Ave, New York, NY 10003',
#  '176 Bleecker St, New York, NY 10012',
#  '177 Henry St, New York, NY 10002',
#  '178 Broadway, Brooklyn, NY 11211',
#  '18 Bedford Ave, Brooklyn, NY 11222',
#  '182 Avenue B, New York, NY 10009',
#  '184 Kent Ave, Brooklyn, NY 11249',
#  '185 Atlantic Ave, Brooklyn, NY 11201',
#  '19 Old Fulton St, Brooklyn, NY 11201',
#  '192 Nassau Ave, Brooklyn, NY 11222',
#  '193 Bleecker St, New York, NY 10012',
#  '194 Grand St, New York, NY 10013',
#  '195 DeKalb Ave, Brooklyn, NY 11205, Brooklyn, NY 11205',
#  '195 Franklin St, Brooklyn, NY 11222',
#  '196 Spring St, New York, NY 10012',
#  '197 Meserole St, Brooklyn, NY 11206',
#  '2 Metrotech Ctr, Brooklyn, NY 11201',
#  '2 Renwick St, New York, NY 10013',
#  '20 Columbia Pl, Brooklyn, NY 11201',
#  '20 E 17th St, New York, NY 10003',
#  '20 Hudson Yards, New York, NY 10001',
#  '20 John St, New York, NY 10038',
#  '20 W 40th St, New York, NY 10018',
#  '200 5th Ave, New York, NY 10010',
#  '200 E 3rd St, New York, NY 10009',
#  '201 Lafayette St, New York, NY 10012',
#  '202 Ave A, New York, NY 10009',
#  '204 E 13th St, New York, NY 10003',
#  '205 E 4th St, New York, NY 10009',
#  '205 E Houston St, New York, NY 10002',
#  '205 W 57th St, New York, NY 10019',
#  '207 W 14th St, New York, NY 10011',
#  '208 Bedford Ave, New York, NY 11249',
#  '209 E 49th St, New York, NY 10017',
#  '209 Mulberry St, New York, NY 10012',
#  '209 N 8th St, Brooklyn, NY 11211',
#  '21 Ann St, New York, NY 10038',
#  '21 Greenpoint Ave, Brooklyn, NY 11222',
#  '21 Mott St, New York, NY 10013',
#  '21 Waverly Pl, New York, NY 10003',
#  '212 E 10th St, New York, NY 10003',
#  '212 Greene Ave, Brooklyn, NY 11238',
#  '213 Smith St, Brooklyn, NY 11201',
#  '215 Chrystie St, New York, NY 10002',
#  '216 7th Ave, New York, NY 10011',
#  '216 Smith St, Brooklyn, NY 11201',
#  '217 E 43rd St, Ste 1f, New York, NY 10017',
#  '218 E 9th St, New York, NY 10003',
#  '219 Dekalb Ave, Brooklyn, NY 11205',
#  '22 N Loop Rd, New York, NY 10044',
#  '22 Old Fulton St, Brooklyn, NY 11201',
#  '22 W 32nd St, Fl 2, New York, NY 10001',
#  '22 W 8th St, New York, NY 10011',
#  '220 West 44th St, New York, NY 10036',
#  '225-227 Front St, New York, NY 10038',
#  '226 Front St, New York, NY 10038',
#  '228 Smith St, Brooklyn, NY 11231',
#  '228 Thompson St, New York, NY 10012',
#  '229 E 9th St, New York, NY 10003',
#  '229 Front St, New York, NY 10038',
#  '229 W 43rd St, New York, NY 10036',
#  '23 Greenpoint Ave, Brooklyn, NY 11222',
#  '230 E 44th St, New York, NY 10017',
#  '230 E 9th St, Fl 2, New York, NY 10003',
#  '231 E 9th St, New York, NY 10003',
#  '231 Eldridge St, New York, NY 10002',
#  '231 Kent Ave, Brooklyn, NY 11249',
#  '233 West St, New York, NY 10013',
#  '236 E 13th St, New York, NY 10003',
#  '239 Centre St, New York, NY 10013',
#  '24 Greenwich Ave, New York, NY 10011',
#  '24-26 Erie st, Jersey City, NJ 07302',
#  '241 S 4th St, Brooklyn, NY 11211',
#  '244 Flatbush Ave, Brooklyn, NY 11217',
#  '244 Mulberry St, New York, NY 10012',
#  '248 Court St, Brooklyn, NY 11201',
#  '25 Bogart St, Brooklyn, NY 11206',
#  '25 Greenpoint Ave, Brooklyn, NY 11222',
#  '250 Dekalb Ave, Brooklyn, NY 11205',
#  '250 Vesey St, New York, NY 10281',
#  '251 Broome St, New York, NY 10002',
#  '251 Church St, New York, NY 10013',
#  '251 W 55th St, Fl 2, New York, NY 10019',
#  '251 West 50th St, New York, NY 10012',
#  '253 Grand St, Brooklyn, NY 11211',
#  '254 S 2nd St, Brooklyn, NY 11211',
#  '258 Wythe Ave, New York, NY 11249',
#  '26 S William St, New York, NY 10004',
#  '261 Moore St, Brooklyn, NY 11206',
#  '265 Canal St, New York, NY 10013',
#  '267 W 17th St, New York, NY 10011',
#  '27 Broadway, Brooklyn, NY 11249',
#  '27 Division St, New York, NY 10002',
#  '277 Smith St, Brooklyn, NY 11231',
#  '28 W 32nd St, Fl 2, New York, NY 10001',
#  '280 Ashland Pl, Brooklyn, NY 11217',
#  '281 Park Ave S 22nd St Entrance, Second Floor, New York, NY 10010',
#  '285 W 12th St, New York, NY 10014',
#  '29 Dunham Pl, Brooklyn, NY 11249',
#  '294 Livingston St, Brooklyn, NY 11217',
#  '295 3rd Ave, Brooklyn, NY 11215',
#  '295 Grand St, New York, NY 10002',
#  '3 Doyers St, New York, NY 10013',
#  '30 E 13th St, New York, NY 10003',
#  '31 W 52nd St, New York, NY 10019',
#  '311 Church St, New York, NY 10013',
#  '316 Court St, Brooklyn, NY 11231',
#  '318 Livingston St, Brooklyn, NY 11217',
#  '319 Kent Ave, Brooklyn, NY 11249',
#  '32 E 16th St, New York, NY 10003',
#  '320 Atlantic Ave, Brooklyn, NY 11201',
#  '320 E 6th St, New York, NY 10003',
#  '321 Nostrand Ave, Brooklyn, NY 11216',
#  '324 E 6th St, New York, NY 10003',
#  '324 Washington St, Hoboken, NJ 07030',
#  '326 E 6th St, New York, NY 10003',
#  '327 Gold St, Brooklyn, NY 11201',
#  '328 E 6th St, New York, NY 10003',
#  '33 Hudson Yards, Fl 24, New York, NY 10001',
#  '330 Myrtle Ave, Brooklyn, NY 11205',
#  '330 W Broadway, New York, NY 10013',
#  '333 Tompkins Ave, Brooklyn, NY 11216',
#  '334 W 46th St, New York, NY 10036',
#  '335 3rd Ave, New York, NY 10010',
#  '340 Lafayette St, New York, NY 10012',
#  '342 E 6th St, New York, NY 10003',
#  '342 Wythe Ave, New York, NY 11249',
#  '35 Downing St, New York, NY 10014',
#  '35 E 18th St, New York, NY 10003',
#  '35 W 13th St, New York, NY 10011',
#  '35 W 19th St, New York, NY 10011',
#  '35 W 35th St, New York, NY 10001',
#  '351 E 12th St, New York, NY 10003',
#  '352 W 39th St, New York, NY 10018',
#  '353 Bedford Ave, Brooklyn, NY 11211',
#  '358 W 46th St, New York, NY 10036',
#  '36 E 22nd St, New York, NY 10010',
#  '362 2nd Ave, New York, NY 10010',
#  '363 3rd Ave, New York, NY 10016',
#  '365 Van Brunt St, Brooklyn, NY 11231',
#  '369 5th Ave, Brooklyn, NY 11215',
#  '370 Lexington Ave, New York, NY 10017',
#  '372 Fulton St, Brooklyn, NY 11201',
#  '372 Myrtle Ave, Brooklyn, NY 11205',
#  '377 Greenwich St, New York, NY 10013',
#  '378 Park Ave S, New York, NY 10010',
#  '380 Van Brunt St, Brooklyn, NY 11231',
#  '387 Myrtle Ave, Brooklyn, NY 11205',
#  '39-04 64th St, New York, NY 11377',
#  '39-06 64th St, Woodside, NY 11377',
#  '398 Manhattan Ave, Brooklyn, NY 11211',
#  '4 W 22nd St, New York, NY 10010',
#  '40 Kenmare St, New York, NY 10012',
#  '40 W 56th St, New York, NY 10019',
#  '40 Water St, Brooklyn, NY 11201',
#  '400 Kent Ave, Brooklyn, NY 11211',
#  '400A W 50th St, New York, NY 10019',
#  '401 E 13th St, New York, NY 10009',
#  '404 W 49th, New York, NY 10019',
#  '407 Smith St, Brooklyn, NY 11231',
#  '408 Broome St, New York, NY 10013',
#  '409 Eastern Pkwy, New York, NY 11216',
#  '40A 10th Ave, New York, NY 10014',
#  '41 W 24th St, New York, NY 10010',
#  '41 W 33rd St, New York, NY 10001',
#  '412 Fifth Ave, Brooklyn, NY 11215',
#  '413 E 12th St, New York, NY 10009',
#  '415 Tompkins Ave, Brooklyn, NY 11216',
#  '419 Putnam Ave, Brooklyn, NY 11216',
#  '42 E 20th St, New York, NY 10003',
#  '420 Kent Ave, Brooklyn, NY 11249',
#  '429 Greenwich St, New York, NY 10013',
#  '43 Carmine St, New York, NY 10014',
#  '43 W 32nd St, New York, NY 10001',
#  '435 W 15th St, New York, NY 10011',
#  '44-14 48th Ave, Sunnyside, NY 11377',
#  '445 Albee Sq W, Dekalb Market Hall, Brooklyn, NY 11201',
#  '447 Rogers Ave, Prospect Lefferts Gardens, Brooklyn, NY 11225',
#  '449 Nostrand Ave, Brooklyn, NY 11216',
#  '45 W 45th St between 5th & 6th Ave, New York, NY 10036',
#  '450 W 33rd St, Whole Foods, New York, NY 10001',
#  '452 Washington St, New York, NY 10013',
#  '454 Van Brunt St, Brooklyn, NY 11231',
#  '455 7th Ave, Brooklyn, NY 11215',
#  '457 3rd Ave, Brooklyn, NY 11215',
#  '458 Myrtle Ave, Brooklyn, NY 11205',
#  '46 Bowery St, New York, NY 10013',
#  '46 Norman Ave, Brooklyn, NY 11222',
#  '462 Court St, Brooklyn, NY 11231',
#  '47 Java St, Brooklyn, NY 11222',
#  '47 Prince St, New York, NY 10012',
#  '47 South 5th St, Brooklyn, NY 11249',
#  '47-15 Northern Blvd, Queens, NY 11101',
#  '470 6th Ave, New York, NY 10011',
#  '472 Myrtle Ave, Brooklyn, NY 11205',
#  '483 10th Ave, New York, NY 10018',
#  '485 7th Ave, New York, NY 10018',
#  '4906 Vernon Blvd, Long Island City, NY 11101',
#  '496 9th Ave, New York, NY 10018',
#  '499 Myrtle Ave, Brooklyn, NY 11205',
#  '5 Ave A, New York, NY 10009',
#  '5 Bleecker St, New York, NY 10012',
#  '5 E 48th St, Manhattan, NY 10017',
#  '5 Greene Ave, Brooklyn, NY 11238',
#  '5 St Marks Pl, New York, NY 10003',
#  '5 West 31st St, New York, NY 10001',
#  '50 Bowery, New York, NY 10013',
#  '50 Henry St, Brooklyn, NY 11201',
#  '500 Prospect Pl, Brooklyn, NY 11238',
#  '507 East 6th St, New York, NY 10009',
#  '509 Amsterdam Ave, New York, NY 10024',
#  '509 Myrtle Ave, Brooklyn, NY 11205',
#  '519 Metropolitan Ave, Brooklyn, NY 11211',
#  '51B Canal St, New York, NY 10002',
#  '520 Hudson St, New York, NY 10014',
#  '521 Court St, Brooklyn, NY 11231',
#  '525 Hudson St, New York, NY 10014',
#  '53 Irving Pl, New York, NY 10003',
#  '531 Myrtle Ave, Brooklyn, NY 11205',
#  '55 Prospect St, Brooklyn, NY 11201',
#  '55 W 35th St, New York, NY 10001',
#  '55 Water St, Brooklyn, NY 11201',
#  '55-33 Myrtle Ave, Ridgewood, NY 11385',
#  '550 Court St, Brooklyn, NY 11231',
#  '562 Grand St, Fl 1, Brooklyn, NY 11211',
#  '57 Clinton St, New York, NY 10002',
#  '572 Fulton St, Brooklyn, NY 11217',
#  '58 E 1st St, New York, NY 10003',
#  '58 Henry St, New York, NY 10002',
#  '581 Vanderbilt Ave, Brooklyn, NY 11238',
#  '59 2nd Ave, New York, NY 10003',
#  '60 E 54th St, New York, NY 10022',
#  '60 Greenpoint Ave, Brooklyn, NY 11222',
#  '60 Henry St, Brooklyn, NY 11201',
#  '601 W 26th St, New York, NY 10001',
#  '605 3rd Ave, New York, NY 10158',
#  '610 5th Ave, New York, NY 10020',
#  '611 Hudson St, New York, NY 10014',
#  '617 Grand St, Brooklyn, NY 11211',
#  '626 Vanderbilt Ave, Brooklyn, NY 11238',
#  '627 E 6th St, New York, NY 10009',
#  '627 Vanderbilt Ave, Brooklyn, NY 11238',
#  '63 Carmine St, New York, NY 10014',
#  '63 Delancey St, New York, NY 10002',
#  '630 Hudson St, New York, NY 10014',
#  '635 2nd Ave, New York, NY 10016',
#  '650 W 42nd St, New York, NY 10036',
#  '659 Vanderbilt Ave, Brooklyn, NY 11238',
#  '66 Charlton St, New York, NY 10014',
#  '66 Hicks St, Brooklyn, NY 11201',
#  '66 S 2nd St, Brooklyn, NY 11249',
#  '67 Murray St, New York, NY 10007',
#  '68 Clinton St, New York, NY 10002',
#  '7 E 48th St, between Fifth and Madison avenues, New York, NY 10017',
#  '70 Forsyth St, New York, NY 10002',
#  '70 Grand St, Brooklyn, NY 11249',
#  '70 Greenpoint Ave, Brooklyn, NY 11222',
#  '70 Hudson Ave, Brooklyn, NY 11201',
#  '701 9th Ave, New York, NY 10019',
#  '71 Clark St, Brooklyn, NY 11201',
#  '71 Pineapple St, Brooklyn, NY 11201',
#  '72 Henry St, Brooklyn, NY 11201',
#  '724 Sterling Pl, Brooklyn, NY 11216',
#  '74 Bleecker St, New York, NY 10012',
#  '746 10th Ave, Fl 1, New York, NY 10019',
#  '749 9th Ave, New York, NY 10019',
#  '75 9th Ave, New York, NY 10011',
#  '76 Henry St, Brooklyn, NY 11201',
#  '77 Warren St, New York, NY 10007',
#  '773 Fulton St, Brooklyn, NY 11217',
#  '783 9th Ave, New York, NY 10019',
#  '788 Franklin Ave, Brooklyn, NY 11238',
#  '79 Chrystie St, New York, NY 10002',
#  '79 Grand St, Brooklyn, NY 11249',
#  '79 Orchard St, New York, NY 10002',
#  '791 Washington Ave, Brooklyn, NY 11238',
#  '80 Clark St, Brooklyn, NY 11201',
#  '80 Montague St, Brooklyn, NY 11201',
#  '81 Broadway, Brooklyn, NY 11249',
#  '81 Division St, New York, NY 10002',
#  '817 Washington St, New York, NY 10014',
#  '82 W 3rd St, New York, NY 10012',
#  '82 Washington Ave, Brooklyn, NY 11205',
#  '833 Dekalb Ave, New York, NY 11221',
#  '84 E 10th St, New York, NY 10003',
#  '84 Stanton St, New York, NY 10002',
#  '85 10th Ave, New York, NY 10011',
#  '85 Bergen St, Brooklyn, NY 11201',
#  '85 Broadway, Brooklyn, NY 11249',
#  '86 S Portland Ave, Brooklyn, NY 11217',
#  '87 South St, New York, NY 10038',
#  '88 E Broadway, Unit 106, Located Outside on Forsyth Street, New York, NY 10002',
#  '88 Reade St, New York, NY 10013',
#  '88 Wall St, New York, NY 10005',
#  '89 E 4th St, New York, NY 10003',
#  '89 South St, Pier 16, New York, NY 10038',
#  '89 South St, Pier 17, New York, NY 10038',
#  '9 Crosby St, NOMO SOHO Hotel, New York, NY 10013',
#  '9 E 37th St, New York, NY 10016',
#  '9 Maiden Ln, New York, NY 10038',
#  '90 Bowery, New York, NY 10013',
#  '90 Clinton St, New York, NY 10002',
#  '90 Washington St, New York, NY 10006',
#  '905 Lorimer St, Brooklyn, NY 11222',
#  '91 Bayard St, New York, NY 10013',
#  '91 S 6th St, Brooklyn, NY 11249',
#  '94 Ave C, New York, NY 10009',
#  '95 1st Ave, New York, NY 10003',
#  '954 Manhattan Ave, Brooklyn, NY 11222',
#  '956 2nd Ave, New York, NY 10022',
#  '96 Orchard St, New York, NY 10002',
#  '96 South St, New York, NY 10038',
#  '98 Mott St, Ste 3, New York, NY 10013',
#  '990 Broadway, Brooklyn, NY 11221',
#  '999 Manhattan Ave, Brooklyn, NY 11222',
#  'New York, NY 10007',
#  'Pier 6 Brooklyn Bridge Park, Brooklyn Bridge Park, Brooklyn, NY 11201',
#  'Pier 81, W 41 St & 12th Ave, New York, NY 10036',
#  'Queens, NY 11104',
#  'Smith Street & Pacific Street, Brooklyn, NY 11201',
#  'W 26th St, Hudson River Park, New York, NY 10010'}

# %%
# viewing the rating scale of the restaurants
set(restaurant_df['Rating'])
# Out:
# {1, 2, 3, 4, 5}

# %%
fig, ax = plt.subplots(figsize=(11,8))
sns.histplot(restaurant_df['Rating'], bins = np.arange(8) - 0.5, color='teal', ax=ax)
ax.set_xticks(range(1,6))
ax.set_xlabel('Ratings')
ax.set_ylabel('Number of Restaurants')
ax.set_title('Restaurant Ratings');

rating_count = restaurant_df['Rating'].value_counts().sort_index()
for i, val in enumerate(rating_count.values):
    ax.text(i+1, val+5, (f'{round((val/sum(rating_count.values))*100, 1)}%'), ha='center', va='bottom',size=12)  
    
    # Observations:
    # The book rating ranges from 0 to 10
    # Most books have a rating of 0
    # The ratings between 1-4 have very few books

# %% [markdown]
# ##### _**2. users_df**_

# %%
user_revs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76395 entries, 0 to 76394
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User_Name        76395 non-null  object
#  1   Account          76395 non-null  object
#  2   Location         76395 non-null  object
#  3   Date_of_review   76395 non-null  object
#  4   Rating           76395 non-null  float64
#  5   Comment          76395 non-null  object
#  6   Restaurant_link  76395 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 4.1+ MB

# %%
# Checking how many unique users rated
len(user_revs_df['Account'].unique())
# Out:
# 53724

# %%
user_revs_df.describe()
# Out:
#              Rating
# count  76395.000000
# mean       4.136959
# std        1.124592
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
# List of locations to users majority
list_of_locs = set(user_revs_df['Location'])
dic_loc = {}

for location in list_of_locs:
    num = len(user_revs_df[user_revs_df['Location'] == location])
    dic_loc[location] = num
dic_loc
# Out:
# {'St Charles, MO': 1,
#  'Arcadia, CA': 35,
#  'Hadley, MA': 1,
#  'Shelton, CT': 10,
#  'Gravesend, NY': 6,
#  'Oxford, MS': 1,
#  'Holland, MI': 1,
#  'Palm Beach, FL': 3,
#  'San Antonio, TX': 91,
#  'Guam, Guam': 1,
#  'Saint Helena, CA': 4,
#  'ROOSEVELT ISL, NY': 1,
#  'Hyde Park, Austin, TX': 1,
#  'Tomball, TX': 2,
#  'Douglasville, GA': 5,
#  'West Chester Township, OH': 2,
#  'Woodridge, IL': 4,
#  'Millbrook, NY': 1,
#  'Jamaica Hills, Queens, NY': 2,
#  'Oak Park, IL': 3,
#  'Santa Barbara, CA': 33,
#  'Lithia Springs, GA': 2,
#  'Delano, CA': 1,
#  'Pittsford, NY': 2,
#  'Babylon, NY': 5,
#  'Montreal, Canada': 33,
#  'Charleston, SC': 23,
#  'Morton, PA': 2,
#  'Galivants Ferry, SC': 1,
#  'Annandale, VA': 22,
#  'Old Town, Tallahassee, FL': 1,
#  'Edenwald, Bronx, NY': 2,
#  'Orange City, FL': 1,
#  'Old Bridge, Old Bridge Township, NJ': 2,
#  'Bayside, NY': 52,
#  'Hamburg, Germany': 5,
#  'Orland Park, IL': 2,
#  'Enfield, London, United Kingdom': 1,
#  'Seminole, FL': 1,
#  'Clearwater, FL': 14,
#  'Zhonghe District, Taiwan': 1,
#  'Tracy, CA': 6,
#  'Tonkawa, OK': 1,
#  'Buffalo, NY': 81,
#  'Palais Royal/Musée du Louvre, Paris, France': 1,
#  'East Moriches, NY': 6,
#  'Lodi, NJ': 8,
#  'Morristown, NJ': 52,
#  'Bar Harbor, ME': 1,
#  'Nolita, Manhattan, NY': 8,
#  'Yokosuka, Japan': 1,
#  'Portola, CA': 2,
#  'Port Moody, Canada': 2,
#  'Riverdale, NJ': 2,
#  'Pasay City, Manila, Philippines': 1,
#  'University Hills, Denver, CO': 1,
#  'Cypress Hills, Brooklyn, NY': 6,
#  'Denville, NJ': 7,
#  'Rochester, VT': 1,
#  'Houston, PA': 2,
#  'Mount Sinai, NY': 1,
#  'Oak Cliff, Dallas, TX': 1,
#  'Panama City, FL': 1,
#  'Voorhees Township, NJ': 3,
#  'Litchfield County, CT': 1,
#  'Seaford, MD': 1,
#  'Boulder City, NV': 1,
#  'Wilton, CT': 11,
#  'Center City, Philadelphia, PA': 3,
#  'Sheffield Lake, OH': 1,
#  'GA, GA': 22,
#  'Addison, TX': 2,
#  'Cape Canaveral, FL': 1,
#  'Parkland, FL': 1,
#  'Lower East Side, Manhattan, NY': 27,
#  'Spring Lake, MI': 1,
#  'Franklin Square, NY': 16,
#  'Tappan, NY': 5,
#  'Ferndale, NY': 2,
#  'Gladstone Central, Australia': 1,
#  'La Puente, CA': 7,
#  'Willow Glen, San Jose, CA': 1,
#  'Rumford, East Providence, RI': 1,
#  'Pasadena, Los Angeles, CA': 4,
#  'Kansas City, KS': 2,
#  'Port Arthur, TX': 4,
#  'Braintree, MA': 3,
#  'McLeansville, NC': 1,
#  'Garwood, NJ': 2,
#  'South End, Boston, MA': 4,
#  'Brooklyn, NY': 9368,
#  'Kutzky Park, Rochester, MN': 2,
#  'Komaba, Meguro-ku, Japan': 2,
#  'Central Business District, Newark, NJ': 1,
#  'Downtown Flushing, Queens, NY': 9,
#  'Williamsport, PA': 1,
#  'Rahway, NJ': 25,
#  'North Brunswick Township, NJ': 14,
#  'Mt Tremper, NY': 1,
#  'Westmoreland, NY': 1,
#  'Marine Park, NY': 2,
#  'SeaTac, WA': 3,
#  'Hackensack River Waterfront, Jersey City, NJ': 1,
#  'Atwater Village, Los Angeles, CA': 1,
#  'South Plainfield, NJ': 10,
#  'Columbia Heights, Washington, DC': 6,
#  'Laketon Heights, Pittsburgh, PA': 1,
#  'Hillburn, NY': 1,
#  'Belmont, Bronx, NY': 2,
#  'Cornwall, NY': 1,
#  'Redondo Beach, CA': 28,
#  'East Bay, CA': 8,
#  'Grand Central Station, NY': 1,
#  'Beverly, MA': 4,
#  'Brea, CA': 18,
#  'MONTE VISTA, CA': 2,
#  'Alcântara, Lisbon, Portugal': 1,
#  'Carmichael, CA': 1,
#  'Sunrise, FL': 5,
#  'JACKSON HTS, NY': 9,
#  'Fifth Avenue, Gainesville, FL': 1,
#  'Laredo, TX': 1,
#  'Shilin District, Taiwan': 1,
#  'Brookline, MA': 28,
#  'Marlton, NJ': 4,
#  'Morris Plains, NJ': 7,
#  'Gastonia, NC': 1,
#  'Cuyahoga Falls, OH': 1,
#  'Fort Mitchell, KY': 2,
#  'Bluff Park, Long Beach, CA': 1,
#  'Gowanus, Brooklyn, NY': 4,
#  'McLean, VA': 24,
#  'Georgetown, Brooklyn, NY': 5,
#  'Crown Heights, New York, NY': 7,
#  'Custer, WA': 1,
#  'Brazos, Waco, TX': 1,
#  'Drexel Hill, PA': 1,
#  'FAR ROCKAWAY, NY': 2,
#  'Balderrama, Hermosillo, Mexico': 1,
#  'Londonderry, NH': 1,
#  'Auburn, WA': 3,
#  'Elizabeth, Charlotte, NC': 1,
#  'Sebastopol, CA': 3,
#  'Orange, CA': 38,
#  'Kew Gardens, NY': 11,
#  'Essex Junction, VT': 2,
#  'Bernards, NJ': 5,
#  'Northridge, CA': 1,
#  'Bedford Stuyvesant, Brooklyn, NY': 36,
#  'Nuuanu - Punchbowl, Honolulu, HI': 1,
#  'Columbia, NJ': 1,
#  'Mount Pleasant, SC': 7,
#  'Stone Ridge, NY': 2,
#  'East New York, NY': 15,
#  'Northwest, Las Vegas, NV': 1,
#  'Polaris North, Columbus, OH': 1,
#  'Lancaster, OH': 1,
#  'Hialeah, FL': 13,
#  'Hempstead, NY': 26,
#  'North Vancouver, Canada': 1,
#  'Murray Hill, Queens, NY': 5,
#  'Clarksburg, WV': 1,
#  'Guilderland, NY': 1,
#  'Clementon, NJ': 1,
#  'San Marcos, CA': 11,
#  'Graniteville, NY': 2,
#  'Fort White, FL': 1,
#  'Milton, DE': 1,
#  'National City, CA': 2,
#  'Hyattsville, MD': 5,
#  'Queen Village, Philadelphia, PA': 1,
#  'Essex, CT': 1,
#  'El Centro, CA': 2,
#  'The Colony, TX': 4,
#  'Bloomington, IN': 11,
#  'Mahwah, NJ': 7,
#  'Center Valley, PA': 1,
#  'Charlottesville, VA': 36,
#  'Rex Manor, Mountain View, CA': 1,
#  'Woonsocket, RI': 3,
#  'MD, MD': 15,
#  'North Potomac, MD': 8,
#  'Marina Del Rey, CA': 1,
#  'Wilmington, MA': 1,
#  'North Strathfield, Australia': 1,
#  'Lincoln, NE': 5,
#  'West New York, NJ': 36,
#  'Bay Ridge, NY': 5,
#  'Healdsburg, CA': 1,
#  'Clark, CO': 1,
#  'The Bronx, New York, NY': 4,
#  'Oakland Gardens, NY': 34,
#  'Mount Laurel, NJ': 6,
#  'Green Cove Springs, FL': 1,
#  'Maryville, IL': 1,
#  'Uniontown, OH': 2,
#  'Coronado, CA': 6,
#  'Lacey, WA': 1,
#  'Harrisville, UT': 1,
#  'Belltown, Seattle, WA': 2,
#  'Catlett, VA': 1,
#  'Lubbock, TX': 3,
#  'Bridgeport, Chicago, IL': 2,
#  'Stoughton, MA': 4,
#  'Gotha, FL': 1,
#  'Cheviot Hills, Los Angeles, CA': 1,
#  'ブルックリン, NY': 2,
#  'Dusseldorf, Germany': 1,
#  'Rolling Hills, CA': 1,
#  'UC Campus Area, Berkeley, CA': 2,
#  'Scranton, PA': 4,
#  'South of Market, San Francisco, CA': 1,
#  'Enterprise, AL': 1,
#  'Bluffton, SC': 3,
#  'Trenton, NJ': 4,
#  'Flint, TX': 3,
#  'Hyde Park, Tampa, FL': 1,
#  'Desert Hot Springs, CA': 1,
#  'Hammonton, NJ': 2,
#  'Alpine, NJ': 1,
#  'San Fernando, CA': 8,
#  'Pooler, GA': 4,
#  'Geneva, NY': 2,
#  'East Syracuse, NY': 3,
#  'Fenway, Boston, MA': 3,
#  'Petaluma, CA': 3,
#  'Malmø, Sweden': 1,
#  'Saltillo, MS': 1,
#  'Gt Lon, United Kingdom': 1,
#  'Coopersburg, PA': 1,
#  'Webster, TX': 6,
#  'San Andreas, CA': 1,
#  'Bel Air, MD': 2,
#  'Edgewater, MD': 1,
#  'Potrero Hill, San Francisco, CA': 1,
#  'Frenchtown, NJ': 3,
#  'Bonita, CA': 3,
#  'Berkley, MI': 1,
#  'Beach Haven, NJ': 2,
#  'Gansevoort, NY': 3,
#  'Bellmawr, NJ': 1,
#  '皇后區, 皇后區, NY': 1,
#  'Port St Lucie, FL': 2,
#  'Sonoma, CA': 3,
#  'Covington, KY': 1,
#  'Valley Stream, NY': 80,
#  'Gautier, MS': 1,
#  'North Bellmore, NY': 2,
#  'Temescal, Oakland, CA': 2,
#  'Moscow, ID': 2,
#  'Hempstead, TX': 1,
#  'Clementi, Singapore, Singapore': 1,
#  'Bezirk Mitte, Berlin, Germany': 1,
#  'Pineville, NC': 5,
#  'Wilsonville, OR': 1,
#  'Wixom, MI': 1,
#  'Narragansett, RI': 6,
#  'Milpitas, CA': 24,
#  'Watertown, MA': 10,
#  'SoMa, San Francisco, CA': 47,
#  'Mørkøv, Denmark': 3,
#  'University of Texas, Austin, TX': 2,
#  'Old Greenwich, Greenwich, CT': 1,
#  'Aliso Viejo, CA': 15,
#  'Duarte, CA': 1,
#  'Westmount, Canada': 2,
#  'Hamilton, OH': 2,
#  'Union Square, Manhattan, NY': 18,
#  'Hollywood, FL': 34,
#  'Parkrose, Portland, OR': 1,
#  'West Hills, CA': 1,
#  'San Marino, CA': 13,
#  'South Hampton Roads, VA': 1,
#  'Pottstown, PA': 2,
#  'Rye Brook, NY': 3,
#  'Holt, MI': 1,
#  'Beltsville, MD': 4,
#  'Winnetka, Los Angeles, CA': 2,
#  'Uniontown, PA': 1,
#  'La Jolla, CA': 18,
#  'Rumford, RI': 1,
#  'Santa Rosa Beach, FL': 2,
#  'Palisades Park, NJ': 44,
#  'Marlow, OK': 1,
#  'Wrightsville Beach, NC': 1,
#  'Chevy Chase Village, MD': 1,
#  'Haidhausen, Munich, Germany': 1,
#  'Elizabethport, NJ': 4,
#  'Fairbanks, AK': 1,
#  'Greenwood, NY': 2,
#  'Menlo Park, CA': 35,
#  'Easton, MD': 2,
#  'Armour Square, Chicago, IL': 2,
#  'Nipomo, CA': 1,
#  'Old Saybrook, CT': 2,
#  'MASPETH, NY': 12,
#  'Hicksville, NY': 17,
#  'Tarrytown, NY': 10,
#  'Pacific, Stockton, CA': 1,
#  'Dallas Downtown Historic District, Dallas, TX': 1,
#  'Farmington, MI': 1,
#  'Park Slope, Brooklyn, NY': 32,
#  'San Pedro, Los Angeles, CA': 1,
#  'Yaphank, NY': 2,
#  'Point Pleasant, NJ': 1,
#  'Granada Hills, CA': 4,
#  'Indian River, Chesapeake, VA': 1,
#  'Safety Harbor, FL': 1,
#  'Troy, NY': 6,
#  'Royal Palm Beach, FL': 2,
#  'Burdett, NY': 1,
#  'Southeast Washington, Washington, DC': 4,
#  'San Pedro Garza García, Mexico': 1,
#  'LaGuardia Airport, New York, NY': 2,
#  'Chamonix-Mont-Blanc, France': 1,
#  'Newtown Square, PA': 2,
#  'FRESH MEADOWS, NY': 14,
#  'New Brunswick, NJ': 48,
#  'Henderson, NV': 13,
#  'Riverfront, Wilmington, DE': 2,
#  "Hell's Kitchen, Manhattan, NY": 26,
#  'Nichols Hills, OK': 1,
#  'Clinton Hill, Brooklyn, NY': 34,
#  'Riverside Rancho, Glendale, CA': 1,
#  'East Side, Bridgeport, CT': 2,
#  'Cedar Rapids, IA': 6,
#  'Ambler, PA': 3,
#  'Paterson, NJ': 14,
#  'Smithfield, NC': 1,
#  'Bland, VA': 1,
#  'Istanbul, Turkey': 7,
#  'Fenway/Kenmore, Boston, MA': 5,
#  'East Hill-Meridian, WA': 1,
#  'Granville, OH': 1,
#  'Bensalem, PA': 4,
#  'Mackinaw City, MI': 1,
#  'West Homestead, PA': 1,
#  'Venetia, PA': 1,
#  'Derwood, MD': 1,
#  'Canton, OH': 7,
#  'Mount Juliet, TN': 1,
#  'East Greenwich, RI': 3,
#  'Kips Bay, Manhattan, NY': 9,
#  'Fordham Manor, NY': 1,
#  'Wilbraham, MA': 2,
#  'Ritzville, WA': 1,
#  'Fairhope, AL': 1,
#  "Quartu Sant'Elena, Italy": 1,
#  'Totowa, NJ': 1,
#  'Hyde Park, Chicago, IL': 1,
#  'Coraopolis, PA': 2,
#  'Cape Girardeau, MO': 1,
#  'East Lansing, MI': 5,
#  'San Marcos, TX': 2,
#  'Alameda, CA': 40,
#  'Lenox, MA': 2,
#  'Sterling, VA': 13,
#  'Manchester, Richmond, VA': 1,
#  'Springfield Gardens, Queens, NY': 3,
#  'Forney, TX': 2,
#  'Thomasville, GA': 1,
#  'Wayne, MI': 1,
#  'Madison, Nashville, TN': 1,
#  'Chatsworth, Los Angeles, CA': 1,
#  'Nazareth, PA': 1,
#  'FOREST HILLS, NY': 50,
#  'Kreis 1, Zürich, Switzerland': 1,
#  'Johns Creek, GA': 2,
#  'Malverne, NY': 6,
#  'Pensacola, FL': 8,
#  'Tampa, FL': 123,
#  'Astoria, New York, NY': 16,
#  'Asbury, NJ': 2,
#  'Ankeny, IA': 2,
#  'Ocean View, NJ': 1,
#  'New Orleans, LA': 88,
#  'Woodway, TX': 2,
#  'College Park, MD': 6,
#  'Richfield, OH': 2,
#  'San Fernando Valley, CA': 18,
#  'Redmond, WA': 9,
#  'Palm Harbor, Tampa Bay, FL': 1,
#  'West Nyack, NY': 3,
#  'Downtown, Pittsburgh, PA': 3,
#  'Gaffney, SC': 2,
#  'Bozeman, MT': 8,
#  'Tynemouth, United Kingdom': 1,
#  'Narberth, PA': 3,
#  'Missoula, MT': 1,
#  'Eastchester, NY': 3,
#  'Little Silver, NJ': 1,
#  'Flemington, NJ': 8,
#  'Beach Barber Tract, San Diego, CA': 1,
#  'Agat, Guam': 1,
#  'Archer Heights, Chicago, IL': 1,
#  'Kenwood, CA': 1,
#  'Mohegan Lake, NY': 1,
#  'El Camino Real, Irvine, CA': 1,
#  'Rimini, Italy': 1,
#  'Grand River, East Lansing, MI': 2,
#  'Suffolk, VA': 2,
#  'South Miami, FL': 2,
#  'VA, VA': 20,
#  'La Mirada, CA': 4,
#  'Independence, KS': 1,
#  'Richmond Hill, GA': 2,
#  'Saint Amant, LA': 2,
#  'Double Oak, TX': 4,
#  'Beaufort, SC': 3,
#  'Bumpass, VA': 1,
#  'Fair Haven, NJ': 2,
#  'Opelika, AL': 1,
#  'Mission Viejo, CA': 13,
#  'Newark, NJ': 119,
#  'Joplin, MO': 1,
#  'Boonton Township, NJ': 2,
#  'San Juan, Puerto Rico': 18,
#  'Wildomar, CA': 1,
#  'Orange, CT': 1,
#  'San Ysidro, San Diego, CA': 1,
#  'Maplewood, NJ': 19,
#  'Daytona Beach, FL': 2,
#  'Southwest, Minneapolis, MN': 2,
#  'North Dallas, Richardson, TX': 1,
#  'Walden, NY': 2,
#  'Henrico, VA': 5,
#  'Castaic, CA': 2,
#  'Goose Creek, SC': 1,
#  'Highlands/Perkins, Baton Rouge, LA': 2,
#  'North Brookline, Brookline, MA': 2,
#  'Farmington, UT': 2,
#  'Vicksburg, MS': 1,
#  'Farmington, NY': 1,
#  'Westerly, RI': 3,
#  'Pratt, NY': 1,
#  'Amarillo, TX': 1,
#  'Daly City, CA': 25,
#  'Horseheads, NY': 1,
#  'Oak Hill, Austin, TX': 1,
#  'Brooklyn, Brooklyn, NY': 1003,
#  'Farmingville, NY': 1,
#  'Park City, UT': 3,
#  'Manassas, VA': 5,
#  'Bernardsville, NJ': 1,
#  'Tysons, VA': 7,
#  'Beachwood, NJ': 1,
#  'Midwood, New York, NY': 3,
#  'Manchester, MD': 1,
#  'Sheepshead Bay, NY': 6,
#  'Kyle, TX': 2,
#  'Riverdale, Bronx, NY': 11,
#  'Oxnard, CA': 10,
#  'Smithfield, VA': 1,
#  'Le Plateau-Mont-Royal, Montreal, Canada': 1,
#  'Hesperia, CA': 5,
#  'Dauphin Island, AL': 2,
#  'The Village, Jersey City, NJ': 1,
#  'Colton, CA': 3,
#  'West Glen, Coral Springs, FL': 1,
#  'Urbana, IL': 8,
#  'Madison, CT': 4,
#  'Adelphi, MD': 1,
#  'Fontana, CA': 9,
#  'Edelweiss, College Station, TX': 1,
#  'Windsor Terrace, Brooklyn, NY': 4,
#  'Fort Walton Beach, FL': 1,
#  'Downtown Miami, Miami, FL': 3,
#  'Westwood, NJ': 10,
#  'Sandy Springs, GA': 4,
#  'Nice, France': 1,
#  'Middlebury, VT': 2,
#  'Murrysville, PA': 1,
#  'Settsu, Japan': 1,
#  'North Springfield, VA': 4,
#  'Point Pleasant Beach, NJ': 2,
#  'Queen Creek, AZ': 13,
#  'Borough Park, Brooklyn, NY': 12,
#  'Barcelona, Spain': 17,
#  'Plymouth, MN': 2,
#  'Glen Mills, PA': 2,
#  'Gillett, PA': 1,
#  'Mount Arlington, NJ': 1,
#  'South San Francisco, CA': 25,
#  'Seaside Park, NJ': 1,
#  'South Belt/Ellington, Houston, TX': 2,
#  'Franklin, MA': 2,
#  'Ramona, CA': 1,
#  'Balboa Peninsula, Newport Beach, CA': 1,
#  'Hazelhurst, WI': 1,
#  'REGO PARK, NY': 8,
#  'Gibsonia, PA': 3,
#  'Greenwood Village, CO': 3,
#  'Westfield, MA': 2,
#  'Enfield, United Kingdom': 1,
#  'Boonsboro, MD': 1,
#  'Carnot-Moon, Moon, PA': 1,
#  'Oswego, NY': 2,
#  'Sherman, TX': 1,
#  'Urban Honolulu, HI': 12,
#  'Anniston, AL': 1,
#  'Auburn, AL': 2,
#  'Marina del Rey, CA': 19,
#  'Portola Valley, CA': 1,
#  'Union Beach, NJ': 1,
#  'Rye, NY': 12,
#  'Pomonok, Queens, NY': 1,
#  'Stillwater, MN': 1,
#  'The Rocks, Australia': 1,
#  'Huntsville, AL': 6,
#  'Liberty Corner, Basking Ridge, NJ': 1,
#  'St James, NY': 1,
#  'Maple City, MI': 1,
#  'Centennial Park District, Atlanta, GA': 1,
#  'Staten Island, Staten Island, NY': 76,
#  'Lexington, MA': 2,
#  'Brookeville, MD': 1,
#  'Exeter, NH': 2,
#  'Haledon, NJ': 6,
#  'Williams, AZ': 2,
#  'Holliswood, Queens, NY': 1,
#  'Longfellow, Iowa City, IA': 1,
#  'Centerville, Fremont, CA': 1,
#  'Somers, NY': 5,
#  'Addisleigh Park, NY': 5,
#  'The Pocket-Greenhaven, Sacramento, CA': 1,
#  'Fairfield, OH': 2,
#  'Lenoir City, TN': 1,
#  'Altamonte Springs, FL': 7,
#  'Del Mar, CA': 1,
#  'Lost Hills, CA': 3,
#  'Jeffries Point, Boston, MA': 2,
#  'Panama City Beach, FL': 2,
#  'Dr. Phillips, Orlando, FL': 1,
#  'Carson City, NV': 2,
#  'Newland, NC': 1,
#  'Oostende, Belgium': 1,
#  'Parlin, Sayreville, NJ': 1,
#  'Old Lyme, CT': 1,
#  'West Loop, Chicago, IL': 3,
#  'Greater East End, Houston, TX': 1,
#  'Fayetteville, GA': 1,
#  'Saint Augustine, FL': 1,
#  'Uptown, Dallas, TX': 3,
#  'Massapequa Park, NY': 7,
#  'Rockland County, NY': 2,
#  'Knightdale, NC': 2,
#  'Quantico, VA': 1,
#  'Hilton, NY': 1,
#  'Jacksonville, AL': 2,
#  'Villa del Puente, Ciudad de México, Mexico': 1,
#  'Keller, TX': 8,
#  'HI, HI': 5,
#  'Wynwood, Miami, FL': 1,
#  'South Boston, Boston, MA': 1,
#  'New Braunfels, TX': 2,
#  'Essex, NJ': 2,
#  'North Ironbound, Newark, NJ': 1,
#  'Cedarburg, WI': 1,
#  'Media, PA': 4,
#  'Warwick, NY': 4,
#  'Old Fourth Ward, Atlanta, GA': 1,
#  'Zephyr Cove, NV': 1,
#  'Pulheim, Germany': 1,
#  'Delaware, OH': 2,
#  'Griswold, CT': 1,
#  'Guilford, CT': 4,
#  'Flatlands, NY': 2,
#  'Merrick, NY': 23,
#  'Ardsley, NY': 6,
#  'North Andover, MA': 2,
#  'Hamilton, Canada': 4,
#  'Nantes, France': 1,
#  'Altadena, CA': 8,
#  'NJ, NJ': 69,
#  'Tottenville, Staten Island, NY': 1,
#  'Wollongong, Australia': 1,
#  'Vernon Township, NJ': 2,
#  'Saugerties, NY': 1,
#  'Clinton, TN': 1,
#  'West Roxbury, Boston, MA': 2,
#  'Olathe, KS': 7,
#  'Stoughton, WI': 1,
#  'Salem, VA': 1,
#  'Beverly Hills, CA': 51,
#  'South Village, Manhattan, NY': 3,
#  'Grandview, Glendale, CA': 1,
#  'Battery Park, Manhattan, NY': 6,
#  'Storrs, Mansfield, CT': 1,
#  'St Albans, VT': 1,
#  'Murfreesboro, TN': 6,
#  'College Point, NY': 2,
#  'Northeast Orlando, Orlando, FL': 1,
#  'Landing, Landing, NJ': 1,
#  'Town of North Hempstead, Long Island, NY': 5,
#  'Gainesville, VA': 5,
#  'East New York, Brooklyn, NY': 2,
#  'New Castle, NH': 1,
#  'Foxboro, MA': 1,
#  'East Village, Manhattan, NY': 30,
#  'Walnut Park, Los Angeles, CA': 1,
#  'Loosdrecht, The Netherlands': 1,
#  'Hopkins, MN': 2,
#  'San Jacinto, CA': 2,
#  'Salford, United Kingdom': 1,
#  'Swarthmore, PA': 2,
#  'Royal Oak, MI': 6,
#  'Long Beach, NY': 26,
#  'Quebec City, Canada': 1,
#  'Haltom City, TX': 1,
#  'Portsmouth, VA': 2,
#  'Las Cruces, NM': 1,
#  'Temple, PA': 2,
#  'Chino, CA': 10,
#  'Mission Hills, CA': 1,
#  'Reno, NV': 29,
#  'New Providence, NJ': 7,
#  'Amsterdam, The Netherlands': 9,
#  'Quezon City, Philippines': 1,
#  'Port Tobacco, MD': 1,
#  'Naperville, IL': 16,
#  'North Highlands, CA': 1,
#  'Port Orange, FL': 1,
#  'Plantersville, TX': 1,
#  'Germantown, MD': 8,
#  'Kona, HI': 2,
#  'Coquina Cove, Port Orange, FL': 1,
#  'Quickborn, Germany': 1,
#  'Quogue, NY': 1,
#  'Monroe, NY': 5,
#  'Cedar Grove, NJ': 1,
#  'Clairemont, San Diego, CA': 3,
#  'Downtown, Honolulu, HI': 1,
#  'San Francisco Peninsula, CA': 2,
#  'Bellerose, NY': 14,
#  'Polk City, FL': 2,
#  'Hendersonville, TN': 1,
#  'South Side, Waltham, MA': 1,
#  'Granby, CO': 1,
#  'Brockton, MA': 3,
#  'MARTINS ADD, MD': 2,
#  'Brawley, CA': 1,
#  'Northeast Dallas, Dallas, TX': 1,
#  'Suncrest, Orem, UT': 1,
#  'Needham, MA': 5,
#  'Boise, ID': 11,
#  'LOEHMANNS PLZ, NY': 1,
#  'Westminster, CO': 6,
#  'Mohnton, PA': 1,
#  'Montrose, Houston, TX': 1,
#  'Manteca, CA': 3,
#  'Chinatown, Philadelphia, PA': 4,
#  'Akron, IN': 1,
#  '堅尼地城, Hong Kong': 1,
#  'Upper East Side, Manhattan, NY': 60,
#  'Zona Hotelera, Cancún, Mexico': 2,
#  'Carpinteria, CA': 2,
#  'Monmouth, IL': 1,
#  'White House, TN': 1,
#  'Waltham, MA': 21,
#  'Washington, DC': 606,
#  'Montauk, NY': 1,
#  'Logan Square, Philadelphia, PA': 2,
#  'Sunset Beach, NC': 1,
#  'Moultonborough, NH': 1,
#  'Harvard, MA': 1,
#  'Mountain Top, PA': 2,
#  'Aptos, CA': 1,
#  'Concourse Village, Bronx, NY': 5,
#  'Sanford, ME': 1,
#  'West Milford, NJ': 3,
#  'Pelham, AL': 1,
#  'Bethel, PA': 1,
#  'Glastonbury Center, Glastonbury, CT': 1,
#  'KY, KY': 2,
#  'Downtown Crossing, Boston, MA': 1,
#  'Irvine Business Complex, Santa Ana, CA': 1,
#  'Tucson, AZ': 26,
#  'Southeast Edmonton, Edmonton, Canada': 1,
#  'Canaan, NY': 2,
#  'Clawson, MI': 1,
#  'Fife, WA': 2,
#  'Tinley Park, IL': 1,
#  'Lombard, IL': 1,
#  'Fan District, Richmond, VA': 1,
#  'Troutdale, OR': 1,
#  'Far Hills, NJ': 1,
#  'Baton Rouge, LA': 19,
#  'Wiesbaden, Germany': 1,
#  'Lower Moreland Township, PA': 1,
#  'Chandler, OK': 1,
#  'Laguna Niguel, CA': 7,
#  'Prospect, KY': 2,
#  'Eagan, MN': 1,
#  'Avenel, NJ': 4,
#  'Glen Rock, NJ': 4,
#  'Holualoa, HI': 2,
#  'Moraga, CA': 8,
#  'Milford Mill, MD': 1,
#  'Union Township, NJ': 5,
#  'Asbury Park, NJ': 10,
#  'Topanga, CA': 1,
#  'North Hollywood, CA': 7,
#  'Windermere, Orlando, FL': 2,
#  'Juneau, AK': 4,
#  'Kensington, Melbourne, Australia': 1,
#  'Waxhaw, NC': 2,
#  'New Bedford, MA': 3,
#  'Chandler, AZ': 16,
#  'Ada, MI': 2,
#  'Bend, OR': 2,
#  'Fulton, GA': 2,
#  'Wolfeboro, NH': 1,
#  'East Hyde Park, Chicago, IL': 2,
#  'Tustin Legacy, Tustin, CA': 1,
#  'McKinney, TX': 9,
#  'West McLean, VA': 1,
#  'Foothill Ranch, CA': 2,
#  'Lee, NH': 1,
#  'Ridgewood, Queens, NY': 20,
#  'Sachse, TX': 2,
#  'South Austin, Austin, TX': 2,
#  'Simi Valley, CA': 9,
#  'Lower East Side, New York, NY': 73,
#  'Elm Park, NY': 1,
#  'United Kingdom': 1,
#  'Amherst, NH': 1,
#  'Altstadt-Lehel, Munich, Germany': 1,
#  'Lancaster, PA': 9,
#  'Riviera, Cancún, Mexico': 1,
#  'South, Denver, CO': 1,
#  'KNICKERBOCKER, NY': 64,
#  'Flatbush, New York, NY': 14,
#  'East Liberty, Pittsburgh, PA': 1,
#  'Guelph, Canada': 2,
#  'North Park, Chicago, IL': 1,
#  'New Haven, IN': 1,
#  'Cambria Heights, NY': 5,
#  'Winnetka, CA': 1,
#  'Boerum Hill, Brooklyn, NY': 10,
#  'Wyckoff, NJ': 6,
#  'City Heights, San Diego, CA': 1,
#  'Greenvale, NY': 1,
#  'Bluebonnet Hills, Fort Worth, TX': 2,
#  'Crofton, MD': 2,
#  'Leander, TX': 3,
#  'Scarsdale, NY': 39,
#  'Santa Clarita, CA': 9,
#  'Solana Beach, CA': 3,
#  'St. Augustine, FL': 2,
#  'Yerba Buena, San Francisco, CA': 1,
#  'Folsom, CA': 5,
#  'Pike Place Market, Seattle, WA': 2,
#  'Sherman, CT': 1,
#  'Middletown, DE': 2,
#  'East Hartford, CT': 2,
#  'Boulder, CO': 37,
#  'Swedesboro, NJ': 1,
#  'Dresher, PA': 1,
#  'Texas City, TX': 2,
#  'MONTGMRY, IL': 1,
#  'Stockholms län, Sweden': 2,
#  'Jefferson Square, Omaha, NE': 2,
#  'Hicksville, Hicksville, NY': 1,
#  'Belford, NJ': 1,
#  'Cologne, Germany': 2,
#  'Green Brook, NJ': 1,
#  'New Windsor, NY': 6,
#  'Brewster, MA': 2,
#  'Seven Trees, San Jose, CA': 1,
#  'Capitol Hill, Seattle, WA': 5,
#  'Short Hills, NJ': 6,
#  'Cockeysville, MD': 1,
#  'Pompton Plains, Pequannock Township, NJ': 1,
#  'Northern, VA': 1,
#  'Sammamish, WA': 5,
#  'San Dimas, CA': 1,
#  'Haddon Heights, NJ': 1,
#  'Spring Valley, Las Vegas, NV': 1,
#  'Bala Cynwyd, PA': 1,
#  'East Providence, RI': 2,
#  'East County Civic Group, Valrico, FL': 1,
#  'Centennial, Las Vegas, NV': 1,
#  'MT, MT': 1,
#  'Humble, TX': 4,
#  'East Nashville, Nashville, TN': 3,
#  'Southside, Fort Worth, TX': 1,
#  'Doylestown, PA': 4,
#  'Miamisburg, OH': 3,
#  'Norman, OK': 4,
#  'Owego, NY': 1,
#  'UT, UT': 2,
#  'Appleton, WI': 1,
#  'Oakland, CA': 192,
#  'Anaheim Colony Historic District, Anaheim, CA': 1,
#  'Lansdowne, PA': 3,
#  'Maple Glen, PA': 1,
#  'Fort Greene, Brooklyn, NY': 21,
#  'Wynnewood, PA': 5,
#  'Barrington, IL': 3,
#  'Sun Valley, ID': 1,
#  'Winnipeg, Canada': 2,
#  'Milton, FL': 1,
#  'Sea Cliff, NY': 1,
#  'Edison, NJ': 48,
#  'Montgomery County, PA': 1,
#  'QUEENS VILLAGE, NY': 6,
#  'Lake Grove, NY': 3,
#  'Old Bridge, NJ': 6,
#  'Washington, PA': 1,
#  'Acton, MA': 3,
#  'Koreatown, Los Angeles, CA': 2,
#  'Naples, Italy': 2,
#  'Trumbull, CT': 4,
#  'Kimberly, AL': 1,
#  'Belmont, NC': 3,
#  'Franklin, NJ': 1,
#  'Sanatoga, PA': 1,
#  'Medfield, MA': 2,
#  'Brockton Village, Toronto, Canada': 1,
#  'Soundview, Bronx, NY': 1,
#  'Elkhorn, NE': 2,
#  'La Cañada Flintridge, CA': 2,
#  'Mitchellville, MD': 1,
#  'Jersey, Jersey': 10,
#  'Mount Hamilton, CA': 1,
#  'Miller Place, NY': 2,
#  'Arlington, TN': 1,
#  'Clermont, FL': 9,
#  'Coney Island, Brooklyn, NY': 2,
#  'Grafton, MA': 3,
#  'Chippewa Falls, WI': 1,
#  'Würzburg, Germany': 1,
#  'Castellaneta, Italy': 1,
#  'Midtown East, New York, NY': 86,
#  'Suwanee, GA': 11,
#  '新莊區, Taiwan': 1,
#  'Southfield, MI': 4,
#  'Schenectady, NY': 11,
#  'Ballwin, MO': 2,
#  'La Crescenta, CA': 2,
#  'Memphis, TN': 17,
#  'Shelby Charter Township, MI': 1,
#  'Everett, MA': 5,
#  'Rockville, MD': 66,
#  'Schaumburg, IL': 4,
#  'University Place, WA': 2,
#  'Ship Bottom, NJ': 1,
#  'Howard Beach, Queens, NY': 4,
#  'Stamford, CT': 64,
#  'Downtown, Stamford, CT': 1,
#  'Newbury Park, CA': 1,
#  'Princeton Meadows, NJ': 1,
#  'Logan, Philadelphia, PA': 3,
#  'Prospect Heights, IL': 3,
#  'Astoria Heights, Queens, NY': 1,
#  'Bedford, NY': 1,
#  'TX, TX': 28,
#  'American Fork, UT': 2,
#  'Rancho Mirage, CA': 3,
#  'Amherst, MA': 11,
#  'Freehold, NJ': 13,
#  'Rogers Park, Chicago, IL': 1,
#  'Liberty Station, San Diego, CA': 2,
#  'Pauma Valley, CA': 1,
#  'Kearneysville, WV': 1,
#  'Charleston, NY': 1,
#  'Midwood, NY': 3,
#  'Redwood Oaks, Redwood City, CA': 1,
#  'Utopia, Queens, NY': 2,
#  'Braintree Town, MA': 1,
#  'Belmont, MA': 4,
#  'Monroe Township, NJ': 11,
#  'Deerfield, IL': 3,
#  'Middle River, MD': 2,
#  'Alpharetta, GA': 17,
#  'Des Peres, MO': 2,
#  'Newton, NJ': 5,
#  'Loranger, LA': 1,
#  'Cookeville, TN': 1,
#  'Town of Oyster Bay, Long Island, NY': 3,
#  'Starin Central, Buffalo, NY': 2,
#  'Lake Oswego, OR': 1,
#  'México, D.F., Mexico': 4,
#  'Atascadero, CA': 2,
#  "Da'an District, Taiwan": 1,
#  'Flatbush, Brooklyn, NY': 20,
#  'North Dallas, Dallas, TX': 2,
#  'Town of Haddam, CT': 1,
#  'AZ, AZ': 6,
#  'Port Crane, NY': 1,
#  'Meatpacking District, Manhattan, NY': 2,
#  'Northeast Seattle, Seattle, WA': 2,
#  'Kinnelon, NJ': 1,
#  'Vinegar Hill, Brooklyn, NY': 1,
#  'Huntington, NY': 28,
#  'Uniondale, NY': 10,
#  'Northeast Philadelphia, PA': 1,
#  'Downtown, Sacramento, CA': 3,
#  'Cuesta Park, Mountain View, CA': 1,
#  'JFK Airport, Queens, NY': 1,
#  'Winnetka, IL': 1,
#  'Westbury, NY': 35,
#  'Davie, FL': 9,
#  'Columbia, MO': 6,
#  'High Bridge, NJ': 8,
#  'Oakville, Canada': 7,
#  'Avondale, LA': 1,
#  'Alexandria, LA': 2,
#  'Palo Alto, CA': 90,
#  'Etna, CA': 1,
#  'Astrodome, Houston, TX': 1,
#  'Millington, TN': 1,
#  'Lake Hiawatha, NJ': 2,
#  'Sunset Park, Brooklyn, NY': 7,
#  'Alexandria, IN': 1,
#  'Stanton, CA': 6,
#  'Warrington, PA': 1,
#  'Commerce, GA': 1,
#  'Lakewood Ranch, FL': 1,
#  'Randall Manor, Staten Island, NY': 2,
#  'Mar Vista, Los Angeles, CA': 1,
#  'Warwick, RI': 2,
#  'Wakefield, MA': 1,
#  'Gulfton, Houston, TX': 1,
#  'Wrentham, MA': 1,
#  'Staten Island, New York, NY': 5,
#  'Bonita Springs, FL': 2,
#  'Downtown Berkeley, Berkeley, CA': 3,
#  'Sarnia, Canada': 1,
#  'Harleysville, PA': 5,
#  'St. Augustine Beach, FL': 1,
#  'Nashua, NH': 2,
#  'Chatham Township, NJ': 4,
#  'Fort Mill, SC': 4,
#  'Fords, Woodbridge Township, NJ': 1,
#  'Alta, UT': 1,
#  'Battery Park, New York, NY': 2,
#  'Downtown, Nashville, TN': 2,
#  'Wahiawā, HI': 1,
#  'Five Points South, Birmingham, AL': 1,
#  'Irmo, SC': 1,
#  'Niagara Falls, NY': 2,
#  'Distrito Central de Bayamón, Bayamón, Puerto Rico': 1,
#  'White Plains, MD': 2,
#  'Norwood, NJ': 6,
#  'Quakertown, PA': 2,
#  'Chattahoochee River': 4,
#  'Katy, TX': 24,
#  'Canberra, Australia': 2,
#  'Lafayette, CO': 2,
#  'Bartonsville, Pocono Township, PA': 2,
#  'West Cambridge, Cambridge, MA': 1,
#  'Thunder Bay, Canada': 1,
#  'Aberdeen Township, NJ': 3,
#  'Oceanside, CA': 16,
#  'Lake Tekapo, New Zealand': 1,
#  'New London, CT': 3,
#  'East Orlando, Alafaya, FL': 1,
#  'Long Island City, New York, NY': 34,
#  'Griffith Park/Los Feliz, Los Angeles, CA': 2,
#  'Mount Holly, NJ': 3,
#  'Litchfield, ME': 1,
#  'Marblehead, MA': 2,
#  'Northeast Bellevue, Bellevue, WA': 1,
#  'Upper Clinton Hill, Newark, NJ': 2,
#  'Concord, CA': 12,
#  'WI, WI': 4,
#  'Vashon, WA': 1,
#  'Southeast Yonkers, Yonkers, NY': 2,
#  'Whitewater, CA': 1,
#  'Whitesboro, NY': 1,
#  'Ventura, CA': 10,
#  'Phoenix, OR': 1,
#  'Toluca Lake, Los Angeles, CA': 1,
#  'Canandaigua, NY': 1,
#  'Oradell, NJ': 10,
#  'Pelham, NH': 1,
#  'Dix Hills, NY': 6,
#  'Highland Lakes, NJ': 1,
#  'Bordentown, NJ': 1,
#  'West Brighton, NY': 2,
#  'Fort Thomas, KY': 1,
#  'Glencairn, Houston, TX': 1,
#  'Sierra Vista, AZ': 3,
#  'Twentynine Palms, CA': 2,
#  'Bellmore, NY': 19,
#  'North Central, San Antonio, TX': 1,
#  'North Haven, CT': 7,
#  'Ewing Township, NJ': 2,
#  'Commack, NY': 12,
#  'Delavan, WI': 1,
#  'バークリー, CA': 1,
#  'River North, Chicago, IL': 3,
#  'Oceanport, NJ': 1,
#  'Kendale Lakes, FL': 2,
#  'Setagaya, Japan': 3,
#  'Drexel Hill, Drexel Hill, PA': 1,
#  'Palm Harbor, FL': 8,
#  'Vicenza, Italy': 1,
#  'Bixby, OK': 2,
#  ...}

# %% [markdown]
# **Checking for the trend in book production over time**

# %%
dic_years = {}
for years in user_revs_df['Date_of_review']:
    if int(years[-4:]) in dic_years.keys():
        dic_years[int(years[-4:])] += 1
    else:
        dic_years[int(years[-4:])] = 1
dic_years
# Out:
# {2023: 3729,
#  2022: 12099,
#  2021: 7889,
#  2020: 4872,
#  2019: 9509,
#  2018: 7827,
#  2016: 5221,
#  2017: 6326,
#  2015: 4904,
#  2014: 3659,
#  2013: 2666,
#  2011: 2127,
#  2012: 2236,
#  2010: 1439,
#  2008: 570,
#  2009: 901,
#  2007: 277,
#  2005: 20,
#  2006: 124}

# %%
# years and books made
myKeys = list(dic_years.keys())
myKeys.sort()

X = myKeys
y = []
for i in myKeys:
    y.append(dic_years[i]) 

year_plot = pd.DataFrame()
year_plot['years'] = X
year_plot['numbers'] = y

plt.figure(figsize=(10, 6))
ax = sns.lineplot(x='years', y='numbers', data=year_plot, color='teal')

ax.set(xlabel='Years', ylabel='Number of users', 
       title='Users\' rating growth in years')
plt.show()
# Observations:
    # Most books in the dataset were published from 1950 to 202

# %% [markdown]
# * make sure we only get businesses that already show up in our review list and delete the rest.
# * This step is necessary to ensure that the final dataset only contains restaurants that have been reviewed by users in the user_rev_df dataset. Removing restaurants that have not been reviewed by any users will help improve the accuracy of the recommender system by only recommending relevant items to users based on their past behavior. Additionally, it can help reduce computational complexity by reducing the number of items that need to be considered in the recommendation process.

# %%
filtered_restaurant_df = restaurant_df[restaurant_df['URL'].isin(user_revs_df['Restaurant_link'].unique())]
len(filtered_restaurant_df)
# Out:
# 152

# %%
filtered_restaurant_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152 entries, 0 to 497
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               152 non-null    object
#  1   Rating             152 non-null    int64
#  2   Pricing            110 non-null    object
#  3   URL                152 non-null    object
#  4   Latitude           152 non-null    float64
#  5   Longitude          152 non-null    float64
#  6   Transactions       152 non-null    object
#  7   Location           152 non-null    object
#  8   Phone              136 non-null    float64
#  9   Display Phone      136 non-null    object
#  10  Distance           152 non-null    float64
#  11  Reviews            152 non-null    object
#  12  Review Count       152 non-null    int64
#  13  Cuisine            152 non-null    object
#  14  Restaurant ID      152 non-null    object
#  15  Number of Reviews  152 non-null    int64
# dtypes: float64(4), int64(3), object(9)
# memory usage: 20.2+ KB

# %% [markdown]
# ### Missing Values

# %% [markdown]
# * Pricing is an important feature that affects a customer's decision to dine in a restaurant. Since only a small percentage of the restaurants have missing pricing data (42 out of 152), we can afford to drop those rows without significantly impacting the size or representativeness of our dataset. Additionally, since we don't have any reliable way of imputing the missing values, dropping those rows is a reasonable choice.

# %%
filtered_restaurant_df.dropna(subset=['Pricing'], inplace=True)

# %%
# Replace missing values in Phone column with NaN
filtered_restaurant_df['Phone'] = filtered_restaurant_df['Phone'].replace({np.nan: 'NaN'})

# Drop Display Phone column
filtered_restaurant_df = filtered_restaurant_df.drop(columns=['Display Phone'])

# %% [markdown]
# * For the Phone column, replacing missing values with NaN allows us to retain the information for restaurants that do not have a phone number listed, while still being able to perform analysis on the available phone numbers for the other restaurants.
# * The Display Phone column is redundant as it contains the same information as the Phone column. Dropping this column helps to simplify the dataframe and reduce unnecessary duplication of data.

# %%
filtered_restaurant_df
# Out:
#                     Name  Rating Pricing  \
# 0              Da Andrea       4      $$
# 1               LoveMama       5      $$
# 3         Joe's Shanghai       4      $$
# 4               Antidote       4      $$
# 5                   Raku       4      $$
# ..                   ...     ...     ...
# 488           Little Mad       3    $$$$
# 490  Steak Frites Bistro       4     $$$
# 494          Bowery Road       3     $$$
# 495          ABC Kitchen       5     $$$
# 497           Luchadores       5      $$
#
#                                                    URL   Latitude  Longitude  \
# 0    https://www.yelp.com/biz/da-andrea-new-york?ad...  40.736218 -73.995970
# 1    https://www.yelp.com/biz/lovemama-new-york?adj...  40.730409 -73.986127
# 3    https://www.yelp.com/biz/joes-shanghai-new-yor...  40.715661 -73.996701
# 4    https://www.yelp.com/biz/antidote-brooklyn-2?a...  40.714253 -73.965448
# 5    https://www.yelp.com/biz/raku-new-york-7?adjus...  40.726499 -73.986653
# ..                                                 ...        ...        ...
# 488  https://www.yelp.com/biz/little-mad-new-york-2...  40.745020 -73.985130
# 490  https://www.yelp.com/biz/steak-frites-bistro-n...  40.755591 -73.994449
# 494  https://www.yelp.com/biz/bowery-road-new-york-...  40.733343 -73.990192
# 495  https://www.yelp.com/biz/abc-kitchen-new-york?...  40.737750 -73.989634
# 497  https://www.yelp.com/biz/luchadores-new-york?a...  40.705820 -74.004110
#
#                                          Transactions  \
# 0    ['delivery', 'pickup', 'restaurant_reservation']
# 1    ['delivery', 'pickup', 'restaurant_reservation']
# 3                              ['delivery', 'pickup']
# 4                              ['delivery', 'pickup']
# 5                              ['delivery', 'pickup']
# ..                                                ...
# 488                                                []
# 490                                                []
# 494                            ['delivery', 'pickup']
# 495                                      ['delivery']
# 497                            ['delivery', 'pickup']
#
#                                 Location          Phone     Distance  \
# 0       35 W 13th St, New York, NY 10011  12123671979.0  3526.365252
# 1        174 2nd Ave, New York, NY 10003  12122545370.0  2645.074283
# 3       46 Bowery St, New York, NY 10013  12122338888.0  1766.176007
# 4        66 S 2nd St, Brooklyn, NY 11249  17187822585.0  1376.494330
# 5       342 E 6th St, New York, NY 10003  12122281324.0  2236.683282
# ..                                   ...            ...          ...
# 488  110 Madison Ave, New York, NY 10016  19172614969.0  4231.367528
# 490      496 9th Ave, New York, NY 10018  19296145070.0  5530.277285
# 494      132 4th Ave, New York, NY 10003  12124321324.0  3052.241537
# 495     35 E 18th St, New York, NY 10003  12124755829.0  3508.876621
# 497      87 South St, New York, NY 10038  19174093033.0  2132.580935
#
#                                                Reviews  Review Count  \
# 0    [{'text': 'This small and crowded place seems ...             3
# 1    [{'text': 'Absolutely LOVED LoveMama!! As a co...             3
# 3    [{'text': 'This is the third stop of our food ...             3
# 4    [{'text': 'Excellent service & food! The drink...             3
# 5    [{'text': 'Delicious food, there are heaters f...             3
# ..                                                 ...           ...
# 488  [{'text': 'I went for my birthday. It took a w...             3
# 490  [{'text': 'Fantastic food and service. Great s...             3
# 494  [{'text': 'Great spot in a fantastic location ...             3
# 495  [{'text': 'Came in shortly after 12:30pm for a...             3
# 497  [{'text': "It's gotten super popular over the ...             3
#
#                                  Cuisine           Restaurant ID  \
# 0                          I t a l i a n  hdiuRS9sVZSMReZm4oV5SA
# 1                                T h a i  jjJc_CrkB2HodEinB6cWww
# 3                S h a n g h a i n e s e  0CjK3esfpFcxIopebzjFxA
# 4              C o c k t a i l   B a r s  4DInnPhOyvXFbYpUdO0SMQ
# 5                        J a p a n e s e  FlZ1zdVEKWv7dwqm8Uw8-w
# ..                                   ...                     ...
# 488          A m e r i c a n   ( N e w )  SmLFW1Ncg26KfVRVX3GVFQ
# 490                S t e a k h o u s e s  V3dHB6xAdd8_dH7t481PAw
# 494          A m e r i c a n   ( N e w )  FJepPR5CYRggxRwAjlqg6A
# 495  B r e a k f a s t   &   B r u n c h  dMhRafXdr765DHe0k-QfaQ
# 497                        M e x i c a n  8_NilECM6qg_L7WYb25uNw
#
#      Number of Reviews
# 0                 1851
# 1                 6377
# 3                 7098
# 4                  325
# 5                 1497
# ..                 ...
# 488                166
# 490                 51
# 494                252
# 495               3165
# 497                130
#
# [110 rows x 15 columns]

# %%
import pandas as pd

filtered_restaurant_df['Comments'] = ''

# loop through each row in the original dataframe
for index, row in filtered_restaurant_df.iterrows():
    # reviews = row['Reviews']
    url = row['URL']
    reviews = []
    holder = user_revs_df.loc[user_revs_df['Restaurant_link'] == url].iterrows()
    for row in holder:
        comment = row[1]['Comment']
        if comment != 'No comment':
            reviews.append([comment])
    
    filtered_restaurant_df['Comments'][filtered_restaurant_df['URL'] == url] = reviews

# %% [markdown]
# # Data Preparation

# %%
filtered_restaurant_df
# Out:
#                     Name  Rating Pricing  \
# 0              Da Andrea       4      $$
# 1               LoveMama       5      $$
# 3         Joe's Shanghai       4      $$
# 4               Antidote       4      $$
# 5                   Raku       4      $$
# ..                   ...     ...     ...
# 488           Little Mad       3    $$$$
# 490  Steak Frites Bistro       4     $$$
# 494          Bowery Road       3     $$$
# 495          ABC Kitchen       5     $$$
# 497           Luchadores       5      $$
#
#                                                    URL   Latitude  Longitude  \
# 0    https://www.yelp.com/biz/da-andrea-new-york?ad...  40.736218 -73.995970
# 1    https://www.yelp.com/biz/lovemama-new-york?adj...  40.730409 -73.986127
# 3    https://www.yelp.com/biz/joes-shanghai-new-yor...  40.715661 -73.996701
# 4    https://www.yelp.com/biz/antidote-brooklyn-2?a...  40.714253 -73.965448
# 5    https://www.yelp.com/biz/raku-new-york-7?adjus...  40.726499 -73.986653
# ..                                                 ...        ...        ...
# 488  https://www.yelp.com/biz/little-mad-new-york-2...  40.745020 -73.985130
# 490  https://www.yelp.com/biz/steak-frites-bistro-n...  40.755591 -73.994449
# 494  https://www.yelp.com/biz/bowery-road-new-york-...  40.733343 -73.990192
# 495  https://www.yelp.com/biz/abc-kitchen-new-york?...  40.737750 -73.989634
# 497  https://www.yelp.com/biz/luchadores-new-york?a...  40.705820 -74.004110
#
#                                          Transactions  \
# 0    ['delivery', 'pickup', 'restaurant_reservation']
# 1    ['delivery', 'pickup', 'restaurant_reservation']
# 3                              ['delivery', 'pickup']
# 4                              ['delivery', 'pickup']
# 5                              ['delivery', 'pickup']
# ..                                                ...
# 488                                                []
# 490                                                []
# 494                            ['delivery', 'pickup']
# 495                                      ['delivery']
# 497                            ['delivery', 'pickup']
#
#                                 Location          Phone     Distance  \
# 0       35 W 13th St, New York, NY 10011  12123671979.0  3526.365252
# 1        174 2nd Ave, New York, NY 10003  12122545370.0  2645.074283
# 3       46 Bowery St, New York, NY 10013  12122338888.0  1766.176007
# 4        66 S 2nd St, Brooklyn, NY 11249  17187822585.0  1376.494330
# 5       342 E 6th St, New York, NY 10003  12122281324.0  2236.683282
# ..                                   ...            ...          ...
# 488  110 Madison Ave, New York, NY 10016  19172614969.0  4231.367528
# 490      496 9th Ave, New York, NY 10018  19296145070.0  5530.277285
# 494      132 4th Ave, New York, NY 10003  12124321324.0  3052.241537
# 495     35 E 18th St, New York, NY 10003  12124755829.0  3508.876621
# 497      87 South St, New York, NY 10038  19174093033.0  2132.580935
#
#                                                Reviews  Review Count  \
# 0    [{'text': 'This small and crowded place seems ...             3
# 1    [{'text': 'Absolutely LOVED LoveMama!! As a co...             3
# 3    [{'text': 'This is the third stop of our food ...             3
# 4    [{'text': 'Excellent service & food! The drink...             3
# 5    [{'text': 'Delicious food, there are heaters f...             3
# ..                                                 ...           ...
# 488  [{'text': 'I went for my birthday. It took a w...             3
# 490  [{'text': 'Fantastic food and service. Great s...             3
# 494  [{'text': 'Great spot in a fantastic location ...             3
# 495  [{'text': 'Came in shortly after 12:30pm for a...             3
# 497  [{'text': "It's gotten super popular over the ...             3
#
#                                  Cuisine           Restaurant ID  \
# 0                          I t a l i a n  hdiuRS9sVZSMReZm4oV5SA
# 1                                T h a i  jjJc_CrkB2HodEinB6cWww
# 3                S h a n g h a i n e s e  0CjK3esfpFcxIopebzjFxA
# 4              C o c k t a i l   B a r s  4DInnPhOyvXFbYpUdO0SMQ
# 5                        J a p a n e s e  FlZ1zdVEKWv7dwqm8Uw8-w
# ..                                   ...                     ...
# 488          A m e r i c a n   ( N e w )  SmLFW1Ncg26KfVRVX3GVFQ
# 490                S t e a k h o u s e s  V3dHB6xAdd8_dH7t481PAw
# 494          A m e r i c a n   ( N e w )  FJepPR5CYRggxRwAjlqg6A
# 495  B r e a k f a s t   &   B r u n c h  dMhRafXdr765DHe0k-QfaQ
# 497                        M e x i c a n  8_NilECM6qg_L7WYb25uNw
#
#      Number of Reviews                                           Comments
# 0                 1851  This small and crowded place seems to be a nei...
# 1                 6377  Absolutely LOVED LoveMama!! As a college stude...
# 3                 7098  Casual, soup dumpling shop in Chinatown. No re...
# 4                  325  Excellent service & food! The drinks were so b...
# 5                 1497  Delicious food, there are heaters for the outs...
# ..                 ...                                                ...
# 488                166  Really amazing experience here. We got the yel...
# 490                 51  Beautiful evening spent in this restaurant. I ...
# 494                252  We came at a down time around midday for the r...
# 495               3165  ABSOLUTELY PHENOMENAL!!! I got the special, wh...
# 497                130  COULD NOT BE BETTER. kind employees, cute seat...
#
# [110 rows x 16 columns]

# %%
# Converting city, style, and reviews attributes to lowercase
filtered_restaurant_df['Location'] = filtered_restaurant_df['Location'].str.lower()
filtered_restaurant_df['Cuisine'] = filtered_restaurant_df['Cuisine'].str.lower()
filtered_restaurant_df['Comments'] = filtered_restaurant_df['Comments'].str.lower()

filtered_restaurant_df.sample(5)
# Out:
#                Name  Rating Pricing  \
# 395   P.J. Clarke's       3      $$
# 151  Izakaya Juraku       3     $$$
# 384          Karasu       4     $$$
# 394         Tuk Tuk       4      $$
# 91          Soba-ya       5      $$
#
#                                                    URL   Latitude  Longitude  \
# 395  https://www.yelp.com/biz/p-j-clarkes-new-york-...  40.713764 -74.016228
# 151  https://www.yelp.com/biz/izakaya-juraku-new-yo...  40.719680 -73.988709
# 384  https://www.yelp.com/biz/karasu-brooklyn-2?adj...  40.689373 -73.973246
# 394  https://www.yelp.com/biz/tuk-tuk-long-island-c...  40.743232 -73.954254
# 91   https://www.yelp.com/biz/soba-ya-new-york?adju...  40.729650 -73.987890
#
#                Transactions                                      Location  \
# 395  ['pickup', 'delivery']              250 vesey st, new york, ny 10281
# 151  ['delivery', 'pickup']             121 ludlow st, new york, ny 10002
# 384                      []  166 dekalb ave, walter's, brooklyn, ny 11217
# 394  ['pickup', 'delivery']  4906 vernon blvd, long island city, ny 11101
# 91   ['pickup', 'delivery']              229 e 9th st, new york, ny 10003
#
#              Phone     Distance  \
# 395  12122851500.0  3226.748903
# 151  12124770100.0  1608.999794
# 384            NaN  2045.301401
# 394  17184725598.0  4508.884632
# 91   12125336966.0  2602.136813
#
#                                                Reviews  Review Count  \
# 395  [{'text': "P.J. Clarke's on the Hudson is a ro...             3
# 151  [{'text': 'Came to this place after work with ...             3
# 384  [{'text': "Karasu is good. It's located within...             3
# 394  [{'text': 'The walls were decorated with some ...             3
# 91   [{'text': 'Place was empty and we were seated ...             3
#
#                                          Cuisine           Restaurant ID  \
# 395  a m e r i c a n   ( t r a d i t i o n a l )  B-MDhRKRTmTqj4Vp_p8AGw
# 151                                      b a r s  RYKGs45OjF-vlb2Ds2Jb_g
# 384                              j a p a n e s e  eyjeP9CJZ_gYgeJFP_vtpQ
# 394                                      t h a i  f7jZvRH-h76F4emzvKytaQ
# 91                               j a p a n e s e  i8ejDDR4COtukAAA1Ls5fw
#
#      Number of Reviews                                           Comments
# 395                670  i have mixed feelings about p.j clarke's mainl...
# 151                191  food was good! especially the karage fries and...
# 384                111  karasu is a japanese speakeasy hidden behind a...
# 394                762  food was good, especially the yum nam khao tod...
# 91                1544  the chicken katsu don was really yummy, but th...

# %%
# Dropping the reviews column
filtered_restaurant_df = filtered_restaurant_df.drop(['Reviews'],axis=1)
filtered_restaurant_df.head()
# Out:
#              Name  Rating Pricing  \
# 0       Da Andrea       4      $$
# 1        LoveMama       5      $$
# 3  Joe's Shanghai       4      $$
# 4        Antidote       4      $$
# 5            Raku       4      $$
#
#                                                  URL   Latitude  Longitude  \
# 0  https://www.yelp.com/biz/da-andrea-new-york?ad...  40.736218 -73.995970
# 1  https://www.yelp.com/biz/lovemama-new-york?adj...  40.730409 -73.986127
# 3  https://www.yelp.com/biz/joes-shanghai-new-yor...  40.715661 -73.996701
# 4  https://www.yelp.com/biz/antidote-brooklyn-2?a...  40.714253 -73.965448
# 5  https://www.yelp.com/biz/raku-new-york-7?adjus...  40.726499 -73.986653
#
#                                        Transactions  \
# 0  ['delivery', 'pickup', 'restaurant_reservation']
# 1  ['delivery', 'pickup', 'restaurant_reservation']
# 3                            ['delivery', 'pickup']
# 4                            ['delivery', 'pickup']
# 5                            ['delivery', 'pickup']
#
#                            Location          Phone     Distance  Review Count  \
# 0  35 w 13th st, new york, ny 10011  12123671979.0  3526.365252             3
# 1   174 2nd ave, new york, ny 10003  12122545370.0  2645.074283             3
# 3  46 bowery st, new york, ny 10013  12122338888.0  1766.176007             3
# 4   66 s 2nd st, brooklyn, ny 11249  17187822585.0  1376.494330             3
# 5  342 e 6th st, new york, ny 10003  12122281324.0  2236.683282             3
#
#                      Cuisine           Restaurant ID  Number of Reviews  \
# 0              i t a l i a n  hdiuRS9sVZSMReZm4oV5SA               1851
# 1                    t h a i  jjJc_CrkB2HodEinB6cWww               6377
# 3    s h a n g h a i n e s e  0CjK3esfpFcxIopebzjFxA               7098
# 4  c o c k t a i l   b a r s  4DInnPhOyvXFbYpUdO0SMQ                325
# 5            j a p a n e s e  FlZ1zdVEKWv7dwqm8Uw8-w               1497
#
#                                             Comments
# 0  this small and crowded place seems to be a nei...
# 1  absolutely loved lovemama!! as a college stude...
# 3  casual, soup dumpling shop in chinatown. no re...
# 4  excellent service & food! the drinks were so b...
# 5  delicious food, there are heaters for the outs...

# %% [markdown]
# # Modeling

# %% [markdown]
# # Evaluation

# %% [markdown]
# # Deployment
