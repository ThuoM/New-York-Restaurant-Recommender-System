# %% [markdown]
# # **New york Recommendation System**

# %% [markdown]
# ##### **Group 1 (i.e. Foodies) members**:
# <ul type='square'>
#     <li> David Mwiti</li>
#     <li> Karen Amanya</li>
#     <li> Mercy Onduso </li>
#     <li> Nicholus Magak </li>
#     <li> Penina Wanyama </li>
#     <li> Stephen Thuo </li>
# </ul>

# %% [markdown]
# # Business Understanding

# %% [markdown]
# #### **Importing the required libraries**

# %%
import pandas as pd
import numpy as np
import string
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# %config inlineBackend.figure_format = 'retina'
import seaborn as sns
sns.set_context('notebook')
from dataprep.clean import clean_country #pip install dataprep
import pycountry #conda install -c conda-forge pycountry
from surprise import Reader, Dataset, SVD, accuracy
from surprise.model_selection import cross_validate
from surprise.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### **Loading the data**

# %% [markdown]
# ##### _**1. restaurants_df**_

# %%
restaurant_df = pd.read_csv('restaurant_data.csv', encoding='utf-8', on_bad_lines='skip', low_memory=False)
restaurant_df.head()
# Out:
#               Name  Rating Pricing  \
# 0        Da Andrea       4      $$
# 1         LoveMama       5      $$
# 2  Ye's Apothecary       5     $$$
# 3   Joe's Shanghai       4      $$
# 4         Antidote       4      $$
#
#                                                  URL   Latitude  Longitude  \
# 0  https://www.yelp.com/biz/da-andrea-new-york?ad...  40.736218 -73.995970
# 1  https://www.yelp.com/biz/lovemama-new-york?adj...  40.730409 -73.986127
# 2  https://www.yelp.com/biz/yes-apothecary-new-yo...  40.719450 -73.989800
# 3  https://www.yelp.com/biz/joes-shanghai-new-yor...  40.715661 -73.996701
# 4  https://www.yelp.com/biz/antidote-brooklyn-2?a...  40.714253 -73.965448
#
#                                        Transactions  \
# 0  ['delivery', 'pickup', 'restaurant_reservation']
# 1  ['delivery', 'pickup', 'restaurant_reservation']
# 2                                                []
# 3                            ['delivery', 'pickup']
# 4                            ['delivery', 'pickup']
#
#                              Location         Phone   Display Phone  \
# 0    35 W 13th St, New York, NY 10011  1.212367e+10  (212) 367-1979
# 1     174 2nd Ave, New York, NY 10003  1.212255e+10  (212) 254-5370
# 2  119 Orchard St, New York, NY 10002           NaN             NaN
# 3    46 Bowery St, New York, NY 10013  1.212234e+10  (212) 233-8888
# 4     66 S 2nd St, Brooklyn, NY 11249  1.718782e+10  (718) 782-2585
#
#       Distance                                            Reviews  \
# 0  3526.365252  [{'text': 'This small and crowded place seems ...
# 1  2645.074283  [{'text': 'Absolutely LOVED LoveMama!! As a co...
# 2  1638.756115  [{'text': 'Edy and Josh are the BEST bartender...
# 3  1766.176007  [{'text': 'This is the third stop of our food ...
# 4  1376.494330  [{'text': 'Excellent service & food! The drink...
#
#    Review Count                                Cuisine  \
# 0             3                    I, t, a, l, i, a, n
# 1             3                             T, h, a, i
# 2             3                 S, z, e, c, h, u, a, n
# 3             3     S, h, a, n, g, h, a, i, n, e, s, e
# 4             3  C, o, c, k, t, a, i, l,  , B, a, r, s
#
#             Restaurant ID  Number of Reviews
# 0  hdiuRS9sVZSMReZm4oV5SA               1851
# 1  jjJc_CrkB2HodEinB6cWww               6377
# 2  8YWLuLUKj0t_0_Xv06UUtw                212
# 3  0CjK3esfpFcxIopebzjFxA               7098
# 4  4DInnPhOyvXFbYpUdO0SMQ                325

# %% [markdown]
# ##### _**2. users_df**_

# %%
user_revs_df = pd.read_csv('final_revs.csv', encoding='utf-8', on_bad_lines='skip', low_memory=False, header=None)
columns=['User_Name','Account','Location','Date_of_review','Rating','Comment','Restaurant_link']
user_revs_df.columns = columns
user_revs_df.head()
# Out:
#     User_Name                                      Account          Location  \
# 0  Richard D.  /user_details?userid=pRfWy61wU9e1nrCVrOEWLA      New York, NY
# 1    Elisa H.  /user_details?userid=ExhcUTTcj_MBhZdFQT9KYg      Brooklyn, NY
# 2  Morlene C.  /user_details?userid=VLTBPUrbNRR-f84h-altQw      Brooklyn, NY
# 3    Ruwan J.  /user_details?userid=xBVo8v0mw64nk6K-pYgI6A      New York, NY
# 4     Mike C.  /user_details?userid=37cpUoM8hlkSQfReIEBd-Q  Forest Hills, NY
#
#   Date_of_review  Rating                                            Comment  \
# 0      2/16/2023     4.0                                         No comment
# 1       1/6/2023     4.0                                         No comment
# 2     12/15/2022     3.0                                         No comment
# 3      3/23/2023     4.0  Urbanspace  Union Square is a newish addition-...
# 4     12/14/2022     5.0                                         No comment
#
#                                      Restaurant_link
# 0  https://www.yelp.com/biz/urbanspace-union-squa...
# 1  https://www.yelp.com/biz/urbanspace-union-squa...
# 2  https://www.yelp.com/biz/urbanspace-union-squa...
# 3  https://www.yelp.com/biz/urbanspace-union-squa...
# 4  https://www.yelp.com/biz/urbanspace-union-squa...

# %% [markdown]
# # Data Understanding

# %% [markdown]
# ##### _**1. restaurants_df**_

# %%
restaurant_df.info()

# Observations:
#   16 columns & 500 rows
#   It has some missing phone & display phone numbers
#   Missing quite a bit of data on the pricing section
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               500 non-null    object
#  1   Rating             500 non-null    int64
#  2   Pricing            315 non-null    object
#  3   URL                500 non-null    object
#  4   Latitude           500 non-null    float64
#  5   Longitude          500 non-null    float64
#  6   Transactions       500 non-null    object
#  7   Location           500 non-null    object
#  8   Phone              430 non-null    float64
#  9   Display Phone      430 non-null    object
#  10  Distance           500 non-null    float64
#  11  Reviews            500 non-null    object
#  12  Review Count       500 non-null    int64
#  13  Cuisine            500 non-null    object
#  14  Restaurant ID      500 non-null    object
#  15  Number of Reviews  500 non-null    int64
# dtypes: float64(4), int64(3), object(9)
# memory usage: 62.6+ KB

# %%
# Converting the cuisine text to a more human readable format
restaurant_df['Cuisine'] = restaurant_df['Cuisine'].map(lambda x: x.replace(',',''))

# %%
# viewing the types of cuisines 
set(restaurant_df['Cuisine'])
# Out:
# {'A m e r i c a n   ( N e w )',
#  'A m e r i c a n   ( T r a d i t i o n a l )',
#  'A r g e n t i n e',
#  'A s i a n   F u s i o n',
#  'A u s t r a l i a n',
#  'A u s t r i a n',
#  'B a g e l s',
#  'B a k e r i e s',
#  'B a r b e q u e',
#  'B a r s',
#  'B e l g i a n',
#  'B r a z i l i a n',
#  'B r e a k f a s t   &   B r u n c h',
#  'B u b b l e   T e a',
#  'B u f f e t s',
#  'B u r g e r s',
#  'B u r m e s e',
#  'C a f e s',
#  'C a j u n / C r e o l e',
#  'C a m b o d i a n',
#  'C a n t o n e s e',
#  'C a r i b b e a n',
#  'C h i c k e n   S h o p',
#  'C h i c k e n   W i n g s',
#  'C h i n e s e',
#  'C o c k t a i l   B a r s',
#  'C o f f e e   &   T e a',
#  'C o m f o r t   F o o d',
#  'C u b a n',
#  'D e l i s',
#  'D e s s e r t s',
#  'D i m   S u m',
#  'D i n e r s',
#  'F a s t   F o o d',
#  'F i l i p i n o',
#  'F o n d u e',
#  'F o o d   C o u r t',
#  'F r e n c h',
#  'G a s t r o p u b s',
#  'G e o r g i a n',
#  'G e r m a n',
#  'G r e e k',
#  'G r o c e r y',
#  'H i m a l a y a n / N e p a l e s e',
#  'H o t   D o g s',
#  'H o t   P o t',
#  'I n d i a n',
#  'I n d o n e s i a n',
#  'I t a l i a n',
#  'I z a k a y a',
#  'J a p a n e s e',
#  'J a p a n e s e   C u r r y',
#  'K o r e a n',
#  'L a t i n   A m e r i c a n',
#  'L e b a n e s e',
#  'L o u n g e s',
#  'M a l a y s i a n',
#  'M e d i t e r r a n e a n',
#  'M e x i c a n',
#  'M i d d l e   E a s t e r n',
#  'M o d e r n   E u r o p e a n',
#  'M o r o c c a n',
#  'N e w   M e x i c a n   C u i s i n e',
#  'N o o d l e s',
#  'P a n   A s i a n',
#  'P a t i s s e r i e / C a k e   S h o p',
#  'P e r s i a n / I r a n i a n',
#  'P e r u v i a n',
#  'P i z z a',
#  'P o r t u g u e s e',
#  'P u b s',
#  'R a m e n',
#  'S a n d w i c h e s',
#  'S c a n d i n a v i a n',
#  'S e a f o o d',
#  'S h a n g h a i n e s e',
#  'S o u l   F o o d',
#  'S o u t h e r n',
#  'S p a n i s h',
#  'S p e a k e a s i e s',
#  'S p e c i a l t y   F o o d',
#  'S t e a k h o u s e s',
#  'S u s h i   B a r s',
#  'S z e c h u a n',
#  'T a c o s',
#  'T a i w a n e s e',
#  'T a p a s   B a r s',
#  'T e a   R o o m s',
#  'T e p p a n y a k i',
#  'T h a i',
#  'T u r k i s h',
#  'V e g e t a r i a n',
#  'V e n e z u e l a n',
#  'V e n u e s   &   E v e n t   S p a c e s',
#  'V i e t n a m e s e',
#  'W i n e   B a r s'}

# %%
# viewing the number of unique restaurants
len(restaurant_df['Restaurant ID'].uniqueque())
# Out:
# 435

# %%
# Types of transactions occuring in the restaurants
set(restaurant_df['Transactions'])
# Out:
# {"['delivery', 'pickup', 'restaurant_reservation']",
#  "['delivery', 'pickup']",
#  "['delivery']",
#  "['pickup', 'delivery', 'restaurant_reservation']",
#  "['pickup', 'delivery']",
#  "['pickup', 'restaurant_reservation', 'delivery']",
#  "['restaurant_reservation', 'delivery', 'pickup']",
#  "['restaurant_reservation', 'delivery']",
#  "['restaurant_reservation']",
#  '[]'}

# %%
# viewing the locations
set(restaurant_df['Location'])
# Out:
# {'1 Doyers St, New York, NY 10013',
#  '1 Greene Ave, Brooklyn, NY 11238',
#  '1 John St, Brooklyn, NY 11201',
#  '10 Columbus Cir, New York, NY 10019',
#  '10 Columbus Cir, Third Floor, New York, NY 10019',
#  '10 Hudson Yards, New York, NY 10001',
#  '100 Pearl St, New York, NY 10004',
#  '102 Lexington Ave, New York, NY 10016',
#  '102 Suffolk St, New York, NY 10002',
#  '1025 Manhattan Ave, Brooklyn, NY 11222',
#  '103 N 3rd St, New York, NY 11249',
#  '1035 Flushing Ave, Brooklyn, NY 11237',
#  '104 2nd Ave, New York, NY 10003',
#  '104 S 4th St, Brooklyn, NY 11249',
#  '105 N 6th St, Brooklyn, NY 11249',
#  '105 Wilson Ave, New York, NY 11237',
#  '1063 1st Ave, New York, NY 10022',
#  '108 E 4th St, New York, NY 10003',
#  '108 W 74th St, New York, NY 10023',
#  '109 N 3rd St, Brooklyn, NY 11249',
#  '109 St Marks Pl, New York, NY 10009',
#  '11 E 13th St, New York, NY 10003',
#  '11 E 30th St, New York, NY 10016',
#  '11 E 47th St, New York, NY 10017',
#  '11 Hanover Sq, New York, NY 10005',
#  '11 Mott St, New York, NY 10013',
#  '11 W 8th St, New York, NY 10011',
#  '11 Water St, Brooklyn, NY 11201',
#  '110 E 7th St, New York, NY 10009',
#  '110 Madison Ave, New York, NY 10016',
#  '112 Eldridge St, New York, NY 10002',
#  '115 Allen St, New York, NY 10002',
#  '115 Division St, New York, NY 10002',
#  '1158 Myrtle Ave, Brooklyn, NY 11221',
#  '116 Newark Ave, Jersey City, NJ 07302',
#  '117 Ferris St, Brooklyn, NY 11231',
#  '117 Second Ave, New York, NY 10003',
#  '118 Madison Ave, New York, NY 10016',
#  '118A Eldridge St, New York, NY 10002',
#  '119 1st Ave, New York, NY 10003',
#  '119 Kent Ave, Brooklyn, NY 11249',
#  '119 Orchard St, New York, NY 10002',
#  '119 Saint Marks Pl, New York, NY 10009',
#  '12 John Street, World Trade Center Stadium, New York, NY 10038',
#  '120 Saint Marks Pl, New York, NY 10009',
#  '121 Ludlow St, New York, NY 10002',
#  '124 E 14th St, New York, NY 10003',
#  '126 MacDougal St, New York, NY 10012',
#  '126 Union St, Brooklyn, NY 11231',
#  '128 Greenpoint Ave, Brooklyn, NY 11222',
#  '128 Macdougal St, New York, NY 10012',
#  '129 Mulberry St, New York, NY 10013',
#  '129 W 52nd St, New York, NY 10019',
#  '130 Division St, New York, NY 10002',
#  '131 Christopher St, New York, NY 10014',
#  '131A Orchard St, New York, NY 10002',
#  '132 4th Ave, New York, NY 10003',
#  '132 Bowery, New York, NY 10013',
#  '132 Franklin St, Brooklyn, NY 11222',
#  '132 Greene Ave, Brooklyn, NY 11238',
#  '132 W 47th St, New York, NY 10036',
#  '133 5th Ave, Brooklyn, NY 11217',
#  '133 Chrystie St, New York, NY 10002',
#  '134 Nevins St, Brooklyn, NY 11217',
#  '135 E 55th St, New York, NY 10022',
#  '136 Church St, New York, NY 10007',
#  '136 Mulberry St, New York, NY 10013',
#  '137 E 13th St, New York, NY 10003',
#  '137 Eldridge St, New York, NY 10002',
#  '138 Smith St, New York, NY 11201',
#  '139 W 28th St, New York, NY 10001',
#  '140 Schermerhorn St, Brooklyn, NY 11201',
#  '143 4th Ave, New York, NY 10003',
#  '143 Orchard St, New York, NY 10002',
#  '1439 2nd Ave, New York, NY 10021',
#  '144 2nd Ave, New York, NY 10003',
#  '145 Borinquen Pl, Brooklyn, NY 11211',
#  '146 Metropolitan Ave, Brooklyn, NY 11249',
#  '147 Front St, Brooklyn, NY 11201',
#  '149 W 14th St, New York, NY 10011',
#  '15 E 31st St, New York, NY 10016',
#  '15 MetroTech Ctr, Brooklyn, NY 11201',
#  '15 Union Square W, New York, NY 10003',
#  '150 Ainslie St, Brooklyn, NY 11211',
#  '150 E 14th St, New York, NY 10003',
#  '151 E Broadway, New York, NY 10002',
#  '151 Elizabeth St, New York, NY 10012',
#  '152 2nd Ave, Ste A, New York, NY 10003',
#  '152 Driggs Ave, Brooklyn, NY 11222',
#  '153 Rivington St, New York, NY 10002',
#  '156 10th Ave, New York, NY 10011',
#  '156 Knickerbocker Ave, New York, NY 11237',
#  '159 Central Ave, Brooklyn, NY 11221',
#  '16 E 46th St, New York, NY 10017',
#  '16 E 58th St, New York, NY 10022',
#  '16 W 29th St, New York, NY 10001',
#  '160 E 23rd St, New York, NY 10010',
#  '160 Franklin St, Brooklyn, NY 11222',
#  '164 Graham Ave, Brooklyn, NY 11206',
#  '165 Mulberry St, New York, NY 10013',
#  "166 Dekalb Ave, Walter's, Brooklyn, NY 11217",
#  '168 Borinquen Pl, Brooklyn, NY 11211',
#  '169 Sullivan St, New York, NY 10012',
#  '17 W 19th St, New York, NY 10011',
#  '170 S 3rd St, Brooklyn, NY 11211',
#  '170 Thompson St, New York, NY 10012',
#  '171 Avenue A, New York, NY 10009',
#  '171 E Broadway, New York, NY 10002',
#  '171 Grand St, Brooklyn, NY 11249',
#  '171 Lafayette Ave, Brooklyn, NY 11238',
#  '174 2nd Ave, New York, NY 10003',
#  '176 Bleecker St, New York, NY 10012',
#  '177 Henry St, New York, NY 10002',
#  '178 Broadway, Brooklyn, NY 11211',
#  '18 Bedford Ave, Brooklyn, NY 11222',
#  '182 Avenue B, New York, NY 10009',
#  '184 Kent Ave, Brooklyn, NY 11249',
#  '185 Atlantic Ave, Brooklyn, NY 11201',
#  '19 Old Fulton St, Brooklyn, NY 11201',
#  '192 Nassau Ave, Brooklyn, NY 11222',
#  '193 Bleecker St, New York, NY 10012',
#  '194 Grand St, New York, NY 10013',
#  '195 DeKalb Ave, Brooklyn, NY 11205, Brooklyn, NY 11205',
#  '195 Franklin St, Brooklyn, NY 11222',
#  '196 Spring St, New York, NY 10012',
#  '197 Meserole St, Brooklyn, NY 11206',
#  '2 Metrotech Ctr, Brooklyn, NY 11201',
#  '2 Renwick St, New York, NY 10013',
#  '20 Columbia Pl, Brooklyn, NY 11201',
#  '20 E 17th St, New York, NY 10003',
#  '20 Hudson Yards, New York, NY 10001',
#  '20 John St, New York, NY 10038',
#  '20 W 40th St, New York, NY 10018',
#  '200 5th Ave, New York, NY 10010',
#  '200 E 3rd St, New York, NY 10009',
#  '201 Lafayette St, New York, NY 10012',
#  '202 Ave A, New York, NY 10009',
#  '204 E 13th St, New York, NY 10003',
#  '205 E 4th St, New York, NY 10009',
#  '205 E Houston St, New York, NY 10002',
#  '205 W 57th St, New York, NY 10019',
#  '207 W 14th St, New York, NY 10011',
#  '208 Bedford Ave, New York, NY 11249',
#  '209 E 49th St, New York, NY 10017',
#  '209 Mulberry St, New York, NY 10012',
#  '209 N 8th St, Brooklyn, NY 11211',
#  '21 Ann St, New York, NY 10038',
#  '21 Greenpoint Ave, Brooklyn, NY 11222',
#  '21 Mott St, New York, NY 10013',
#  '21 Waverly Pl, New York, NY 10003',
#  '212 E 10th St, New York, NY 10003',
#  '212 Greene Ave, Brooklyn, NY 11238',
#  '213 Smith St, Brooklyn, NY 11201',
#  '215 Chrystie St, New York, NY 10002',
#  '216 7th Ave, New York, NY 10011',
#  '216 Smith St, Brooklyn, NY 11201',
#  '217 E 43rd St, Ste 1f, New York, NY 10017',
#  '218 E 9th St, New York, NY 10003',
#  '219 Dekalb Ave, Brooklyn, NY 11205',
#  '22 N Loop Rd, New York, NY 10044',
#  '22 Old Fulton St, Brooklyn, NY 11201',
#  '22 W 32nd St, Fl 2, New York, NY 10001',
#  '22 W 8th St, New York, NY 10011',
#  '220 West 44th St, New York, NY 10036',
#  '225-227 Front St, New York, NY 10038',
#  '226 Front St, New York, NY 10038',
#  '228 Smith St, Brooklyn, NY 11231',
#  '228 Thompson St, New York, NY 10012',
#  '229 E 9th St, New York, NY 10003',
#  '229 Front St, New York, NY 10038',
#  '229 W 43rd St, New York, NY 10036',
#  '23 Greenpoint Ave, Brooklyn, NY 11222',
#  '230 E 44th St, New York, NY 10017',
#  '230 E 9th St, Fl 2, New York, NY 10003',
#  '231 E 9th St, New York, NY 10003',
#  '231 Eldridge St, New York, NY 10002',
#  '231 Kent Ave, Brooklyn, NY 11249',
#  '233 West St, New York, NY 10013',
#  '236 E 13th St, New York, NY 10003',
#  '239 Centre St, New York, NY 10013',
#  '24 Greenwich Ave, New York, NY 10011',
#  '24-26 Erie st, Jersey City, NJ 07302',
#  '241 S 4th St, Brooklyn, NY 11211',
#  '244 Flatbush Ave, Brooklyn, NY 11217',
#  '244 Mulberry St, New York, NY 10012',
#  '248 Court St, Brooklyn, NY 11201',
#  '25 Bogart St, Brooklyn, NY 11206',
#  '25 Greenpoint Ave, Brooklyn, NY 11222',
#  '250 Dekalb Ave, Brooklyn, NY 11205',
#  '250 Vesey St, New York, NY 10281',
#  '251 Broome St, New York, NY 10002',
#  '251 Church St, New York, NY 10013',
#  '251 W 55th St, Fl 2, New York, NY 10019',
#  '251 West 50th St, New York, NY 10012',
#  '253 Grand St, Brooklyn, NY 11211',
#  '254 S 2nd St, Brooklyn, NY 11211',
#  '258 Wythe Ave, New York, NY 11249',
#  '26 S William St, New York, NY 10004',
#  '261 Moore St, Brooklyn, NY 11206',
#  '265 Canal St, New York, NY 10013',
#  '267 W 17th St, New York, NY 10011',
#  '27 Broadway, Brooklyn, NY 11249',
#  '27 Division St, New York, NY 10002',
#  '277 Smith St, Brooklyn, NY 11231',
#  '28 W 32nd St, Fl 2, New York, NY 10001',
#  '280 Ashland Pl, Brooklyn, NY 11217',
#  '281 Park Ave S 22nd St Entrance, Second Floor, New York, NY 10010',
#  '285 W 12th St, New York, NY 10014',
#  '29 Dunham Pl, Brooklyn, NY 11249',
#  '294 Livingston St, Brooklyn, NY 11217',
#  '295 3rd Ave, Brooklyn, NY 11215',
#  '295 Grand St, New York, NY 10002',
#  '3 Doyers St, New York, NY 10013',
#  '30 E 13th St, New York, NY 10003',
#  '31 W 52nd St, New York, NY 10019',
#  '311 Church St, New York, NY 10013',
#  '316 Court St, Brooklyn, NY 11231',
#  '318 Livingston St, Brooklyn, NY 11217',
#  '319 Kent Ave, Brooklyn, NY 11249',
#  '32 E 16th St, New York, NY 10003',
#  '320 Atlantic Ave, Brooklyn, NY 11201',
#  '320 E 6th St, New York, NY 10003',
#  '321 Nostrand Ave, Brooklyn, NY 11216',
#  '324 E 6th St, New York, NY 10003',
#  '324 Washington St, Hoboken, NJ 07030',
#  '326 E 6th St, New York, NY 10003',
#  '327 Gold St, Brooklyn, NY 11201',
#  '328 E 6th St, New York, NY 10003',
#  '33 Hudson Yards, Fl 24, New York, NY 10001',
#  '330 Myrtle Ave, Brooklyn, NY 11205',
#  '330 W Broadway, New York, NY 10013',
#  '333 Tompkins Ave, Brooklyn, NY 11216',
#  '334 W 46th St, New York, NY 10036',
#  '335 3rd Ave, New York, NY 10010',
#  '340 Lafayette St, New York, NY 10012',
#  '342 E 6th St, New York, NY 10003',
#  '342 Wythe Ave, New York, NY 11249',
#  '35 Downing St, New York, NY 10014',
#  '35 E 18th St, New York, NY 10003',
#  '35 W 13th St, New York, NY 10011',
#  '35 W 19th St, New York, NY 10011',
#  '35 W 35th St, New York, NY 10001',
#  '351 E 12th St, New York, NY 10003',
#  '352 W 39th St, New York, NY 10018',
#  '353 Bedford Ave, Brooklyn, NY 11211',
#  '358 W 46th St, New York, NY 10036',
#  '36 E 22nd St, New York, NY 10010',
#  '362 2nd Ave, New York, NY 10010',
#  '363 3rd Ave, New York, NY 10016',
#  '365 Van Brunt St, Brooklyn, NY 11231',
#  '369 5th Ave, Brooklyn, NY 11215',
#  '370 Lexington Ave, New York, NY 10017',
#  '372 Fulton St, Brooklyn, NY 11201',
#  '372 Myrtle Ave, Brooklyn, NY 11205',
#  '377 Greenwich St, New York, NY 10013',
#  '378 Park Ave S, New York, NY 10010',
#  '380 Van Brunt St, Brooklyn, NY 11231',
#  '387 Myrtle Ave, Brooklyn, NY 11205',
#  '39-04 64th St, New York, NY 11377',
#  '39-06 64th St, Woodside, NY 11377',
#  '398 Manhattan Ave, Brooklyn, NY 11211',
#  '4 W 22nd St, New York, NY 10010',
#  '40 Kenmare St, New York, NY 10012',
#  '40 W 56th St, New York, NY 10019',
#  '40 Water St, Brooklyn, NY 11201',
#  '400 Kent Ave, Brooklyn, NY 11211',
#  '400A W 50th St, New York, NY 10019',
#  '401 E 13th St, New York, NY 10009',
#  '404 W 49th, New York, NY 10019',
#  '407 Smith St, Brooklyn, NY 11231',
#  '408 Broome St, New York, NY 10013',
#  '409 Eastern Pkwy, New York, NY 11216',
#  '40A 10th Ave, New York, NY 10014',
#  '41 W 24th St, New York, NY 10010',
#  '41 W 33rd St, New York, NY 10001',
#  '412 Fifth Ave, Brooklyn, NY 11215',
#  '413 E 12th St, New York, NY 10009',
#  '415 Tompkins Ave, Brooklyn, NY 11216',
#  '419 Putnam Ave, Brooklyn, NY 11216',
#  '42 E 20th St, New York, NY 10003',
#  '420 Kent Ave, Brooklyn, NY 11249',
#  '429 Greenwich St, New York, NY 10013',
#  '43 Carmine St, New York, NY 10014',
#  '43 W 32nd St, New York, NY 10001',
#  '435 W 15th St, New York, NY 10011',
#  '44-14 48th Ave, Sunnyside, NY 11377',
#  '445 Albee Sq W, Dekalb Market Hall, Brooklyn, NY 11201',
#  '447 Rogers Ave, Prospect Lefferts Gardens, Brooklyn, NY 11225',
#  '449 Nostrand Ave, Brooklyn, NY 11216',
#  '45 W 45th St between 5th & 6th Ave, New York, NY 10036',
#  '450 W 33rd St, Whole Foods, New York, NY 10001',
#  '452 Washington St, New York, NY 10013',
#  '454 Van Brunt St, Brooklyn, NY 11231',
#  '455 7th Ave, Brooklyn, NY 11215',
#  '457 3rd Ave, Brooklyn, NY 11215',
#  '458 Myrtle Ave, Brooklyn, NY 11205',
#  '46 Bowery St, New York, NY 10013',
#  '46 Norman Ave, Brooklyn, NY 11222',
#  '462 Court St, Brooklyn, NY 11231',
#  '47 Java St, Brooklyn, NY 11222',
#  '47 Prince St, New York, NY 10012',
#  '47 South 5th St, Brooklyn, NY 11249',
#  '47-15 Northern Blvd, Queens, NY 11101',
#  '470 6th Ave, New York, NY 10011',
#  '472 Myrtle Ave, Brooklyn, NY 11205',
#  '483 10th Ave, New York, NY 10018',
#  '485 7th Ave, New York, NY 10018',
#  '4906 Vernon Blvd, Long Island City, NY 11101',
#  '496 9th Ave, New York, NY 10018',
#  '499 Myrtle Ave, Brooklyn, NY 11205',
#  '5 Ave A, New York, NY 10009',
#  '5 Bleecker St, New York, NY 10012',
#  '5 E 48th St, Manhattan, NY 10017',
#  '5 Greene Ave, Brooklyn, NY 11238',
#  '5 St Marks Pl, New York, NY 10003',
#  '5 West 31st St, New York, NY 10001',
#  '50 Bowery, New York, NY 10013',
#  '50 Henry St, Brooklyn, NY 11201',
#  '500 Prospect Pl, Brooklyn, NY 11238',
#  '507 East 6th St, New York, NY 10009',
#  '509 Amsterdam Ave, New York, NY 10024',
#  '509 Myrtle Ave, Brooklyn, NY 11205',
#  '519 Metropolitan Ave, Brooklyn, NY 11211',
#  '51B Canal St, New York, NY 10002',
#  '520 Hudson St, New York, NY 10014',
#  '521 Court St, Brooklyn, NY 11231',
#  '525 Hudson St, New York, NY 10014',
#  '53 Irving Pl, New York, NY 10003',
#  '531 Myrtle Ave, Brooklyn, NY 11205',
#  '55 Prospect St, Brooklyn, NY 11201',
#  '55 W 35th St, New York, NY 10001',
#  '55 Water St, Brooklyn, NY 11201',
#  '55-33 Myrtle Ave, Ridgewood, NY 11385',
#  '550 Court St, Brooklyn, NY 11231',
#  '562 Grand St, Fl 1, Brooklyn, NY 11211',
#  '57 Clinton St, New York, NY 10002',
#  '572 Fulton St, Brooklyn, NY 11217',
#  '58 E 1st St, New York, NY 10003',
#  '58 Henry St, New York, NY 10002',
#  '581 Vanderbilt Ave, Brooklyn, NY 11238',
#  '59 2nd Ave, New York, NY 10003',
#  '60 E 54th St, New York, NY 10022',
#  '60 Greenpoint Ave, Brooklyn, NY 11222',
#  '60 Henry St, Brooklyn, NY 11201',
#  '601 W 26th St, New York, NY 10001',
#  '605 3rd Ave, New York, NY 10158',
#  '610 5th Ave, New York, NY 10020',
#  '611 Hudson St, New York, NY 10014',
#  '617 Grand St, Brooklyn, NY 11211',
#  '626 Vanderbilt Ave, Brooklyn, NY 11238',
#  '627 E 6th St, New York, NY 10009',
#  '627 Vanderbilt Ave, Brooklyn, NY 11238',
#  '63 Carmine St, New York, NY 10014',
#  '63 Delancey St, New York, NY 10002',
#  '630 Hudson St, New York, NY 10014',
#  '635 2nd Ave, New York, NY 10016',
#  '650 W 42nd St, New York, NY 10036',
#  '659 Vanderbilt Ave, Brooklyn, NY 11238',
#  '66 Charlton St, New York, NY 10014',
#  '66 Hicks St, Brooklyn, NY 11201',
#  '66 S 2nd St, Brooklyn, NY 11249',
#  '67 Murray St, New York, NY 10007',
#  '68 Clinton St, New York, NY 10002',
#  '7 E 48th St, between Fifth and Madison avenues, New York, NY 10017',
#  '70 Forsyth St, New York, NY 10002',
#  '70 Grand St, Brooklyn, NY 11249',
#  '70 Greenpoint Ave, Brooklyn, NY 11222',
#  '70 Hudson Ave, Brooklyn, NY 11201',
#  '701 9th Ave, New York, NY 10019',
#  '71 Clark St, Brooklyn, NY 11201',
#  '71 Pineapple St, Brooklyn, NY 11201',
#  '72 Henry St, Brooklyn, NY 11201',
#  '724 Sterling Pl, Brooklyn, NY 11216',
#  '74 Bleecker St, New York, NY 10012',
#  '746 10th Ave, Fl 1, New York, NY 10019',
#  '749 9th Ave, New York, NY 10019',
#  '75 9th Ave, New York, NY 10011',
#  '76 Henry St, Brooklyn, NY 11201',
#  '77 Warren St, New York, NY 10007',
#  '773 Fulton St, Brooklyn, NY 11217',
#  '783 9th Ave, New York, NY 10019',
#  '788 Franklin Ave, Brooklyn, NY 11238',
#  '79 Chrystie St, New York, NY 10002',
#  '79 Grand St, Brooklyn, NY 11249',
#  '79 Orchard St, New York, NY 10002',
#  '791 Washington Ave, Brooklyn, NY 11238',
#  '80 Clark St, Brooklyn, NY 11201',
#  '80 Montague St, Brooklyn, NY 11201',
#  '81 Broadway, Brooklyn, NY 11249',
#  '81 Division St, New York, NY 10002',
#  '817 Washington St, New York, NY 10014',
#  '82 W 3rd St, New York, NY 10012',
#  '82 Washington Ave, Brooklyn, NY 11205',
#  '833 Dekalb Ave, New York, NY 11221',
#  '84 E 10th St, New York, NY 10003',
#  '84 Stanton St, New York, NY 10002',
#  '85 10th Ave, New York, NY 10011',
#  '85 Bergen St, Brooklyn, NY 11201',
#  '85 Broadway, Brooklyn, NY 11249',
#  '86 S Portland Ave, Brooklyn, NY 11217',
#  '87 South St, New York, NY 10038',
#  '88 E Broadway, Unit 106, Located Outside on Forsyth Street, New York, NY 10002',
#  '88 Reade St, New York, NY 10013',
#  '88 Wall St, New York, NY 10005',
#  '89 E 4th St, New York, NY 10003',
#  '89 South St, Pier 16, New York, NY 10038',
#  '89 South St, Pier 17, New York, NY 10038',
#  '9 Crosby St, NOMO SOHO Hotel, New York, NY 10013',
#  '9 E 37th St, New York, NY 10016',
#  '9 Maiden Ln, New York, NY 10038',
#  '90 Bowery, New York, NY 10013',
#  '90 Clinton St, New York, NY 10002',
#  '90 Washington St, New York, NY 10006',
#  '905 Lorimer St, Brooklyn, NY 11222',
#  '91 Bayard St, New York, NY 10013',
#  '91 S 6th St, Brooklyn, NY 11249',
#  '94 Ave C, New York, NY 10009',
#  '95 1st Ave, New York, NY 10003',
#  '954 Manhattan Ave, Brooklyn, NY 11222',
#  '956 2nd Ave, New York, NY 10022',
#  '96 Orchard St, New York, NY 10002',
#  '96 South St, New York, NY 10038',
#  '98 Mott St, Ste 3, New York, NY 10013',
#  '990 Broadway, Brooklyn, NY 11221',
#  '999 Manhattan Ave, Brooklyn, NY 11222',
#  'New York, NY 10007',
#  'Pier 6 Brooklyn Bridge Park, Brooklyn Bridge Park, Brooklyn, NY 11201',
#  'Pier 81, W 41 St & 12th Ave, New York, NY 10036',
#  'Queens, NY 11104',
#  'Smith Street & Pacific Street, Brooklyn, NY 11201',
#  'W 26th St, Hudson River Park, New York, NY 10010'}

# %%
# viewing the rating scale of the restaurants
set(restaurant_df['Rating'])
# Out:
# {1, 2, 3, 4, 5}

# %%
fig, ax = plt.subplots(figsize=(11,8))
sns.histplot(restaurant_df['Rating'], bins = np.arange(8) - 0.5, color='teal', ax=ax)
ax.set_xticks(range(1,6))
ax.set_xlabel('Ratings')
ax.set_ylabel('Number of Restaurants')
ax.set_title('Restaurant Ratings');

rating_count = restaurant_df['Rating'].value_counts().sort_index()
for i, val in enumerate(rating_count.values):
    ax.text(i+1, val+5, (f'{round((val/sum(rating_count.values))*100, 1)}%'), ha='center', va='bottom',size=12)  
    
    # Observations:
    # The book rating ranges from 0 to 10
    # Most books have a rating of 0
    # The ratings between 1-4 have very few books

# %% [markdown]
# ##### _**2. users_df**_

# %%
user_revs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38094 entries, 0 to 38093
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User_Name        38094 non-null  object
#  1   Account          38094 non-null  object
#  2   Location         38094 non-null  object
#  3   Date_of_review   38094 non-null  object
#  4   Rating           38094 non-null  float64
#  5   Comment          38094 non-null  object
#  6   Restaurant_link  38094 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 2.0+ MB

# %%
# Checking how many unique users rated
len(user_revs_df['Account'].unique())
# Out:
# 33168

# %%
user_revs_df.describe()
# Out:
#              Rating
# count  38094.000000
# mean       4.096104
# std        1.137435
# min        1.000000
# 25%        4.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000

# %%
# List of locations to users majority
list_of_locs = set(user_revs_df['Location'])
dic_loc = {}

for location in list_of_locs:
    num = len(user_revs_df[user_revs_df['Location'] == location])
    dic_loc[location] = num
dic_loc
# Out:
# {'Port St. Lucie, FL': 1,
#  'Denton, TX': 2,
#  'Encino, Los Angeles, CA': 2,
#  'Merrick, NY': 10,
#  'Tuscaloosa, AL': 3,
#  'Arlington, TN': 1,
#  'Mart, TX': 1,
#  'Montgomery, TX': 2,
#  'East Los Angeles, CA': 2,
#  'Sunrise, FL': 3,
#  'Tillsonburg, Canada': 1,
#  'Bronx, NY': 259,
#  'Fair Haven, NJ': 1,
#  'Aix-en-Provence, France': 1,
#  'Parlin, Old Bridge Township, NJ': 2,
#  'Baltimore, MD': 90,
#  'Hallett Cove, Australia': 1,
#  'Oceanside, CA': 8,
#  'Windsor, CT': 2,
#  'Memphis, TN': 9,
#  'Baton Rouge, LA': 9,
#  'Rosedale, Queens, NY': 2,
#  'Sartrouville, France': 1,
#  'Pompano Beach, FL': 15,
#  'Berkeley Heights, NJ': 3,
#  'Williamsburg, NY': 18,
#  'Tracy, CA': 5,
#  'Port Washington, NY': 16,
#  'Sequim, WA': 1,
#  'Sunkist Park, Culver City, CA': 1,
#  'Kansas City, KS': 2,
#  'Shoreline, WA': 1,
#  'Östermalm, Stockholm, Sweden': 1,
#  'Margate City, NJ': 1,
#  'Timberwood Park, TX': 1,
#  'Dover, DE': 2,
#  'Myrtle Beach, SC': 4,
#  'Dayton, OH': 4,
#  'East Meadow, NY': 9,
#  'Evergreen, CO': 3,
#  'La Habra, CA': 1,
#  'Amherst, OH': 1,
#  'North San Jose, San Jose, CA': 3,
#  'Corniglia, Italy': 1,
#  'Kensington, MD': 1,
#  'Ocean City, NJ': 1,
#  'Corktown, Detroit, MI': 1,
#  'Dearborn, MI': 3,
#  'Winter Park, FL': 4,
#  'Trocadéro/Iéna, Paris, France': 1,
#  'Tulsa, OK': 6,
#  'Menifee, CA': 2,
#  'Viborg, Denmark': 1,
#  'Sonoma, CA': 1,
#  'Tsawwassen, Delta, Canada': 1,
#  'Lebanon, IN': 1,
#  'Webster, TX': 3,
#  'Altstadt-Lehel, Munich, Germany': 1,
#  'Sebastopol, CA': 1,
#  'Northville, MI': 4,
#  'Vista East, Orlando, FL': 1,
#  'Napa, CA': 6,
#  'Woodbridge, Irvine, CA': 1,
#  'Greensboro, NC': 5,
#  'Herriman, UT': 1,
#  'El Monte, CA': 5,
#  'Woodcliff Lake, NJ': 1,
#  'West University, Houston, TX': 1,
#  'Piedmont, CA': 2,
#  'Santa Clara, CA': 30,
#  'Central Boulder, Boulder, CO': 1,
#  'Burien, WA': 1,
#  'Port Crane, NY': 1,
#  'Elizabethport, NJ': 2,
#  'Saint Rose, LA': 1,
#  'Waukesha, WI': 2,
#  'West Jordan, UT': 2,
#  'Conway, SC': 1,
#  'Belgrade, MN': 1,
#  'West Adams, Los Angeles, CA': 1,
#  'Miami Lakes, FL': 2,
#  'Parsippany, Parsippany-Troy Hills, NJ': 1,
#  'South Hempstead, NY': 1,
#  'North Dallas, Richardson, TX': 1,
#  'Bay Shore, NY': 8,
#  'Watertown, CT': 1,
#  'New Square, NY': 1,
#  'South Tempe, Tempe, AZ': 1,
#  'Iowa City, IA': 4,
#  'San Marcos, CA': 4,
#  'Meatpacking District, Manhattan, NY': 1,
#  'Orchard Park, NY': 2,
#  'River Oaks, Bakersfield, CA': 1,
#  'Baldwin Park, CA': 5,
#  'Westfield, IN': 4,
#  'Hampstead, Canada': 1,
#  'Koreatown, Manhattan, NY': 2,
#  'South Plainfield, NJ': 7,
#  'Pocono Summit, PA': 2,
#  'Old Orchard Beach, ME': 1,
#  'Kyle, TX': 1,
#  'Shavertown, PA': 1,
#  'Burnaby, Canada': 3,
#  'Brunswick, OH': 1,
#  'Brea, CA': 12,
#  'Temple, TX': 1,
#  'Colchester, VT': 1,
#  'Milford Charter Township, MI': 1,
#  'Vista, CA': 5,
#  'Austell, GA': 1,
#  'Norristown, PA': 2,
#  'Yuma, AZ': 1,
#  'Riverside, Tempe, AZ': 1,
#  'Elk Grove, CA': 19,
#  'Volcano, HI': 1,
#  'Moultonborough, NH': 1,
#  'South Salt Lake, UT': 2,
#  'Livingston, NJ': 17,
#  'BELLE MEAD, NJ': 1,
#  'Saint AUG BEACH, FL': 1,
#  'Newberry, FL': 1,
#  'Holt, MI': 1,
#  'London, United Kingdom': 83,
#  'LA JOLLA, CA': 1,
#  'East Orange, NJ': 15,
#  'Stephenville, TX': 1,
#  'Les Grandes Carmes, Marseille, France': 1,
#  'Indian Harbour Beach, FL': 1,
#  'Hollywood, Los Angeles, CA': 5,
#  'Chinatown, Houston, TX': 1,
#  'West Hills, CA': 1,
#  'Lafayette Hill, PA': 1,
#  'Downtown Crossing, Boston, MA': 1,
#  'Winnetka, CA': 1,
#  'Sewanee, TN': 1,
#  'South Ozone Park, NY': 1,
#  'Saint Cloud, FL': 2,
#  'Lexington, KY': 7,
#  'North University, Austin, TX': 1,
#  'East Greenwich, RI': 3,
#  'Kittery Point, ME': 1,
#  'ROWLAND HGHTS, CA': 1,
#  'Le Pré-Saint-Gervais, France': 1,
#  'East Syracuse, NY': 1,
#  'Palatine, IL': 6,
#  'Arcata, CA': 1,
#  'Fresh Meadows, NY': 24,
#  'Flemington, NJ': 8,
#  'Ladera Ranch, CA': 3,
#  'Stroudsburg, PA': 1,
#  'Glencoe, IL': 1,
#  'Santee, CA': 1,
#  'Guaynabo, Puerto Rico': 1,
#  'Laguna Hills, CA': 5,
#  'Burns Park, Ann Arbor, MI': 2,
#  'Flatiron, Manhattan, NY': 12,
#  'Foxborough, MA': 2,
#  'Old Palo Alto, Palo Alto, CA': 1,
#  'Pleasantville, NY': 4,
#  'Davenport, FL': 2,
#  'New Hope, PA': 1,
#  'Massapequa Park, NY': 4,
#  'Brentwood, Saint Louis, MO': 1,
#  'Grosse Pointe, MI': 1,
#  'Washington, DC': 314,
#  'Hicksville, Hicksville, NY': 1,
#  'Grandview Heights, Columbus, OH': 1,
#  'Lutz, FL': 2,
#  'Vale, NC': 1,
#  'Petersburg, VA': 1,
#  'Northampton, MA': 4,
#  'Ghent, Norfolk, VA': 1,
#  'Elmont, NY': 22,
#  'Lindon Park, Tempe, AZ': 1,
#  'Pittstown, NJ': 1,
#  'Stockbridge, GA': 2,
#  'North Las Vegas, NV': 5,
#  'Burleson, TX': 1,
#  'Loches, France': 1,
#  'North Babylon, NY': 3,
#  'Santa Rosa, CA': 4,
#  'West New York, NJ': 19,
#  'Jacksonville, FL': 29,
#  'Bronxville, NY': 11,
#  'Subiaco, Australia': 1,
#  'JACKSON HTS, NY': 2,
#  'Portales, NM': 1,
#  'Manchester, NH': 3,
#  'Abilene, TX': 1,
#  'Bellerose, NY': 5,
#  'Pomonok, Queens, NY': 1,
#  'Harrington Park, NJ': 1,
#  'San Francisco Bay Area, CA': 16,
#  'Wynnewood, PA': 2,
#  'Johns Creek, GA': 2,
#  'Athens, GA': 4,
#  'Clinton, MD': 2,
#  'Glenmont, NY': 2,
#  'North Dartmouth, MA': 1,
#  'South Hill, WA': 1,
#  'Bridgeton, MO': 2,
#  'Watervliet, NY': 1,
#  'Northwest Anaheim, Anaheim, CA': 1,
#  'Brandon, FL': 2,
#  'Forest Hills, Queens, NY': 18,
#  'Bayonne, NJ': 16,
#  'Patterson, NY': 1,
#  'Albany, CA': 8,
#  'East Arlington, Jacksonville, FL': 1,
#  'Dalton, GA': 1,
#  'Ballantyne, Charlotte, NC': 1,
#  'South Village, Manhattan, NY': 1,
#  'College Hill, Providence, RI': 1,
#  'Burlington, WI': 1,
#  'Peachtree City, GA': 3,
#  'Oakwood, OH': 1,
#  'SOMA, San Francisco, CA': 1,
#  'Oak Park, Santa Barbara, CA': 1,
#  'Midland, TX': 2,
#  'Coquitlam, Canada': 1,
#  'Englishtown, NJ': 4,
#  'Sun City Center, FL': 1,
#  'Flatbush, New York, NY': 7,
#  'Redford, MI': 1,
#  'Spanish Fork, UT': 1,
#  'Pelham Bay, Bronx, NY': 1,
#  'Chester Township, NJ': 1,
#  'Rosslyn, Arlington, VA': 1,
#  'Deer Park, NY': 5,
#  'Lost Hills, CA': 2,
#  'Alta Loma, CA': 1,
#  'Exeter, NH': 1,
#  'University Park, State College, PA': 1,
#  'Friendswood, TX': 2,
#  'Irvine Business Complex, Irvine, CA': 2,
#  'Downtown, San Antonio, TX': 1,
#  'Denville, NJ': 4,
#  'Bruchmühlbach-Miesau, Germany': 1,
#  'Claremont, CA': 9,
#  'Erith, United Kingdom': 1,
#  'Pleasant Grove, UT': 1,
#  'Dale City, VA': 1,
#  'Lombard, IL': 1,
#  'Bay Area, CA': 2,
#  'Heath, OH': 1,
#  'Logan, Philadelphia, PA': 2,
#  'Delano, CA': 1,
#  'Princeton Meadows, NJ': 1,
#  'New Port Richey, FL': 3,
#  'Miami Shores, FL': 1,
#  'Spokane Valley, WA': 2,
#  'South Hadley, MA': 1,
#  'East Oakland, Oakland, CA': 2,
#  'Alhambra, Los Angeles, CA': 2,
#  'Goodlettsville, TN': 1,
#  'Brazos, Waco, TX': 1,
#  'Beaumont, TX': 2,
#  'Central Business District, New Orleans, LA': 1,
#  'Orlando, FL': 91,
#  'Woodbury, NJ': 2,
#  'Central Austin, Austin, TX': 2,
#  'Pacific Heights, San Francisco, CA': 2,
#  'Edmonds, WA': 2,
#  'Gaslamp Quarter, San Diego, CA': 2,
#  'Kennewick, WA': 1,
#  'Glen Mills, PA': 2,
#  'Orchard Lake, MI': 1,
#  'Athens, NY': 2,
#  'Williamsburg, MA': 1,
#  'NORTH HILLS, CA': 1,
#  'LeFrak City, Queens, NY': 1,
#  'Mystic, CT': 1,
#  'Old Lyme, CT': 1,
#  'McDonough, GA': 1,
#  'Oxford Charter Township, MI': 1,
#  'Fayetteville, NC': 1,
#  'Providence, RI': 32,
#  'Wildwood Crest, NJ': 1,
#  'Carlsbad, CA': 13,
#  'Lincoln, MA': 1,
#  'Bluffton, SC': 1,
#  'Cliffside Park, NJ': 16,
#  'Chapel Hill, NC': 15,
#  'Albertson, NY': 7,
#  'Hyde Park, Tampa, FL': 1,
#  'Montvale, NJ': 1,
#  'O‘ahu, HI': 2,
#  'Winnetka, IL': 1,
#  'Penfield, NY': 1,
#  'Northridge, CA': 1,
#  'Kuala Lumpur, Malaysia': 2,
#  'Kirkland, WA': 6,
#  'Hampton, VA': 1,
#  'Martlesham, United Kingdom': 1,
#  'Wharton, NJ': 2,
#  'Jasper, Canada': 1,
#  'Weehawken, NJ': 36,
#  'West Bloomfield Township, MI': 2,
#  'NC, NC': 5,
#  'Marco Island, FL': 3,
#  'Centerville, OH': 1,
#  'Anaheim Resort, Garden Grove, CA': 1,
#  'Sagaponack, NY': 2,
#  'PT ORANGE, FL': 1,
#  'Des Plaines, IL': 4,
#  'Rancho Santa Fe, CA': 1,
#  'Gravesend, Brooklyn, NY': 3,
#  'Kew Gardens, NY': 2,
#  'Mississauga, Canada': 6,
#  'Elysian Valley, Los Angeles, CA': 1,
#  'Cordova, TN': 1,
#  'Griffith Park/Los Feliz, Los Angeles, CA': 1,
#  'Murray Hill, Queens, NY': 5,
#  'Chicago, IL': 336,
#  'Heber City, UT': 1,
#  'San Marino, CA': 9,
#  'Brookhaven, GA': 1,
#  'Market East, Philadelphia, PA': 1,
#  'East York, Toronto, Canada': 1,
#  'Quebec City, Canada': 1,
#  'Westerly, RI': 1,
#  'Tomball, TX': 2,
#  'Grass Valley, CA': 1,
#  'Warrensburg, MO': 1,
#  'Falls Church, VA': 15,
#  'Roosevelt, NJ': 1,
#  'Cardiff-by-the-Sea, CA': 1,
#  'Topsfield, MA': 2,
#  'Salt Lake City, UT': 34,
#  'Union, NJ': 22,
#  'West Allis, Milwaukee, WI': 1,
#  'Colonial Village, Arlington, VA': 1,
#  'Kihei, HI': 2,
#  'Hemet, CA': 2,
#  'Cheshire, CT': 1,
#  'Reston, VA': 5,
#  'St. Georg, Hamburg, Germany': 1,
#  'Medical Center, Houston, TX': 1,
#  'Sea Girt, NJ': 1,
#  'Tiffin, IA': 1,
#  'Nijmegen, The Netherlands': 1,
#  'Steinway, Queens, NY': 2,
#  'Caldwell, NJ': 2,
#  'Osprey, FL': 1,
#  'Northport, NY': 4,
#  'Canarsie, Brooklyn, NY': 5,
#  'West Nyack, NY': 3,
#  'Old Sarum, United Kingdom': 1,
#  'Key West, FL': 2,
#  'Carson, Pittsburgh, PA': 1,
#  'JFK Airport, New York, NY': 1,
#  'Tarrytown, NY': 7,
#  'College Park, MD': 2,
#  'Franklin, OH': 1,
#  'Old Saybrook, CT': 2,
#  'Metuchen, NJ': 10,
#  'Greater Pinellas Point, St. Petersburg, FL': 1,
#  'Aiken, SC': 1,
#  'Boca Ratón, FL': 1,
#  'Waialua, HI': 1,
#  'Saint Johns, FL': 2,
#  'Chappaqua, NY': 7,
#  'Hobe Sound, FL': 1,
#  'Edgewater, NJ': 30,
#  'Clearwater, Tampa Bay, FL': 2,
#  'Prairie / Piper-KC-KS, Kansas City, KS': 1,
#  'Grapevine, TX': 7,
#  'Muncie, IN': 2,
#  'Campbell Hall, NY': 1,
#  'Chester, United Kingdom': 1,
#  'North Vancouver, Canada': 1,
#  'Frankfort, IL': 1,
#  'Cartersville, GA': 1,
#  'Wheaton, IL': 5,
#  'West Babylon, NY': 11,
#  'Huntsville, TX': 1,
#  'Rochester, MN': 2,
#  'Enfield, London, United Kingdom': 1,
#  'Nassau, NY': 5,
#  'Pearl River, NY': 1,
#  'North Charlotte, Charlotte, NC': 1,
#  'Allston, MA': 2,
#  'Coronado, CA': 1,
#  'Irmo, SC': 1,
#  'Taguig, Philippines': 1,
#  'North Valley, San Jose, CA': 1,
#  'Montreal, Canada': 21,
#  'South Charleston, WV': 1,
#  'Vineland, NJ': 1,
#  'Bensonhurst, NY': 5,
#  'Merida, Mexico': 1,
#  'North Druid Hills, GA': 1,
#  'Jacksonville Beach, FL': 3,
#  'Buenos Aires, Argentina': 1,
#  'Babylon, NY': 3,
#  'Campinas, Brazil': 1,
#  'Oakland, ME': 1,
#  'Forest Hill, TX': 1,
#  'Somers, NY': 3,
#  'Bradenton, FL': 5,
#  'Patchogue, NY': 7,
#  'Little Falls, NJ': 2,
#  'Andover, MA': 3,
#  'Morris Plains, NJ': 5,
#  'Princeton Township, NJ': 1,
#  'Hendersonville, NC': 1,
#  'Ponte Vedra Beach, FL': 1,
#  'Chantilly, VA': 14,
#  'Fort Lee, NJ': 50,
#  'Roanoke, VA': 1,
#  'Parlin, NJ': 1,
#  'Rhodes Ranch, Las Vegas, NV': 1,
#  'Opa-locka, FL': 1,
#  'Suffolk, NY': 1,
#  'Studio City, Los Angeles, CA': 1,
#  'Morton, PA': 1,
#  'Long Beach, NY': 13,
#  'Mill Creek, WA': 1,
#  'Waldoboro, ME': 1,
#  '11ème, Paris, France': 1,
#  'Brooklyn Heights, Brooklyn, NY': 3,
#  'Shédiac, Canada': 1,
#  'Flamingo, Flamingo, FL': 1,
#  'Mount Laurel, NJ': 2,
#  'Flatbush, Brooklyn, NY': 6,
#  'University Park, Dallas, TX': 1,
#  'Tyrone, PA': 1,
#  'Canton, CT': 1,
#  'Oxford, MS': 1,
#  'Kennebunk, ME': 1,
#  'Colleyville, TX': 3,
#  'Glastonbury, CT': 2,
#  'Olympia, WA': 5,
#  'Riverdale, Bronx, NY': 4,
#  'Wake Forest, NC': 5,
#  'Falmouth, MA': 1,
#  'Rancho Palos Verdes, CA': 13,
#  "Fisherman's Wharf, San Francisco, CA": 1,
#  'Pasadena, Los Angeles, CA': 1,
#  'French Quarter, New Orleans, LA': 1,
#  'Hopkins, MN': 2,
#  'Southeast Magnolia, Seattle, WA': 1,
#  'Tappan, NY': 2,
#  'Northeast, Denver, CO': 2,
#  'Beacon, NY': 4,
#  'Mililani, HI': 1,
#  'Sea Cliff, NY': 1,
#  'Merriam Park West, Saint Paul, MN': 1,
#  'Peterborough, NH': 1,
#  'Champaign, IL': 8,
#  'Incline Village, NV': 1,
#  'Cupertino, CA': 21,
#  'South Portland, ME': 1,
#  'Wexford, PA': 2,
#  'La Costa, Carlsbad, CA': 1,
#  'Northbridge, MA': 1,
#  'Ma Campagne, Brussels, Belgium': 1,
#  'Fontana, CA': 5,
#  'East Hill-Meridian, WA': 1,
#  'Joliet, IL': 1,
#  'Billings, MT': 1,
#  'Miami, FL': 229,
#  'SKILLMAN, NJ': 1,
#  'Newark, DE': 10,
#  'Greenbelt, MD': 1,
#  'Gibsonia, PA': 1,
#  'Longmont, CO': 1,
#  'Sicklerville, NJ': 1,
#  'Milltown, NJ': 1,
#  'Alviso, CA': 1,
#  'Zürich, Switzerland': 8,
#  'RICHMOND HILL, NY': 5,
#  'Paris, France': 15,
#  'East San Jose, San Jose, CA': 2,
#  'Palo Alto, CA': 37,
#  'Stockholms län, Sweden': 2,
#  'Brownsburg, IN': 1,
#  'Amsterdam, The Netherlands': 4,
#  'Amityville, NY': 8,
#  'Mount Vernon Square, Washington, DC': 1,
#  'Hope Mills, NC': 1,
#  'South Hackensack, NJ': 1,
#  'Meriden, CT': 2,
#  'Mountain Top, PA': 2,
#  'Peekskill, NY': 2,
#  'Southfield, MI': 2,
#  'Ocean Shores, Australia': 1,
#  'Freeport, IL': 1,
#  'Utopia, Queens, NY': 1,
#  'Bensonhurst, Brooklyn, NY': 7,
#  'Evesham Township, NJ': 2,
#  'Sedro-Woolley, WA': 1,
#  'Landing, Landing, NJ': 1,
#  'Pauma Valley, CA': 1,
#  '東京都, Japan': 1,
#  'Jersey, Jersey': 4,
#  'Mount Holly, NJ': 2,
#  'Colts Neck, NJ': 5,
#  'Pocono Mountains, PA': 1,
#  'Southeast Washington, Washington, DC': 1,
#  'Midtown, Detroit, MI': 1,
#  'Near West Side, Chicago, IL': 1,
#  'Damascus, OR': 1,
#  'Inglewood, CA': 5,
#  'Bullshead, Staten Island, NY': 1,
#  'MT, MT': 1,
#  'Westchester / LAX, Los Angeles, CA': 1,
#  'South Houston, TX': 1,
#  'Westwood, NJ': 5,
#  'Hoschton, GA': 1,
#  'Rumford, RI': 1,
#  'Cape Canaveral, FL': 1,
#  'Wilmington, MA': 1,
#  'Manassas Park, VA': 1,
#  'Istanbul, Turkey': 3,
#  'ブルックリン, NY': 2,
#  'Old Pasadena, Pasadena, CA': 1,
#  'Tualatin, OR': 1,
#  '16ème, Paris, France': 1,
#  'Saint Louis, MO': 22,
#  'Sabana Llana Sur, San Juan, Puerto Rico, San Juan, Puerto Rico': 1,
#  'Downtown, Columbus, OH': 1,
#  'Northern California, CA': 1,
#  'Blacklick, OH': 1,
#  'Gowanus, NY': 1,
#  'Rockland County, NY': 1,
#  'Downtown, Vancouver, Canada': 1,
#  'Cedarhurst, NY': 1,
#  'Fairlie-Poplar, Atlanta, GA': 1,
#  'Brunswick, ME': 1,
#  'Bay Ridge, Brooklyn, NY': 6,
#  'North Granby, CT': 1,
#  'Manchester, CT': 5,
#  'Hudson, NH': 1,
#  'Vallejo, CA': 2,
#  'Elkridge, MD': 5,
#  'Barnstable, MA': 1,
#  'Teton Village, WY': 1,
#  'La Vergne, TN': 1,
#  'Oldsmar, FL': 1,
#  'Douglasville, GA': 2,
#  'Placentia, CA': 6,
#  'Bay Ridge, NY': 2,
#  'Bastia, France': 2,
#  'Kent, OH': 1,
#  'Dunwoody, GA': 8,
#  'Downtown Oakland, Oakland, CA': 1,
#  'Staten Island, New York, NY': 3,
#  'Lambertville, NJ': 1,
#  'Clover, SC': 1,
#  'Ajax, Canada': 1,
#  'Monmouth, IL': 1,
#  'Whippany, Hanover, NJ': 1,
#  'West Caldwell, NJ': 2,
#  'Carrboro, NC': 1,
#  'Orinda, CA': 3,
#  'Lahaina, HI': 3,
#  'Akron, OH': 3,
#  'Anaheim Resort, Orange, CA': 1,
#  'San Nicolas, San Nicolas, Argentina': 1,
#  'Severn, MD': 2,
#  'Thornwood, NY': 2,
#  'Newton Lower Falls, Newton, MA': 3,
#  'Garland, TX': 4,
#  'Barcelona, Spain': 8,
#  'Springfield, MA': 5,
#  'Detroit, MI': 22,
#  'West Warwick, RI': 1,
#  'Clarks Summit, PA': 1,
#  'Scarsdale, NY': 17,
#  'West Springfield, MA': 1,
#  'Stoughton, WI': 1,
#  'Hamilton, NJ': 1,
#  'Bergen County, NJ': 19,
#  'Little Silver, NJ': 1,
#  'Pine Bush, NY': 1,
#  'Hoosick Falls, NY': 1,
#  'Castleton-on-Hudson, NY': 1,
#  'Lancaster, CA': 2,
#  'Calabasas, CA': 3,
#  'Newport, RI': 2,
#  'Washington D.C., DC': 6,
#  'Bayside, NY': 30,
#  'Spring, TX': 11,
#  'Oakville, Canada': 3,
#  'Clear Lake, Webster, TX': 1,
#  'The Loop, Chicago, IL': 3,
#  'Mesa, AZ': 13,
#  'Glassboro, NJ': 1,
#  'Litchfield County, CT': 1,
#  'Roslyn, NY': 8,
#  'Lewisburg, PA': 2,
#  'Middletown, NJ': 2,
#  'Franklin Township, NJ': 4,
#  'Lexington, MA': 1,
#  'Jericho, NY': 18,
#  'Saint Clair Shores, MI': 1,
#  'Sioux City, IA': 1,
#  'Belle Mead, NJ': 2,
#  'Wallington, NJ': 3,
#  'Yorktown Heights, NY': 5,
#  'Rocky Point, NY': 1,
#  'Green Village, NJ': 1,
#  'New Westminster, Canada': 2,
#  'Lewisville, NC': 1,
#  'West Bloomfield, MI': 1,
#  'Ann Arbor, MI': 20,
#  'Cherry Hill, NJ': 6,
#  'Wayne, PA': 2,
#  'Elmhurst, New York, NY': 3,
#  'Maywood, CA': 1,
#  'Stewartsville, NJ': 3,
#  'Belmont Shore, Long Beach, CA': 1,
#  'Palm Beach Gardens, FL': 5,
#  'Cypress, CA': 11,
#  'Tahoe Park, Sacramento, CA': 1,
#  'Centereach, NY': 1,
#  'King, WA': 2,
#  'Beverly, MA': 2,
#  'Torrance, CA': 31,
#  'Ridgewood, NJ': 18,
#  'Lima, NY': 1,
#  'Romeoville, IL': 2,
#  'Woodhaven, NY': 2,
#  'Davis, CA': 10,
#  'Cocoa Beach, FL': 1,
#  'Mapleton, NY': 1,
#  'North Wales, PA': 1,
#  'West Lafayette, IN': 2,
#  'Larkspur, CO': 1,
#  'Cranston, RI': 5,
#  'Downtown Jersey City, Jersey City, NJ': 6,
#  'Franklin Park, NJ': 3,
#  'East Elmhurst, NY': 20,
#  'Placerville, CA': 2,
#  'Glen Oaks, NY': 7,
#  'Hoboken, NJ': 128,
#  'Long Island City, New York, NY': 19,
#  'Pelham, NY': 7,
#  'Roselle, NJ': 4,
#  'Kansas City, MO': 20,
#  'City of Orange, NJ': 2,
#  'Bloomsburg, PA': 1,
#  'Hacienda Heights, CA': 3,
#  'North Hollywood, CA': 5,
#  'Sweden': 1,
#  'Congers, NY': 1,
#  'Upper Darby, PA': 1,
#  'Dublin, Republic of Ireland': 4,
#  'Garner, NC': 3,
#  'Burke, VA': 1,
#  'Ferndale, MI': 1,
#  'Red Bank, NJ': 5,
#  'Hagerstown, MD': 1,
#  'San Rafael, CA': 5,
#  'Near North Side, Chicago, IL': 5,
#  'Clearwater Beach, Tampa Bay, FL': 1,
#  'Bezirk Mitte, Berlin, Germany': 1,
#  'Plymouth Meeting, PA': 1,
#  'Madison, CT': 3,
#  'La Palma, CA': 4,
#  'Utrecht, The Netherlands': 1,
#  'River Edge, NJ': 10,
#  'Windsor Mill, Milford Mill, MD': 1,
#  'Mount Pleasant/Lower Broadway, Newark, NJ': 1,
#  'Orangeburg, NY': 1,
#  'McAllen, TX': 1,
#  'Antioch, Nashville, TN': 2,
#  'Absecon, NJ': 1,
#  'Upavon, United Kingdom': 1,
#  'København, Denmark': 3,
#  'Holland, MI': 1,
#  'Downtown, Fort Worth, TX': 1,
#  'Bay City, TX': 1,
#  'Windsor Hills, Windsor Hills, CA': 1,
#  'East Northport, NY': 7,
#  'Westdale South, Hamilton, Canada': 1,
#  'Post, TX': 1,
#  'Waltham, MA': 10,
#  'Hollywood Hills West, Los Angeles, CA': 1,
#  'Orland Park, IL': 1,
#  'Cordova, Cordova, TN': 1,
#  'Johnson City, NY': 1,
#  'Ocean Township, NJ': 2,
#  'Seward, AK': 1,
#  'Charlottesville, VA': 20,
#  'San Clemente, CA': 2,
#  'Rex Manor, Mountain View, CA': 1,
#  'College Hill, Greensboro, NC': 1,
#  'South Side, Chicago, IL': 2,
#  'Winston-Salem, NC': 3,
#  'Fairfield, CT': 6,
#  'Westport, CT': 8,
#  'Hyattsville, MD': 1,
#  'Madison, IN': 1,
#  'Southwest Portland, Portland, OR': 3,
#  'Dilworth, Charlotte, NC': 1,
#  'Rivertowns, NY': 2,
#  'Montgomery Village, MD': 3,
#  'West Hartford, CT': 16,
#  '12, MD': 1,
#  'Madrid, Spain': 5,
#  'Krotz Springs, LA': 1,
#  'Newton, NJ': 1,
#  'Hamilton, IL': 1,
#  'Parkside, Portland, ME': 1,
#  'North Billerica, MA': 1,
#  'Guilford, CT': 2,
#  'Foothill Ranch, CA': 2,
#  'San Anselmo, CA': 2,
#  'Merced, CA': 2,
#  'Lindsay, CA': 1,
#  'Sun Valley, ID': 1,
#  'Northeast Philadelphia, Philadelphia, PA': 1,
#  'North Attleborough, MA': 1,
#  'West Bronx, NY': 7,
#  'Purchase, Harrison, NY': 1,
#  'Greenwich, CT': 17,
#  'Douglaston, Queens, NY': 2,
#  'Perkasie, PA': 2,
#  'Long Island City, NY': 100,
#  'Annandale, VA': 15,
#  'Middlesex, CT': 1,
#  'Oxford, United Kingdom': 1,
#  'Chesterfield, VA': 1,
#  'Frankfort, NY': 1,
#  'Outram, Singapore, Singapore': 1,
#  'Richfield, OH': 1,
#  'Aptos, CA': 1,
#  'North Royalton, OH': 1,
#  'Morgantown, WV': 2,
#  'Hartland, WI': 1,
#  'Smithfield, RI': 1,
#  'Coney Island, Brooklyn, NY': 1,
#  'Chatan, Japan': 1,
#  'Las Cruces, NM': 1,
#  'Carroll Gardens, Brooklyn, NY': 6,
#  'Novato, CA': 2,
#  'Melissa, TX': 1,
#  'Downtown, New Haven, CT': 1,
#  'La Sierra, CA': 1,
#  'Normal, IL': 1,
#  'Pocono Pines, PA': 2,
#  'Kingston, Canada': 3,
#  'Landis, NC': 1,
#  'Queen Anne, Seattle, WA': 1,
#  'Brooklyn, New York, NY': 103,
#  'Milan, Italy': 1,
#  'Beech Mountain, NC': 1,
#  'Carolina, Puerto Rico': 2,
#  'Sierra Madre, CA': 2,
#  'Kendall Park, South Brunswick Township, NJ': 1,
#  'Chinatown, Philadelphia, PA': 1,
#  'The Villages, FL': 1,
#  'Hudson, Hudson, MA': 1,
#  'Shreveport, LA': 1,
#  'Vancouver, WA': 7,
#  'New Boston, TX': 1,
#  'Pacific, Stockton, CA': 1,
#  'St Paul, MN': 1,
#  'Castle Heights, Los Angeles, CA': 1,
#  'Manchester, MD': 1,
#  'Springfield, VA': 8,
#  'Glendale, Queens, NY': 3,
#  'New Braunfels, TX': 2,
#  'Maple Glen, PA': 1,
#  'Lihue, HI': 1,
#  'Starin Central, Buffalo, NY': 2,
#  'Milton, MA': 1,
#  'Rohnert Park, CA': 1,
#  'Manhattan, KS': 1,
#  'Depew, NY': 1,
#  'Buford, GA': 2,
#  'Westside, Jacksonville, FL': 2,
#  'Cornwall, NY': 1,
#  'Brookline, MA': 17,
#  'Lynn, MA': 2,
#  'Winter Garden, FL': 3,
#  'Ewing Township, NJ': 1,
#  'Fulton Market, Chicago, IL': 1,
#  'Federal Way, WA': 3,
#  'Westchester County, NY': 11,
#  'Woodmont Triangle, Bethesda, MD': 2,
#  'Corte Madera, CA': 2,
#  'York, ME': 1,
#  'Bloomfield Hills, MI': 3,
#  'La Grange, IL': 1,
#  'Union Square, Manhattan, NY': 12,
#  'Richmond Hill, Canada': 10,
#  'Westchester Square, Bronx, NY': 1,
#  'Mid City, Los Angeles, CA': 2,
#  'Westport, MA': 1,
#  'Englewood Cliffs, NJ': 4,
#  'West Milford, NJ': 2,
#  'Portola, CA': 1,
#  'Naugatuck, CT': 1,
#  'Cambria Heights, NY': 3,
#  'Montgomery, NJ': 1,
#  'Glen Head, NY': 4,
#  'Midwood, Brooklyn, NY': 6,
#  'Rockwall, TX': 2,
#  'East Stroudsburg, PA': 7,
#  'Southern California, CA': 2,
#  'Brambleton, VA': 1,
#  'Williston Park, NY': 3,
#  'Constable Hook, Bayonne, NJ': 1,
#  'Macon, GA': 2,
#  'Northwest Dallas, Dallas, TX': 1,
#  'San Francisco, CA': 998,
#  'Ontario, CA': 3,
#  'Venetia, PA': 1,
#  'Brick Township, NJ': 1,
#  'Hillsdale, NJ': 1,
#  'North End, Boston, MA': 3,
#  'Shelton, CT': 7,
#  'Kips Bay, Manhattan, NY': 5,
#  'Oak Park, Sacramento, CA': 1,
#  'Old Town Alexandria, Alexandria, VA': 2,
#  'Wilsonville, OR': 1,
#  'Ann Arbor Charter Township, MI': 2,
#  'Shoreline West, Mountain View, CA': 1,
#  'Shenandoah, TX': 1,
#  'Dania Beach, FL': 1,
#  'Cutler Bay, FL': 1,
#  'Hockley, TX': 1,
#  'East Austin, Austin, TX': 1,
#  'Storrs, Mansfield, CT': 1,
#  'Paso Robles, CA': 1,
#  'Bearsville, NY': 1,
#  'Puyallup, WA': 3,
#  'Bedford-Stuyvesant, NY': 8,
#  'Covina, CA': 2,
#  'Pine Brook, NJ': 1,
#  'Chevy Chase, MD': 7,
#  'Kaohsiung, Taiwan': 1,
#  'Richardson, TX': 8,
#  'Knoxville, TN': 12,
#  'Town of Oyster Bay, Long Island, NY': 2,
#  'Litchfield, ME': 1,
#  'Broome, Australia': 1,
#  'Pawling, NY': 1,
#  'Hastings-on-Hudson, NY': 1,
#  'Waterloo, NE': 1,
#  'Georgetown, TX': 3,
#  'Largo, FL': 2,
#  'Lewis Center, OH': 3,
#  'Flower Mound, TX': 4,
#  'Cranford, NJ': 5,
#  'Cudahy, WI': 1,
#  'Chattanooga, TN': 7,
#  'DUMBO, Brooklyn, NY': 6,
#  'Grandview, Glendale, CA': 1,
#  'Seekonk, MA': 1,
#  'Windsor Terrace, NY': 1,
#  'Bronx, Bronx, NY': 50,
#  'Kodak, TN': 1,
#  'Granger, IN': 1,
#  'Nichols Hills, OK': 1,
#  'Ypsilanti, MI': 3,
#  'Windermere, Orlando, FL': 1,
#  'Tacoma, WA': 12,
#  'San Pedro, San Pedro, CA': 1,
#  'Bloomingdale, IL': 1,
#  'Camarillo, CA': 4,
#  'Florence, Italy': 4,
#  'Noord, Amsterdam, The Netherlands': 1,
#  'Silverdale, WA': 1,
#  'Rolling Meadows, IL': 1,
#  'Marylebone, London, United Kingdom': 1,
#  'Wauwatosa, WI': 1,
#  'Blacksburg, VA': 1,
#  'Hempstead, TX': 1,
#  'Paramus, NJ': 25,
#  'Haledon, NJ': 4,
#  'Berkeley, CA': 67,
#  'Stockton, CA': 6,
#  'The Colony, TX': 3,
#  'Lake Worth, FL': 3,
#  'Stoughton, MA': 3,
#  'Leipzig, Germany': 1,
#  'Gig Harbor, WA': 1,
#  'LaPlace, LA': 1,
#  'INCLINE VLG, NV': 1,
#  'Dyker Heights, Brooklyn, NY': 5,
#  'Uptown/Carrollton, New Orleans, LA': 1,
#  'Fredericktown, OH': 1,
#  'Vienna, Austria': 1,
#  'Boston, MA': 273,
#  'Millburn, NJ': 2,
#  'Westchester, Los Angeles, CA': 1,
#  'Indian Trail, NC': 1,
#  'Lorton, VA': 3,
#  'Cecil, PA': 1,
#  'REGO PARK, NY': 6,
#  'Lincolnshire, IL': 1,
#  'Uptown, Dallas, TX': 2,
#  'Buena Park, CA': 9,
#  'Hartsdale, NY': 8,
#  'Melbourne, Australia': 5,
#  'West Los Angeles, CA': 7,
#  'Evanston, IL': 18,
#  'Arroyo Grande, CA': 2,
#  'Woodinville, WA': 2,
#  'Union Square, San Francisco, CA': 2,
#  'NH, NH': 1,
#  'West Hollywood, CA': 26,
#  'Elmhurst, Queens, NY': 8,
#  'Shiba, Minato-ku, Japan': 1,
#  'Las Vegas, NV': 93,
#  'Canandaigua, NY': 1,
#  'Brighton Beach, NY': 1,
#  'SoMa, San Francisco, CA': 19,
#  'Escondido, CA': 4,
#  'West Palm Beach, FL': 9,
#  'Narberth, PA': 1,
#  'Town of Islip, Long Island, NY': 1,
#  'Clarksville, TN': 2,
#  'Chester, NJ': 2,
#  'Carnegie, Pittsburgh, PA': 1,
#  'Pittsburgh, PA': 60,
#  'Washington Heights, New York, NY': 4,
#  'Marlow, OK': 1,
#  'Downtown, Saint Louis, MO': 1,
#  'Little Italy, Manhattan, NY': 5,
#  'Brewster, MA': 1,
#  'Williamsburg - South Side, Brooklyn, NY': 16,
#  'Polk City, FL': 1,
#  'Canaan, NY': 1,
#  'Aubrey, TX': 2,
#  'Castle Hill, Bronx, NY': 1,
#  'Malverne, NY': 2,
#  'Seal Beach, CA': 1,
#  'Germantown, MD': 5,
#  'Norman, OK': 3,
#  '堅尼地城, Hong Kong': 1,
#  'Nashville, TN': 38,
#  'Spring Valley, CA': 5,
#  'Oak Cliff, Dallas, TX': 1,
#  'Sammamish, WA': 4,
#  'JACKSON HEIGHTS, NY': 2,
#  'Lansdale, PA': 1,
#  'Lake Harmony, PA': 1,
#  'Harrison, NJ': 9,
#  'Layton, UT': 3,
#  'New City, NY': 3,
#  'Lancaster, OH': 1,
#  'Waterbury, CT': 1,
#  'Klamath Falls, OR': 1,
#  'Huntington Beach, CA': 36,
#  'CT, CT': 9,
#  'Westminster, CO': 3,
#  'Butchers Hill, Baltimore, MD': 1,
#  'Warwick, RI': 2,
#  'Northeast Calgary, Calgary, Canada': 1,
#  'Carlstadt, NJ': 5,
#  'District of Columbia, DC': 1,
#  'SOUTH RICHMOND HILL, NY': 2,
#  'Savannah, TX': 1,
#  'Omaha, NE': 7,
#  'Morganville, NJ': 2,
#  'University Park, Irvine, CA': 1,
#  'Hobby, Houston, TX': 1,
#  'Marshfield, MO': 1,
#  'Avenel, NJ': 2,
#  'Alexandria, LA': 1,
#  'Crystal Lake, IL': 1,
#  'Kintnersville, PA': 1,
#  'Theater District, Manhattan, NY': 10,
#  'Somerville, NJ': 4,
#  'Cedar Rapids, IA': 2,
#  'Mountainside, NJ': 3,
#  'Mission Viejo, CA': 7,
#  'Washington Township, NJ': 1,
#  'Budd Lake, NJ': 1,
#  'Fresno, CA': 5,
#  'Milton, Canada': 2,
#  'Xinyi District, Taiwan': 2,
#  'Verona, NJ': 1,
#  'Pittsford, NY': 1,
#  'Cedar Hills, UT': 1,
#  'Willoughby Hills, OH': 1,
#  'Atascadero, CA': 2,
#  'Anaheim, CA': 35,
#  'Smyrna, GA': 3,
#  'Santa Ana, CA': 21,
#  'Poway, CA': 4,
#  'Ridgewood, NY': 11,
#  'Windermere, FL': 2,
#  'Lakewood, CA': 6,
#  'Jacksonville, AL': 1,
#  'Chevy Chase Village, MD': 1,
#  'Temple City, CA': 10,
#  'Cancún, Mexico': 1,
#  'Mount Juliet, TN': 1,
#  'Balch Springs, TX': 2,
#  'Schuylkill Haven, PA': 1,
#  'Crown Heights, New York, NY': 1,
#  'New Castle, DE': 1,
#  'Allen, TX': 8,
#  'Newark, CA': 8,
#  ...}

# %% [markdown]
# **Checking for the trend in book production over time**

# %%
dic_years = {}
for years in user_revs_df['Date_of_review']:
    if int(years[-4:]) in dic_years.keys():
        dic_years[int(years[-4:])] += 1
    else:
        dic_years[int(years[-4:])] = 1
dic_years
# Out:
# {2023: 1474,
#  2022: 4975,
#  2021: 3411,
#  2020: 2188,
#  2019: 4368,
#  2018: 4320,
#  2016: 2954,
#  2017: 3461,
#  2015: 2861,
#  2014: 2153,
#  2013: 1547,
#  2011: 1232,
#  2012: 1301,
#  2010: 812,
#  2008: 308,
#  2009: 501,
#  2007: 141,
#  2005: 9,
#  2006: 78}

# %% [markdown]
# # Data Preparation

# %% [markdown]
# # Modeling

# %% [markdown]
# # Evaluation

# %% [markdown]
# # Deployment
